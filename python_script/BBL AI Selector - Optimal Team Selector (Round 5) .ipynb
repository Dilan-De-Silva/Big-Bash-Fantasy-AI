# %% [markdown]
# # BBLF AI Selector: Part 2: During Tournament Optimal Squad - Optimser (Round 5)

# %% [markdown]
# # 0. Prerequistes

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 

os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI'
add_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/round_5'
over_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/overall'
py_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets'

# %% [markdown]
# # 1. Data Extraction

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 5
opt_round = 2

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_5.csv'), low_memory=False)
#price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_', str(current_round), '.csv'), low_memory=False)

# print(price_df) 

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
# print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(py_data_directory,'bbl14_fullteam_model_score_during_rnd_5.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
# print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
# print(game_df)

    # Join on expected points for each game
# print(game_df.columns)
# print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
# print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# print(player_df)

player_df_next_rnd = player_df_raw[player_df_raw.Round == current_round].groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
next_rnd_exp_pts=('exp_pts',"sum"))
player_df_next_rnd = player_df_next_rnd[["Name", "Team", "next_rnd_exp_pts"]]

# %% [markdown]
# # 2. Optimisation Process (Round 5) - Normal 3 Trades
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,746,100
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1746100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]
sel_player_df = pd.merge(sel_player_df, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "Price", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_5.csv')
# Out:
# [<mip.entities.Var object at 0x00000230811545E0>, <mip.entities.Var object at 0x00000230811545B0>, <mip.entities.Var object at 0x0000023081154850>, <mip.entities.Var object at 0x00000230811546D0>, <mip.entities.Var object at 0x0000023081154880>, <mip.entities.Var object at 0x0000023081154700>, <mip.entities.Var object at 0x0000023081154760>, <mip.entities.Var object at 0x0000023081154730>, <mip.entities.Var object at 0x00000230811548E0>, <mip.entities.Var object at 0x00000230811549A0>, <mip.entities.Var object at 0x0000023081154940>, <mip.entities.Var object at 0x0000023081154A00>, <mip.entities.Var object at 0x0000023081154820>, <mip.entities.Var object at 0x0000023081154A60>, <mip.entities.Var object at 0x0000023081154970>, <mip.entities.Var object at 0x0000023081154A90>, <mip.entities.Var object at 0x0000023081154AF0>, <mip.entities.Var object at 0x00000230811548B0>, <mip.entities.Var object at 0x0000023081154B20>, <mip.entities.Var object at 0x00000230811547F0>, <mip.entities.Var object at 0x0000023081154A30>, <mip.entities.Var object at 0x0000023081154790>, <mip.entities.Var object at 0x0000023081154610>, <mip.entities.Var object at 0x0000023081154B80>, <mip.entities.Var object at 0x0000023081154BE0>, <mip.entities.Var object at 0x0000023081154C40>, <mip.entities.Var object at 0x0000023081154CA0>, <mip.entities.Var object at 0x0000023081154AC0>, <mip.entities.Var object at 0x0000023081154B50>, <mip.entities.Var object at 0x0000023081154C10>, <mip.entities.Var object at 0x0000023081154BB0>, <mip.entities.Var object at 0x0000023081154D30>, <mip.entities.Var object at 0x0000023081154910>, <mip.entities.Var object at 0x00000230811549D0>, <mip.entities.Var object at 0x0000023081154DC0>, <mip.entities.Var object at 0x0000023081154D00>, <mip.entities.Var object at 0x0000023081154D60>, <mip.entities.Var object at 0x0000023081154E50>, <mip.entities.Var object at 0x0000023081154DF0>, <mip.entities.Var object at 0x0000023081154E20>, <mip.entities.Var object at 0x0000023081154C70>, <mip.entities.Var object at 0x0000023081154F10>, <mip.entities.Var object at 0x0000023081154CD0>, <mip.entities.Var object at 0x0000023081154D90>, <mip.entities.Var object at 0x0000023081154FA0>, <mip.entities.Var object at 0x0000023081154FD0>, <mip.entities.Var object at 0x0000023081154EE0>, <mip.entities.Var object at 0x0000023081155030>, <mip.entities.Var object at 0x0000023081154F70>, <mip.entities.Var object at 0x0000023081154EB0>, <mip.entities.Var object at 0x0000023081154E80>, <mip.entities.Var object at 0x0000023081155090>, <mip.entities.Var object at 0x0000023081154F40>, <mip.entities.Var object at 0x0000023081155120>, <mip.entities.Var object at 0x0000023081155180>, <mip.entities.Var object at 0x00000230811550C0>, <mip.entities.Var object at 0x00000230811550F0>, <mip.entities.Var object at 0x00000230811551B0>, <mip.entities.Var object at 0x0000023081155000>, <mip.entities.Var object at 0x0000023081155210>, <mip.entities.Var object at 0x00000230811551E0>, <mip.entities.Var object at 0x0000023081155270>, <mip.entities.Var object at 0x0000023081155240>, <mip.entities.Var object at 0x0000023081155150>, <mip.entities.Var object at 0x00000230811552D0>, <mip.entities.Var object at 0x0000023081155390>, <mip.entities.Var object at 0x0000023081155300>, <mip.entities.Var object at 0x0000023081155060>, <mip.entities.Var object at 0x0000023081155420>, <mip.entities.Var object at 0x00000230811553C0>, <mip.entities.Var object at 0x00000230811553F0>, <mip.entities.Var object at 0x0000023081155480>, <mip.entities.Var object at 0x00000230811554E0>, <mip.entities.Var object at 0x00000230811552A0>, <mip.entities.Var object at 0x0000023081155330>, <mip.entities.Var object at 0x0000023081155540>, <mip.entities.Var object at 0x00000230811555A0>, <mip.entities.Var object at 0x0000023081155450>, <mip.entities.Var object at 0x0000023081155510>, <mip.entities.Var object at 0x0000023081155600>, <mip.entities.Var object at 0x0000023081155660>, <mip.entities.Var object at 0x ...
# selected items: [11, 34, 42, 46, 69, 80, 85, 115, 119, 121, 142, 145]
# Total Expect Points: 1218.3731500000001
# Total Next Round Points: 523.88275
# Total Team Cost: 1600200
# Number of Wk: 2
# Number of Bat: 7
# Number of Bowl: 9
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0     Ben Dwarshuis  178600        Sydney Sixers     0      0       1  BOWL
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 5   Lockie Ferguson  159000       Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600       Sydney Thunder     1      1       0    WK
# 10         Wes Agar  146800       Sydney Thunder     0      0       1  BOWL
# 3      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 1    Fergus O'Neill  128000  Melbourne Renegades     0      0       1  BOWL
# 6    Marcus Stoinis  121300      Melbourne Stars     0      1       1  ALLR
# 2       Hayden Kerr  113700        Sydney Sixers     0      1       1  ALLR
# 4        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 0        1          1        1   76.90800          40.25350
# 11       1          1        1   76.29850          39.37750
# 5        1          1        0  153.77400          44.69850
# 8        1          1        0  151.62950          46.84800
# 10       1          1        0  158.66900          42.58200
# 3        1          1        1   87.43700          43.21900
# 1        1          1        1  110.91450          57.89000
# 6        1          1        1   67.03450          35.18150
# 2        1          1        1   78.59050          40.11000
# 4        1          1        1   79.17450          41.02600
# 7        1          1        1   92.39000          47.37800
# 9        1          1        1   85.55315          45.31875
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0     Ben Dwarshuis  178600        Sydney Sixers     0      0       1  BOWL
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 3      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 1    Fergus O'Neill  128000  Melbourne Renegades     0      0       1  BOWL
# 6    Marcus Stoinis  121300      Melbourne Stars     0      1       1  ALLR
# 2       Hayden Kerr  113700        Sydney Sixers     0      1       1  ALLR
# 4        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 0        1          1        1   76.90800          40.25350
# 11       1          1        1   76.29850          39.37750
# 3        1          1        1   87.43700          43.21900
# 1        1          1        1  110.91450          57.89000
# 6        1          1        1   67.03450          35.18150
# 2        1          1        1   78.59050          40.11000
# 4        1          1        1   79.17450          41.02600
# 7        1          1        1   92.39000          47.37800
# 9        1          1        1   85.55315          45.31875
#                Name   Price            Team  Wk_f  Bat_f  Bowl_f  Role  \
# 5   Lockie Ferguson  159000  Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600  Sydney Thunder     1      1       0    WK
# 10         Wes Agar  146800  Sydney Thunder     0      0       1  BOWL
#
#     weight  Available  In_Team   exp_pts  next_rnd_exp_pts
# 5        1          1        0  153.7740           44.6985
# 8        1          1        0  151.6295           46.8480
# 10       1          1        0  158.6690           42.5820

# %% [markdown]
# # 3. Optimisation Process (Round 5) - Normal 3 Trades + Boost
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,746,100
# 6. Atleast 8 players in current team (4 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 8, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1746100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost = player_df.iloc[selected]
sel_player_df_boost = pd.merge(sel_player_df_boost, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost["Price"]))
print("Number of Wk:", sum(sel_player_df_boost["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost["In_Team"]))

print(sel_player_df_boost.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost[sel_player_df_boost['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost[sel_player_df_boost['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df_boost.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_5_boost.csv')
# Out:
# [<mip.entities.Var object at 0x00000230FFC78F70>, <mip.entities.Var object at 0x000002308113A410>, <mip.entities.Var object at 0x00000230811386D0>, <mip.entities.Var object at 0x000002308113A8F0>, <mip.entities.Var object at 0x000002308113A7D0>, <mip.entities.Var object at 0x000002308113A590>, <mip.entities.Var object at 0x000002308113A680>, <mip.entities.Var object at 0x000002308113A980>, <mip.entities.Var object at 0x000002308113A890>, <mip.entities.Var object at 0x000002308113A6B0>, <mip.entities.Var object at 0x000002308113A920>, <mip.entities.Var object at 0x000002308113A800>, <mip.entities.Var object at 0x000002308113A2C0>, <mip.entities.Var object at 0x000002308113A5F0>, <mip.entities.Var object at 0x000002308113AE90>, <mip.entities.Var object at 0x000002308113A470>, <mip.entities.Var object at 0x000002308113A650>, <mip.entities.Var object at 0x000002308113A530>, <mip.entities.Var object at 0x000002308113A110>, <mip.entities.Var object at 0x000002308113A200>, <mip.entities.Var object at 0x000002308113A740>, <mip.entities.Var object at 0x000002308113AC80>, <mip.entities.Var object at 0x000002308113AA10>, <mip.entities.Var object at 0x000002308113A860>, <mip.entities.Var object at 0x000002308113AA70>, <mip.entities.Var object at 0x000002308113AB00>, <mip.entities.Var object at 0x000002308113AE60>, <mip.entities.Var object at 0x000002308113AF50>, <mip.entities.Var object at 0x000002308113ADD0>, <mip.entities.Var object at 0x000002308113B160>, <mip.entities.Var object at 0x000002308113A770>, <mip.entities.Var object at 0x000002308113A320>, <mip.entities.Var object at 0x000002308113A950>, <mip.entities.Var object at 0x000002308113A4A0>, <mip.entities.Var object at 0x000002308113A1A0>, <mip.entities.Var object at 0x000002308113AB30>, <mip.entities.Var object at 0x000002308113A1D0>, <mip.entities.Var object at 0x000002308113A440>, <mip.entities.Var object at 0x000002308113ACB0>, <mip.entities.Var object at 0x000002308113A380>, <mip.entities.Var object at 0x000002308113A5C0>, <mip.entities.Var object at 0x000002308113A350>, <mip.entities.Var object at 0x000002308113A620>, <mip.entities.Var object at 0x000002308113AC50>, <mip.entities.Var object at 0x000002308113B310>, <mip.entities.Var object at 0x000002308113B8B0>, <mip.entities.Var object at 0x000002308113ABC0>, <mip.entities.Var object at 0x000002308113AEF0>, <mip.entities.Var object at 0x000002308113AA40>, <mip.entities.Var object at 0x000002308113AB90>, <mip.entities.Var object at 0x000002308113AFB0>, <mip.entities.Var object at 0x000002308113AC20>, <mip.entities.Var object at 0x000002308113B250>, <mip.entities.Var object at 0x000002308113ADA0>, <mip.entities.Var object at 0x000002308113ABF0>, <mip.entities.Var object at 0x000002308113AD10>, <mip.entities.Var object at 0x000002308113AF20>, <mip.entities.Var object at 0x000002308113B010>, <mip.entities.Var object at 0x000002308113B0A0>, <mip.entities.Var object at 0x000002308113B3D0>, <mip.entities.Var object at 0x000002308113AF80>, <mip.entities.Var object at 0x000002308113B070>, <mip.entities.Var object at 0x000002308113B100>, <mip.entities.Var object at 0x000002308113B1F0>, <mip.entities.Var object at 0x000002308113B040>, <mip.entities.Var object at 0x000002308113B2E0>, <mip.entities.Var object at 0x000002308113B280>, <mip.entities.Var object at 0x000002308113B370>, <mip.entities.Var object at 0x000002308113AD40>, <mip.entities.Var object at 0x000002308113B4C0>, <mip.entities.Var object at 0x000002308113B130>, <mip.entities.Var object at 0x000002308113B430>, <mip.entities.Var object at 0x000002308113B5E0>, <mip.entities.Var object at 0x000002308113B8E0>, <mip.entities.Var object at 0x000002308113B940>, <mip.entities.Var object at 0x000002308113B850>, <mip.entities.Var object at 0x000002308113B970>, <mip.entities.Var object at 0x000002308113B1C0>, <mip.entities.Var object at 0x000002308113B190>, <mip.entities.Var object at 0x000002308113B340>, <mip.entities.Var object at 0x000002308113B490>, <mip.entities.Var object at 0x ...
# selected items: [11, 30, 34, 42, 46, 69, 80, 115, 119, 121, 142, 145]
# Total Expect Points: 1288.18665
# Total Next Round Points: 529.65025
# Total Team Cost: 1631200
# Number of Wk: 2
# Number of Bat: 7
# Number of Bowl: 9
# Available Players: 12
# Current Players Remaining: 8
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0     Ben Dwarshuis  178600        Sydney Sixers     0      0       1  BOWL
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 6   Lockie Ferguson  159000       Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600       Sydney Thunder     1      1       0    WK
# 1       Daniel Sams  152300       Sydney Thunder     0      1       1  ALLR
# 10         Wes Agar  146800       Sydney Thunder     0      0       1  BOWL
# 4      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 2    Fergus O'Neill  128000  Melbourne Renegades     0      0       1  BOWL
# 3       Hayden Kerr  113700        Sydney Sixers     0      1       1  ALLR
# 5        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 0        1          1        1   76.90800          40.25350
# 11       1          1        1   76.29850          39.37750
# 6        1          1        0  153.77400          44.69850
# 8        1          1        0  151.62950          46.84800
# 1        1          1        0  136.84800          40.94900
# 10       1          1        0  158.66900          42.58200
# 4        1          1        1   87.43700          43.21900
# 2        1          1        1  110.91450          57.89000
# 3        1          1        1   78.59050          40.11000
# 5        1          1        1   79.17450          41.02600
# 7        1          1        1   92.39000          47.37800
# 9        1          1        1   85.55315          45.31875
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0     Ben Dwarshuis  178600        Sydney Sixers     0      0       1  BOWL
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 4      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 2    Fergus O'Neill  128000  Melbourne Renegades     0      0       1  BOWL
# 3       Hayden Kerr  113700        Sydney Sixers     0      1       1  ALLR
# 5        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 0        1          1        1   76.90800          40.25350
# 11       1          1        1   76.29850          39.37750
# 4        1          1        1   87.43700          43.21900
# 2        1          1        1  110.91450          57.89000
# 3        1          1        1   78.59050          40.11000
# 5        1          1        1   79.17450          41.02600
# 7        1          1        1   92.39000          47.37800
# 9        1          1        1   85.55315          45.31875
#                Name   Price            Team  Wk_f  Bat_f  Bowl_f  Role  \
# 6   Lockie Ferguson  159000  Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600  Sydney Thunder     1      1       0    WK
# 1       Daniel Sams  152300  Sydney Thunder     0      1       1  ALLR
# 10         Wes Agar  146800  Sydney Thunder     0      0       1  BOWL
#
#     weight  Available  In_Team   exp_pts  next_rnd_exp_pts
# 6        1          1        0  153.7740           44.6985
# 8        1          1        0  151.6295           46.8480
# 1        1          1        0  136.8480           40.9490
# 10       1          1        0  158.6690           42.5820

# %% [markdown]
# # 4. Optimisation Process (Round 5) - Normal 3 Trades + Sam Konstas (Boost)
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,746,100 + $36,100
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1782200, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost_SK = player_df.iloc[selected]
sel_player_df_boost_SK = pd.merge(sel_player_df_boost_SK, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost_SK["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost_SK["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost_SK["Price"]))
print("Number of Wk:", sum(sel_player_df_boost_SK["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost_SK["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost_SK["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost_SK["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost_SK["In_Team"]))

print(sel_player_df_boost_SK.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df_boost_SK.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_5_boost_SK.csv')
# Out:
# [<mip.entities.Var object at 0x00000230811BF2B0>, <mip.entities.Var object at 0x00000230811BCB80>, <mip.entities.Var object at 0x00000230811BF700>, <mip.entities.Var object at 0x00000230811BF760>, <mip.entities.Var object at 0x00000230811BF340>, <mip.entities.Var object at 0x00000230811BF640>, <mip.entities.Var object at 0x00000230811BC6A0>, <mip.entities.Var object at 0x00000230811BD210>, <mip.entities.Var object at 0x00000230811BDCF0>, <mip.entities.Var object at 0x00000230811BD9C0>, <mip.entities.Var object at 0x00000230811BC370>, <mip.entities.Var object at 0x00000230811BD360>, <mip.entities.Var object at 0x00000230811BD570>, <mip.entities.Var object at 0x00000230811BCEB0>, <mip.entities.Var object at 0x00000230811BC6D0>, <mip.entities.Var object at 0x00000230811BD750>, <mip.entities.Var object at 0x00000230811BCA60>, <mip.entities.Var object at 0x00000230811BCFD0>, <mip.entities.Var object at 0x00000230811BD150>, <mip.entities.Var object at 0x00000230811BC7F0>, <mip.entities.Var object at 0x00000230811BD450>, <mip.entities.Var object at 0x00000230811BD090>, <mip.entities.Var object at 0x00000230811BD5A0>, <mip.entities.Var object at 0x00000230811BCA90>, <mip.entities.Var object at 0x00000230811BCE50>, <mip.entities.Var object at 0x00000230811BD1E0>, <mip.entities.Var object at 0x00000230811BC850>, <mip.entities.Var object at 0x00000230811BD840>, <mip.entities.Var object at 0x00000230811BD2D0>, <mip.entities.Var object at 0x00000230811BD4B0>, <mip.entities.Var object at 0x00000230811BD510>, <mip.entities.Var object at 0x00000230811BD720>, <mip.entities.Var object at 0x00000230811BCE80>, <mip.entities.Var object at 0x00000230811BC520>, <mip.entities.Var object at 0x00000230811BD3C0>, <mip.entities.Var object at 0x00000230811BD6C0>, <mip.entities.Var object at 0x00000230811BD600>, <mip.entities.Var object at 0x00000230811BD780>, <mip.entities.Var object at 0x00000230811BD7E0>, <mip.entities.Var object at 0x00000230811BD810>, <mip.entities.Var object at 0x00000230811BD870>, <mip.entities.Var object at 0x00000230811BC0D0>, <mip.entities.Var object at 0x00000230811BE080>, <mip.entities.Var object at 0x00000230811BDAE0>, <mip.entities.Var object at 0x00000230811BD690>, <mip.entities.Var object at 0x00000230811BD630>, <mip.entities.Var object at 0x00000230811BD060>, <mip.entities.Var object at 0x00000230811BCC70>, <mip.entities.Var object at 0x00000230811BD5D0>, <mip.entities.Var object at 0x00000230811BC790>, <mip.entities.Var object at 0x00000230811BD0F0>, <mip.entities.Var object at 0x00000230811BD480>, <mip.entities.Var object at 0x00000230811BD660>, <mip.entities.Var object at 0x00000230811BC670>, <mip.entities.Var object at 0x00000230811BD270>, <mip.entities.Var object at 0x00000230811BD000>, <mip.entities.Var object at 0x00000230811BCF70>, <mip.entities.Var object at 0x00000230811BD240>, <mip.entities.Var object at 0x00000230811BCEE0>, <mip.entities.Var object at 0x00000230811BDA80>, <mip.entities.Var object at 0x00000230811BDA50>, <mip.entities.Var object at 0x00000230811BCFA0>, <mip.entities.Var object at 0x00000230811BE830>, <mip.entities.Var object at 0x00000230811BCF10>, <mip.entities.Var object at 0x00000230811BC8E0>, <mip.entities.Var object at 0x00000230811BCE20>, <mip.entities.Var object at 0x00000230811BDC00>, <mip.entities.Var object at 0x00000230811BDBA0>, <mip.entities.Var object at 0x00000230811BD330>, <mip.entities.Var object at 0x00000230811BDE10>, <mip.entities.Var object at 0x00000230811BDC60>, <mip.entities.Var object at 0x00000230811BDDB0>, <mip.entities.Var object at 0x00000230811BDB10>, <mip.entities.Var object at 0x00000230811BDA20>, <mip.entities.Var object at 0x00000230811BDD20>, <mip.entities.Var object at 0x00000230811BD0C0>, <mip.entities.Var object at 0x00000230811BC730>, <mip.entities.Var object at 0x00000230811BDD80>, <mip.entities.Var object at 0x00000230811BD3F0>, <mip.entities.Var object at 0x00000230811BDB40>, <mip.entities.Var object at 0x00000230811BD1B0>, <mip.entities.Var object at 0x ...
# selected items: [11, 34, 42, 46, 69, 80, 85, 115, 119, 121, 142, 145]
# Total Expect Points: 1218.3731500000001
# Total Next Round Points: 523.88275
# Total Team Cost: 1600200
# Number of Wk: 2
# Number of Bat: 7
# Number of Bowl: 9
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0     Ben Dwarshuis  178600        Sydney Sixers     0      0       1  BOWL
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 5   Lockie Ferguson  159000       Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600       Sydney Thunder     1      1       0    WK
# 10         Wes Agar  146800       Sydney Thunder     0      0       1  BOWL
# 3      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 1    Fergus O'Neill  128000  Melbourne Renegades     0      0       1  BOWL
# 6    Marcus Stoinis  121300      Melbourne Stars     0      1       1  ALLR
# 2       Hayden Kerr  113700        Sydney Sixers     0      1       1  ALLR
# 4        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 0        1          1        1   76.90800          40.25350
# 11       1          1        1   76.29850          39.37750
# 5        1          1        0  153.77400          44.69850
# 8        1          1        0  151.62950          46.84800
# 10       1          1        0  158.66900          42.58200
# 3        1          1        1   87.43700          43.21900
# 1        1          1        1  110.91450          57.89000
# 6        1          1        1   67.03450          35.18150
# 2        1          1        1   78.59050          40.11000
# 4        1          1        1   79.17450          41.02600
# 7        1          1        1   92.39000          47.37800
# 9        1          1        1   85.55315          45.31875
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0     Ben Dwarshuis  178600        Sydney Sixers     0      0       1  BOWL
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 3      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 1    Fergus O'Neill  128000  Melbourne Renegades     0      0       1  BOWL
# 6    Marcus Stoinis  121300      Melbourne Stars     0      1       1  ALLR
# 2       Hayden Kerr  113700        Sydney Sixers     0      1       1  ALLR
# 4        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 0        1          1        1   76.90800          40.25350
# 11       1          1        1   76.29850          39.37750
# 3        1          1        1   87.43700          43.21900
# 1        1          1        1  110.91450          57.89000
# 6        1          1        1   67.03450          35.18150
# 2        1          1        1   78.59050          40.11000
# 4        1          1        1   79.17450          41.02600
# 7        1          1        1   92.39000          47.37800
# 9        1          1        1   85.55315          45.31875
#                Name   Price            Team  Wk_f  Bat_f  Bowl_f  Role  \
# 5   Lockie Ferguson  159000  Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600  Sydney Thunder     1      1       0    WK
# 10         Wes Agar  146800  Sydney Thunder     0      0       1  BOWL
#
#     weight  Available  In_Team   exp_pts  next_rnd_exp_pts
# 5        1          1        0  153.7740           44.6985
# 8        1          1        0  151.6295           46.8480
# 10       1          1        0  158.6690           42.5820

# %% [markdown]
# # 5. Extra Scenario - Round 5 (Coffs Rain)

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 5
opt_round = 2

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_5_coff_rain.csv'), low_memory=False)
#price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_', str(current_round), '.csv'), low_memory=False)

# print(price_df) 

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
# print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(py_data_directory,'bbl14_fullteam_model_score_during_rnd_5.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
# print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
# print(game_df)

    # Join on expected points for each game
# print(game_df.columns)
# print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
# print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# print(player_df)

player_df_next_rnd = player_df_raw[player_df_raw.Round == current_round].groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
next_rnd_exp_pts=('exp_pts',"sum"))
player_df_next_rnd = player_df_next_rnd[["Name", "Team", "next_rnd_exp_pts"]]

# %% [markdown]
# # 6. Optimisation Process (Round 5) - Extra Scenario - 2 Trades
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,746,100
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1746100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost_SK = player_df.iloc[selected]
sel_player_df_boost_SK = pd.merge(sel_player_df_boost_SK, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost_SK["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost_SK["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost_SK["Price"]))
print("Number of Wk:", sum(sel_player_df_boost_SK["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost_SK["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost_SK["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost_SK["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost_SK["In_Team"]))

print(sel_player_df_boost_SK.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df_boost_SK.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_5_coff.csv')
# Out:
# [<mip.entities.Var object at 0x000002CD03B3A140>, <mip.entities.Var object at 0x000002CD03B3A080>, <mip.entities.Var object at 0x000002CD03B3A5C0>, <mip.entities.Var object at 0x000002CD03B3A500>, <mip.entities.Var object at 0x000002CD03B3A7D0>, <mip.entities.Var object at 0x000002CD03B3A620>, <mip.entities.Var object at 0x000002CD03B3A830>, <mip.entities.Var object at 0x000002CD03B39FF0>, <mip.entities.Var object at 0x000002CD03B3A8C0>, <mip.entities.Var object at 0x000002CD03B3A4A0>, <mip.entities.Var object at 0x000002CD03B3A530>, <mip.entities.Var object at 0x000002CD03B3A710>, <mip.entities.Var object at 0x000002CD03B3A680>, <mip.entities.Var object at 0x000002CD03B3A950>, <mip.entities.Var object at 0x000002CD03B3A980>, <mip.entities.Var object at 0x000002CD03B3A920>, <mip.entities.Var object at 0x000002CD03B3A4D0>, <mip.entities.Var object at 0x000002CD03B3AA40>, <mip.entities.Var object at 0x000002CD03B3A8F0>, <mip.entities.Var object at 0x000002CD03B3AAA0>, <mip.entities.Var object at 0x000002CD03B3A860>, <mip.entities.Var object at 0x000002CD03B3AA70>, <mip.entities.Var object at 0x000002CD03B3A020>, <mip.entities.Var object at 0x000002CD03B3A890>, <mip.entities.Var object at 0x000002CD03B3AB30>, <mip.entities.Var object at 0x000002CD03B3AB90>, <mip.entities.Var object at 0x000002CD03B3ABF0>, <mip.entities.Var object at 0x000002CD03B3A770>, <mip.entities.Var object at 0x000002CD03B3AC80>, <mip.entities.Var object at 0x000002CD03B3ABC0>, <mip.entities.Var object at 0x000002CD03B3AC50>, <mip.entities.Var object at 0x000002CD03B3AB00>, <mip.entities.Var object at 0x000002CD03B3A800>, <mip.entities.Var object at 0x000002CD03B3ACB0>, <mip.entities.Var object at 0x000002CD03B3AB60>, <mip.entities.Var object at 0x000002CD03B3A9B0>, <mip.entities.Var object at 0x000002CD03B3AAD0>, <mip.entities.Var object at 0x000002CD03B3ACE0>, <mip.entities.Var object at 0x000002CD03B3ADD0>, <mip.entities.Var object at 0x000002CD03B3AD70>, <mip.entities.Var object at 0x000002CD03B3AE60>, <mip.entities.Var object at 0x000002CD03B3AD40>, <mip.entities.Var object at 0x000002CD03B3AE30>, <mip.entities.Var object at 0x000002CD03B3AEC0>, <mip.entities.Var object at 0x000002CD03B3AC20>, <mip.entities.Var object at 0x000002CD03B3AD10>, <mip.entities.Var object at 0x000002CD03B3AF20>, <mip.entities.Var object at 0x000002CD03B3AF80>, <mip.entities.Var object at 0x000002CD03B3AE90>, <mip.entities.Var object at 0x000002CD03B3AF50>, <mip.entities.Var object at 0x000002CD03B3AA10>, <mip.entities.Var object at 0x000002CD03B3AFB0>, <mip.entities.Var object at 0x000002CD03B3AE00>, <mip.entities.Var object at 0x000002CD03B3B0A0>, <mip.entities.Var object at 0x000002CD03B3B040>, <mip.entities.Var object at 0x000002CD03B3B130>, <mip.entities.Var object at 0x000002CD03B3A9E0>, <mip.entities.Var object at 0x000002CD03B3B100>, <mip.entities.Var object at 0x000002CD03B3B010>, <mip.entities.Var object at 0x000002CD03B3B0D0>, <mip.entities.Var object at 0x000002CD03B3B1F0>, <mip.entities.Var object at 0x000002CD03B3B190>, <mip.entities.Var object at 0x000002CD03B3B280>, <mip.entities.Var object at 0x000002CD03B3AEF0>, <mip.entities.Var object at 0x000002CD03B3B250>, <mip.entities.Var object at 0x000002CD03B3B2E0>, <mip.entities.Var object at 0x000002CD03B3B160>, <mip.entities.Var object at 0x000002CD03B3B370>, <mip.entities.Var object at 0x000002CD03B3AFE0>, <mip.entities.Var object at 0x000002CD03B3B340>, <mip.entities.Var object at 0x000002CD03B3B2B0>, <mip.entities.Var object at 0x000002CD03B3B1C0>, <mip.entities.Var object at 0x000002CD03B3B3D0>, <mip.entities.Var object at 0x000002CD03B3B3A0>, <mip.entities.Var object at 0x000002CD03B3B430>, <mip.entities.Var object at 0x000002CD03B3B310>, <mip.entities.Var object at 0x000002CD03B3B490>, <mip.entities.Var object at 0x000002CD03B3B400>, <mip.entities.Var object at 0x000002CD03B3B4F0>, <mip.entities.Var object at 0x000002CD03B3B580>, <mip.entities.Var object at 0x000002CD03B3B460>, <mip.entities.Var object at 0x ...
# selected items: [43, 46, 57, 69, 79, 80, 85, 115, 119, 121, 142, 145]
# Total Expect Points: 1076.6914357142857
# Total Next Round Points: 510.36053571428573
# Total Team Cost: 1668200
# Number of Wk: 2
# Number of Bat: 7
# Number of Bowl: 9
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 2     Jamie Overton  229500    Adelaide Strikers     0      1       1  ALLR
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 5   Lockie Ferguson  159000       Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600       Sydney Thunder     1      1       0    WK
# 10         Wes Agar  146800       Sydney Thunder     0      0       1  BOWL
# 1      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 4        Lloyd Pope  135600    Adelaide Strikers     0      0       1  BOWL
# 0    Henry Thornton  123200    Adelaide Strikers     0      0       1  BOWL
# 6    Marcus Stoinis  121300      Melbourne Stars     0      1       1  ALLR
# 3        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 2        1          1        1   41.713786         41.713786
# 11       1          1        1   76.298500         39.377500
# 5        1          1        0  153.774000         44.698500
# 8        1          1        0  151.629500         46.848000
# 10       1          1        0  158.669000         42.582000
# 1        1          1        1   87.437000         43.219000
# 4        1          1        1   32.412500         32.412500
# 0        1          1        1   50.605000         50.605000
# 6        1          1        1   67.034500         35.181500
# 3        1          1        1   79.174500         41.026000
# 7        1          1        1   92.390000         47.378000
# 9        1          1        1   85.553150         45.318750
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 2     Jamie Overton  229500    Adelaide Strikers     0      1       1  ALLR
# 11  Will Sutherland  174200  Melbourne Renegades     0      1       1  ALLR
# 1      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 4        Lloyd Pope  135600    Adelaide Strikers     0      0       1  BOWL
# 0    Henry Thornton  123200    Adelaide Strikers     0      0       1  BOWL
# 6    Marcus Stoinis  121300      Melbourne Stars     0      1       1  ALLR
# 3        Josh Brown  110900  Melbourne Renegades     0      1       0   BAT
# 7      Peter Siddle   98100      Melbourne Stars     0      0       1  BOWL
# 9        Sam Harper   74300      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 2        1          1        1  41.713786         41.713786
# 11       1          1        1  76.298500         39.377500
# 1        1          1        1  87.437000         43.219000
# 4        1          1        1  32.412500         32.412500
# 0        1          1        1  50.605000         50.605000
# 6        1          1        1  67.034500         35.181500
# 3        1          1        1  79.174500         41.026000
# 7        1          1        1  92.390000         47.378000
# 9        1          1        1  85.553150         45.318750
#                Name   Price            Team  Wk_f  Bat_f  Bowl_f  Role  \
# 5   Lockie Ferguson  159000  Sydney Thunder     0      0       1  BOWL
# 8      Sam Billings  153600  Sydney Thunder     1      1       0    WK
# 10         Wes Agar  146800  Sydney Thunder     0      0       1  BOWL
#
#     weight  Available  In_Team   exp_pts  next_rnd_exp_pts
# 5        1          1        0  153.7740           44.6985
# 8        1          1        0  151.6295           46.8480
# 10       1          1        0  158.6690           42.5820
