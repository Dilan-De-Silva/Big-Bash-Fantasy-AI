# %% [markdown]
# # BBLF AI Selector: Part 2: During Tournament Optimal Squad - Optimser (Round 4)

# %% [markdown]
# # 0. Prerequistes

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 

os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI'
add_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/round_4'
over_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/overall'
py_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets'

# %% [markdown]
# # 1. Data Extraction

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 4
opt_round = 2

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_4.csv'), low_memory=False)
#price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_', str(current_round), '.csv'), low_memory=False)

# print(price_df) 

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
# print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(py_data_directory,'bbl14_fullteam_model_score_during_rnd_4_3g.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
# print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
# print(game_df)

    # Join on expected points for each game
# print(game_df.columns)
# print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
# print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# print(player_df)

player_df_next_rnd = player_df_raw[player_df_raw.Round == current_round].groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
next_rnd_exp_pts=('exp_pts',"sum"))
player_df_next_rnd = player_df_next_rnd[["Name", "Team", "next_rnd_exp_pts"]]

# %% [markdown]
# # 2. Optimisation Process (Round 4) - Normal 3 Trades
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,808,800
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1808800, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]
sel_player_df = pd.merge(sel_player_df, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "Price", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_4.csv')
# Out:
# [<mip.entities.Var object at 0x00000212CD01A020>, <mip.entities.Var object at 0x00000212CD019E70>, <mip.entities.Var object at 0x00000212CD01A4A0>, <mip.entities.Var object at 0x00000212CD01A740>, <mip.entities.Var object at 0x00000212CD01A140>, <mip.entities.Var object at 0x00000212CD01A3E0>, <mip.entities.Var object at 0x00000212CD01A590>, <mip.entities.Var object at 0x00000212CD01A500>, <mip.entities.Var object at 0x00000212CD01A7D0>, <mip.entities.Var object at 0x00000212CD01A800>, <mip.entities.Var object at 0x00000212CD01A7A0>, <mip.entities.Var object at 0x00000212CD01A2F0>, <mip.entities.Var object at 0x00000212CD01A8C0>, <mip.entities.Var object at 0x00000212CD01A770>, <mip.entities.Var object at 0x00000212CD01A920>, <mip.entities.Var object at 0x00000212CD01A6E0>, <mip.entities.Var object at 0x00000212CD01A8F0>, <mip.entities.Var object at 0x00000212CD01A3B0>, <mip.entities.Var object at 0x00000212CD01A5F0>, <mip.entities.Var object at 0x00000212CD01A9B0>, <mip.entities.Var object at 0x00000212CD01AA10>, <mip.entities.Var object at 0x00000212CD01AA70>, <mip.entities.Var object at 0x00000212CD01A320>, <mip.entities.Var object at 0x00000212CD01AB00>, <mip.entities.Var object at 0x00000212CD01AA40>, <mip.entities.Var object at 0x00000212CD01AAD0>, <mip.entities.Var object at 0x00000212CD01A980>, <mip.entities.Var object at 0x00000212CD01A680>, <mip.entities.Var object at 0x00000212CD01A830>, <mip.entities.Var object at 0x00000212CD01A9E0>, <mip.entities.Var object at 0x00000212CD01A710>, <mip.entities.Var object at 0x00000212CD01A950>, <mip.entities.Var object at 0x00000212CD01AB60>, <mip.entities.Var object at 0x00000212CD01AC50>, <mip.entities.Var object at 0x00000212CD01ABF0>, <mip.entities.Var object at 0x00000212CD01ACE0>, <mip.entities.Var object at 0x00000212CD01ABC0>, <mip.entities.Var object at 0x00000212CD01ACB0>, <mip.entities.Var object at 0x00000212CD01AD40>, <mip.entities.Var object at 0x00000212CD01AB30>, <mip.entities.Var object at 0x00000212CD01AB90>, <mip.entities.Var object at 0x00000212CD01ADA0>, <mip.entities.Var object at 0x00000212CD01AE00>, <mip.entities.Var object at 0x00000212CD01AD10>, <mip.entities.Var object at 0x00000212CD01ADD0>, <mip.entities.Var object at 0x00000212CD01A890>, <mip.entities.Var object at 0x00000212CD01AC20>, <mip.entities.Var object at 0x00000212CD01A860>, <mip.entities.Var object at 0x00000212CD01AF20>, <mip.entities.Var object at 0x00000212CD01AEC0>, <mip.entities.Var object at 0x00000212CD01AFB0>, <mip.entities.Var object at 0x00000212CD01AAA0>, <mip.entities.Var object at 0x00000212CD01AF80>, <mip.entities.Var object at 0x00000212CD01AE90>, <mip.entities.Var object at 0x00000212CD01AF50>, <mip.entities.Var object at 0x00000212CD01B070>, <mip.entities.Var object at 0x00000212CD01B010>, <mip.entities.Var object at 0x00000212CD01B100>, <mip.entities.Var object at 0x00000212CD01AE30>, <mip.entities.Var object at 0x00000212CD01B0D0>, <mip.entities.Var object at 0x00000212CD01B160>, <mip.entities.Var object at 0x00000212CD01AD70>, <mip.entities.Var object at 0x00000212CD01B1F0>, <mip.entities.Var object at 0x00000212CD01AEF0>, <mip.entities.Var object at 0x00000212CD01B1C0>, <mip.entities.Var object at 0x00000212CD01AFE0>, <mip.entities.Var object at 0x00000212CD01B0A0>, <mip.entities.Var object at 0x00000212CD01B250>, <mip.entities.Var object at 0x00000212CD01AC80>, <mip.entities.Var object at 0x00000212CD01B2B0>, <mip.entities.Var object at 0x00000212CD01B190>, <mip.entities.Var object at 0x00000212CD01B310>, <mip.entities.Var object at 0x00000212CD01AE60>, <mip.entities.Var object at 0x00000212CD01B370>, <mip.entities.Var object at 0x00000212CD01B400>, <mip.entities.Var object at 0x00000212CD01B2E0>, <mip.entities.Var object at 0x00000212CD01B430>, <mip.entities.Var object at 0x00000212CD01B460>, <mip.entities.Var object at 0x00000212CD01B4C0>, <mip.entities.Var object at 0x00000212CD01B130>, <mip.entities.Var object at 0x00000212CD01B340>, <mip.entities.Var object at 0x ...
# selected items: [34, 42, 43, 46, 57, 69, 79, 85, 93, 121, 135, 145]
# Total Expect Points: 1593.6934349999997
# Total Next Round Points: 969.9474699999998
# Total Team Cost: 1797300
# Number of Wk: 1
# Number of Bat: 9
# Number of Bowl: 10
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 8     Matthew Short  249100    Adelaide Strikers     0      1       1  ALLR
# 4     Jamie Overton  242000    Adelaide Strikers     0      1       1  ALLR
# 11  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 6        Lloyd Pope  155900    Adelaide Strikers     0      0       1  BOWL
# 3      Jack Edwards  153000        Sydney Sixers     0      1       1  ALLR
# 10       Tom Curran  140700      Melbourne Stars     0      1       1  ALLR
# 0    Fergus O'Neill  140500  Melbourne Renegades     0      0       1  BOWL
# 7    Marcus Stoinis  114700      Melbourne Stars     0      1       1  ALLR
# 2    Henry Thornton  114000    Adelaide Strikers     0      0       1  BOWL
# 1       Hayden Kerr  110700        Sydney Sixers     0      1       1  ALLR
# 5        Josh Brown  103000  Melbourne Renegades     0      1       0   BAT
# 9        Sam Harper   82100      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 8        1          1        1  198.732805        131.879265
# 4        1          1        1  170.484190        109.824115
# 11       1          1        0  166.950715        109.840155
# 6        1          1        1  149.645605         96.695095
# 3        1          1        1  112.037550         56.933520
# 10       1          1        1  112.810055         56.047530
# 0        1          1        0  169.482095        111.376565
# 7        1          1        1   82.285735         40.719120
# 2        1          1        1  121.878555         81.630215
# 1        1          1        1   97.305520         49.223010
# 5        1          1        0  131.323055         87.019355
# 9        1          1        1   80.757555         38.759525
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 8    Matthew Short  249100  Adelaide Strikers     0      1       1  ALLR
# 4    Jamie Overton  242000  Adelaide Strikers     0      1       1  ALLR
# 6       Lloyd Pope  155900  Adelaide Strikers     0      0       1  BOWL
# 3     Jack Edwards  153000      Sydney Sixers     0      1       1  ALLR
# 10      Tom Curran  140700    Melbourne Stars     0      1       1  ALLR
# 7   Marcus Stoinis  114700    Melbourne Stars     0      1       1  ALLR
# 2   Henry Thornton  114000  Adelaide Strikers     0      0       1  BOWL
# 1      Hayden Kerr  110700      Sydney Sixers     0      1       1  ALLR
# 9       Sam Harper   82100    Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 8        1          1        1  198.732805        131.879265
# 4        1          1        1  170.484190        109.824115
# 6        1          1        1  149.645605         96.695095
# 3        1          1        1  112.037550         56.933520
# 10       1          1        1  112.810055         56.047530
# 7        1          1        1   82.285735         40.719120
# 2        1          1        1  121.878555         81.630215
# 1        1          1        1   97.305520         49.223010
# 9        1          1        1   80.757555         38.759525
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 11  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 0    Fergus O'Neill  140500  Melbourne Renegades     0      0       1  BOWL
# 5        Josh Brown  103000  Melbourne Renegades     0      1       0   BAT
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 11       1          1        0  166.950715        109.840155
# 0        1          1        0  169.482095        111.376565
# 5        1          1        0  131.323055         87.019355

# %% [markdown]
# # 3. Optimisation Process (Round 4) - Normal 3 Trades + Boost
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,808,800
# 6. Atleast 8 players in current team (4 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 8, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1808800, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost = player_df.iloc[selected]
sel_player_df_boost = pd.merge(sel_player_df_boost, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost["Price"]))
print("Number of Wk:", sum(sel_player_df_boost["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost["In_Team"]))

print(sel_player_df_boost.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost[sel_player_df_boost['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost[sel_player_df_boost['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df_boost.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_4_boost.csv')
# Out:
# [<mip.entities.Var object at 0x000002129CAB3490>, <mip.entities.Var object at 0x000002129CAB37C0>, <mip.entities.Var object at 0x00000212CD036A10>, <mip.entities.Var object at 0x00000212CD035BD0>, <mip.entities.Var object at 0x00000212CD036A70>, <mip.entities.Var object at 0x00000212CD0367D0>, <mip.entities.Var object at 0x00000212CD036830>, <mip.entities.Var object at 0x00000212CD0367A0>, <mip.entities.Var object at 0x00000212CD036710>, <mip.entities.Var object at 0x00000212CD036380>, <mip.entities.Var object at 0x00000212CD035C60>, <mip.entities.Var object at 0x00000212CD0353C0>, <mip.entities.Var object at 0x00000212CD0368F0>, <mip.entities.Var object at 0x00000212CD036890>, <mip.entities.Var object at 0x00000212CD035F90>, <mip.entities.Var object at 0x00000212CD036560>, <mip.entities.Var object at 0x00000212CD036680>, <mip.entities.Var object at 0x00000212CD036410>, <mip.entities.Var object at 0x00000212CD036230>, <mip.entities.Var object at 0x00000212CD036470>, <mip.entities.Var object at 0x00000212CD0353F0>, <mip.entities.Var object at 0x00000212CD036AA0>, <mip.entities.Var object at 0x00000212CD036170>, <mip.entities.Var object at 0x00000212CD036080>, <mip.entities.Var object at 0x00000212CD0361A0>, <mip.entities.Var object at 0x00000212CD0361D0>, <mip.entities.Var object at 0x00000212CD036290>, <mip.entities.Var object at 0x00000212CD036800>, <mip.entities.Var object at 0x00000212CD036770>, <mip.entities.Var object at 0x00000212CD035DE0>, <mip.entities.Var object at 0x00000212CD036DA0>, <mip.entities.Var object at 0x00000212CD035FC0>, <mip.entities.Var object at 0x00000212CD036E90>, <mip.entities.Var object at 0x00000212CD037010>, <mip.entities.Var object at 0x00000212CD036020>, <mip.entities.Var object at 0x00000212CD036E00>, <mip.entities.Var object at 0x00000212CD036EC0>, <mip.entities.Var object at 0x00000212CD036F80>, <mip.entities.Var object at 0x00000212CD036F20>, <mip.entities.Var object at 0x00000212CD036F50>, <mip.entities.Var object at 0x00000212CD0377C0>, <mip.entities.Var object at 0x00000212CD037190>, <mip.entities.Var object at 0x00000212CD034E20>, <mip.entities.Var object at 0x00000212CD035540>, <mip.entities.Var object at 0x00000212CD037790>, <mip.entities.Var object at 0x00000212CD036C50>, <mip.entities.Var object at 0x00000212CD036CE0>, <mip.entities.Var object at 0x00000212CD035E70>, <mip.entities.Var object at 0x00000212CD036D10>, <mip.entities.Var object at 0x00000212CD037220>, <mip.entities.Var object at 0x00000212CD037250>, <mip.entities.Var object at 0x00000212CD036B30>, <mip.entities.Var object at 0x00000212CD0370D0>, <mip.entities.Var object at 0x00000212CD037160>, <mip.entities.Var object at 0x00000212CD0372E0>, <mip.entities.Var object at 0x00000212CD037280>, <mip.entities.Var object at 0x00000212CD0371C0>, <mip.entities.Var object at 0x00000212CD0372B0>, <mip.entities.Var object at 0x00000212CD037520>, <mip.entities.Var object at 0x00000212CD035660>, <mip.entities.Var object at 0x00000212CD0373D0>, <mip.entities.Var object at 0x00000212CD037310>, <mip.entities.Var object at 0x00000212CD036260>, <mip.entities.Var object at 0x00000212CD037700>, <mip.entities.Var object at 0x00000212CD0377F0>, <mip.entities.Var object at 0x00000212CD037850>, <mip.entities.Var object at 0x00000212CD036FE0>, <mip.entities.Var object at 0x00000212CD036CB0>, <mip.entities.Var object at 0x00000212CD037100>, <mip.entities.Var object at 0x00000212CD0371F0>, <mip.entities.Var object at 0x00000212CD036FB0>, <mip.entities.Var object at 0x00000212CD037130>, <mip.entities.Var object at 0x00000212CD036620>, <mip.entities.Var object at 0x00000212CD036050>, <mip.entities.Var object at 0x00000212CD0363E0>, <mip.entities.Var object at 0x00000212CD035F30>, <mip.entities.Var object at 0x00000212CD035F60>, <mip.entities.Var object at 0x00000212CD036140>, <mip.entities.Var object at 0x00000212CD0355A0>, <mip.entities.Var object at 0x00000212CD037040>, <mip.entities.Var object at 0x00000212CD035480>, <mip.entities.Var object at 0x ...
# selected items: [2, 34, 42, 43, 46, 57, 79, 93, 121, 135, 137, 145]
# Total Expect Points: 1654.7191349999998
# Total Next Round Points: 1022.9664699999998
# Total Team Cost: 1804300
# Number of Wk: 1
# Number of Bat: 7
# Number of Bowl: 11
# Available Players: 12
# Current Players Remaining: 8
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 7     Matthew Short  249100    Adelaide Strikers     0      1       1  ALLR
# 5     Jamie Overton  242000    Adelaide Strikers     0      1       1  ALLR
# 11  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 6        Lloyd Pope  155900    Adelaide Strikers     0      0       1  BOWL
# 4      Jack Edwards  153000        Sydney Sixers     0      1       1  ALLR
# 10       Tom Rogers  150900  Melbourne Renegades     0      0       1  BOWL
# 9        Tom Curran  140700      Melbourne Stars     0      1       1  ALLR
# 1    Fergus O'Neill  140500  Melbourne Renegades     0      0       1  BOWL
# 3    Henry Thornton  114000    Adelaide Strikers     0      0       1  BOWL
# 2       Hayden Kerr  110700        Sydney Sixers     0      1       1  ALLR
# 8        Sam Harper   82100      Melbourne Stars     1      1       0    WK
# 0        Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 7        1          1        1  198.732805        131.879265
# 5        1          1        1  170.484190        109.824115
# 11       1          1        0  166.950715        109.840155
# 6        1          1        1  149.645605         96.695095
# 4        1          1        1  112.037550         56.933520
# 10       1          1        0  158.871310        103.518720
# 9        1          1        1  112.810055         56.047530
# 1        1          1        0  169.482095        111.376565
# 3        1          1        1  121.878555         81.630215
# 2        1          1        1   97.305520         49.223010
# 8        1          1        1   80.757555         38.759525
# 0        1          1        0  115.763180         77.238755
#              Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 7   Matthew Short  249100  Adelaide Strikers     0      1       1  ALLR
# 5   Jamie Overton  242000  Adelaide Strikers     0      1       1  ALLR
# 6      Lloyd Pope  155900  Adelaide Strikers     0      0       1  BOWL
# 4    Jack Edwards  153000      Sydney Sixers     0      1       1  ALLR
# 9      Tom Curran  140700    Melbourne Stars     0      1       1  ALLR
# 3  Henry Thornton  114000  Adelaide Strikers     0      0       1  BOWL
# 2     Hayden Kerr  110700      Sydney Sixers     0      1       1  ALLR
# 8      Sam Harper   82100    Melbourne Stars     1      1       0    WK
#
#    weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 7       1          1        1  198.732805        131.879265
# 5       1          1        1  170.484190        109.824115
# 6       1          1        1  149.645605         96.695095
# 4       1          1        1  112.037550         56.933520
# 9       1          1        1  112.810055         56.047530
# 3       1          1        1  121.878555         81.630215
# 2       1          1        1   97.305520         49.223010
# 8       1          1        1   80.757555         38.759525
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 11  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 10       Tom Rogers  150900  Melbourne Renegades     0      0       1  BOWL
# 1    Fergus O'Neill  140500  Melbourne Renegades     0      0       1  BOWL
# 0        Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 11       1          1        0  166.950715        109.840155
# 10       1          1        0  158.871310        103.518720
# 1        1          1        0  169.482095        111.376565
# 0        1          1        0  115.763180         77.238755

# %% [markdown]
# # 4. Optimisation Process (Round 3) - Normal 3 Trades + Sam Konstas (Boost)
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,808,800 + $36,100
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1844900, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost_SK = player_df.iloc[selected]
sel_player_df_boost_SK = pd.merge(sel_player_df_boost_SK, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost_SK["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost_SK["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost_SK["Price"]))
print("Number of Wk:", sum(sel_player_df_boost_SK["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost_SK["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost_SK["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost_SK["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost_SK["In_Team"]))

print(sel_player_df_boost_SK.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 0].sort_values(by = "Price", ascending = False))


sel_player_df_boost_SK.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_4_boost_SK.csv')
# Out:
# [<mip.entities.Var object at 0x00000212CD09C460>, <mip.entities.Var object at 0x00000212CD09C610>, <mip.entities.Var object at 0x00000212CD09C9A0>, <mip.entities.Var object at 0x00000212CD09C5B0>, <mip.entities.Var object at 0x00000212CD09C520>, <mip.entities.Var object at 0x00000212CD09DA80>, <mip.entities.Var object at 0x00000212CD09DF60>, <mip.entities.Var object at 0x00000212CD09D690>, <mip.entities.Var object at 0x00000212CD09C310>, <mip.entities.Var object at 0x00000212CD09D2A0>, <mip.entities.Var object at 0x00000212CD09DB70>, <mip.entities.Var object at 0x00000212CD09D7B0>, <mip.entities.Var object at 0x00000212CD09DF00>, <mip.entities.Var object at 0x00000212CD09D180>, <mip.entities.Var object at 0x00000212CD09D510>, <mip.entities.Var object at 0x00000212CD09D210>, <mip.entities.Var object at 0x00000212CD09C730>, <mip.entities.Var object at 0x00000212CD09D570>, <mip.entities.Var object at 0x00000212CD09D450>, <mip.entities.Var object at 0x00000212CD09D270>, <mip.entities.Var object at 0x00000212CD09CA90>, <mip.entities.Var object at 0x00000212CD09D2D0>, <mip.entities.Var object at 0x00000212CD09CEB0>, <mip.entities.Var object at 0x00000212CD09D660>, <mip.entities.Var object at 0x00000212CD09D480>, <mip.entities.Var object at 0x00000212CD09D5A0>, <mip.entities.Var object at 0x00000212CD09D3F0>, <mip.entities.Var object at 0x00000212CD09CE50>, <mip.entities.Var object at 0x00000212CD09D6F0>, <mip.entities.Var object at 0x00000212CD09D4E0>, <mip.entities.Var object at 0x00000212CD09D060>, <mip.entities.Var object at 0x00000212CD09D7E0>, <mip.entities.Var object at 0x00000212CD09D6C0>, <mip.entities.Var object at 0x00000212CD09D5D0>, <mip.entities.Var object at 0x00000212CD09CC40>, <mip.entities.Var object at 0x00000212CD09D780>, <mip.entities.Var object at 0x00000212CD09C340>, <mip.entities.Var object at 0x00000212CD09D330>, <mip.entities.Var object at 0x00000212CD09C2E0>, <mip.entities.Var object at 0x00000212CD09C220>, <mip.entities.Var object at 0x00000212CD09D4B0>, <mip.entities.Var object at 0x00000212CD09D3C0>, <mip.entities.Var object at 0x00000212CD09CEE0>, <mip.entities.Var object at 0x00000212CD09D300>, <mip.entities.Var object at 0x00000212CD09D360>, <mip.entities.Var object at 0x00000212CD09D600>, <mip.entities.Var object at 0x00000212CD09CF10>, <mip.entities.Var object at 0x00000212CD09D960>, <mip.entities.Var object at 0x00000212CD09C580>, <mip.entities.Var object at 0x00000212CD09D090>, <mip.entities.Var object at 0x00000212CD09D240>, <mip.entities.Var object at 0x00000212CD09C850>, <mip.entities.Var object at 0x00000212CD09D0C0>, <mip.entities.Var object at 0x00000212CD09D0F0>, <mip.entities.Var object at 0x00000212CD09DF90>, <mip.entities.Var object at 0x00000212CD09C400>, <mip.entities.Var object at 0x00000212CD09C880>, <mip.entities.Var object at 0x00000212CD09DED0>, <mip.entities.Var object at 0x00000212CD09C640>, <mip.entities.Var object at 0x00000212CD09DD50>, <mip.entities.Var object at 0x00000212CD09D900>, <mip.entities.Var object at 0x00000212CD09D150>, <mip.entities.Var object at 0x00000212CD09CB20>, <mip.entities.Var object at 0x00000212CD09E1A0>, <mip.entities.Var object at 0x00000212CD09DBA0>, <mip.entities.Var object at 0x00000212CD09D930>, <mip.entities.Var object at 0x00000212CD09DD80>, <mip.entities.Var object at 0x00000212CD09D540>, <mip.entities.Var object at 0x00000212CD09D870>, <mip.entities.Var object at 0x00000212CD09C760>, <mip.entities.Var object at 0x00000212CD09E0E0>, <mip.entities.Var object at 0x00000212CD09D810>, <mip.entities.Var object at 0x00000212CD09DB10>, <mip.entities.Var object at 0x00000212CD09D750>, <mip.entities.Var object at 0x00000212CD09DCF0>, <mip.entities.Var object at 0x00000212CD09C700>, <mip.entities.Var object at 0x00000212CD09D840>, <mip.entities.Var object at 0x00000212CD09E200>, <mip.entities.Var object at 0x00000212CD09DE70>, <mip.entities.Var object at 0x00000212CD09DB40>, <mip.entities.Var object at 0x00000212CD09CD30>, <mip.entities.Var object at 0x ...
# selected items: [34, 42, 43, 46, 57, 79, 93, 115, 121, 135, 137, 145]
# Total Expect Points: 1615.2831049999998
# Total Next Round Points: 983.1917999999998
# Total Team Cost: 1829800
# Number of Wk: 1
# Number of Bat: 7
# Number of Bowl: 11
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 6     Matthew Short  249100    Adelaide Strikers     0      1       1  ALLR
# 4     Jamie Overton  242000    Adelaide Strikers     0      1       1  ALLR
# 11  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 5        Lloyd Pope  155900    Adelaide Strikers     0      0       1  BOWL
# 3      Jack Edwards  153000        Sydney Sixers     0      1       1  ALLR
# 10       Tom Rogers  150900  Melbourne Renegades     0      0       1  BOWL
# 9        Tom Curran  140700      Melbourne Stars     0      1       1  ALLR
# 0    Fergus O'Neill  140500  Melbourne Renegades     0      0       1  BOWL
# 2    Henry Thornton  114000    Adelaide Strikers     0      0       1  BOWL
# 1       Hayden Kerr  110700        Sydney Sixers     0      1       1  ALLR
# 7      Peter Siddle   99300      Melbourne Stars     0      0       1  BOWL
# 8        Sam Harper   82100      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 6        1          1        1  198.732805        131.879265
# 4        1          1        1  170.484190        109.824115
# 11       1          1        0  166.950715        109.840155
# 5        1          1        1  149.645605         96.695095
# 3        1          1        1  112.037550         56.933520
# 10       1          1        0  158.871310        103.518720
# 9        1          1        1  112.810055         56.047530
# 0        1          1        0  169.482095        111.376565
# 2        1          1        1  121.878555         81.630215
# 1        1          1        1   97.305520         49.223010
# 7        1          1        1   76.327150         37.464085
# 8        1          1        1   80.757555         38.759525
#              Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 6   Matthew Short  249100  Adelaide Strikers     0      1       1  ALLR
# 4   Jamie Overton  242000  Adelaide Strikers     0      1       1  ALLR
# 5      Lloyd Pope  155900  Adelaide Strikers     0      0       1  BOWL
# 3    Jack Edwards  153000      Sydney Sixers     0      1       1  ALLR
# 9      Tom Curran  140700    Melbourne Stars     0      1       1  ALLR
# 2  Henry Thornton  114000  Adelaide Strikers     0      0       1  BOWL
# 1     Hayden Kerr  110700      Sydney Sixers     0      1       1  ALLR
# 7    Peter Siddle   99300    Melbourne Stars     0      0       1  BOWL
# 8      Sam Harper   82100    Melbourne Stars     1      1       0    WK
#
#    weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 6       1          1        1  198.732805        131.879265
# 4       1          1        1  170.484190        109.824115
# 5       1          1        1  149.645605         96.695095
# 3       1          1        1  112.037550         56.933520
# 9       1          1        1  112.810055         56.047530
# 2       1          1        1  121.878555         81.630215
# 1       1          1        1   97.305520         49.223010
# 7       1          1        1   76.327150         37.464085
# 8       1          1        1   80.757555         38.759525
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 11  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 10       Tom Rogers  150900  Melbourne Renegades     0      0       1  BOWL
# 0    Fergus O'Neill  140500  Melbourne Renegades     0      0       1  BOWL
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 11       1          1        0  166.950715        109.840155
# 10       1          1        0  158.871310        103.518720
# 0        1          1        0  169.482095        111.376565
