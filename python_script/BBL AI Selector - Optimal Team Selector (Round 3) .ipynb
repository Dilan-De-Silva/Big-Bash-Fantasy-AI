# %% [markdown]
# # BBLF AI Selector: Part 2: During Tournament Optimal Squad - Optimser (Round 3)

# %% [markdown]
# # 0. Prerequistes

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 

os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI'
add_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/round_3'
over_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/overall'
py_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets'

# %% [markdown]
# # 1. Data Extraction

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 3
opt_round = 3

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_3.csv'), low_memory=False)
#price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_', str(current_round), '.csv'), low_memory=False)

print(price_df) 

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(py_data_directory,'bbl14_fullteam_model_score_during_rnd_3.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
print(game_df)

    # Join on expected points for each game
print(game_df.columns)
print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "opp", "venue", "Home_f","Round"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
print(player_df)

player_df_next_rnd = player_df_raw[player_df_raw.Round == current_round].groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
next_rnd_exp_pts=('exp_pts',"sum"))
player_df_next_rnd = player_df_next_rnd[["Name", "Team", "next_rnd_exp_pts"]]
# Out:
#       Last_Name First_Name First_Name_Short        Full_Name         player  \
# 0        Abbott       Sean               SA      Sean Abbott      SA Abbott
# 1          Agar     Ashton               AC      Ashton Agar        AC Agar
# 2          Agar        Wes               WA         Wes Agar        WA Agar
# 3         Allen     Fabian              NaN     Fabian Allen   Fabian Allen
# 4         Allen       Finn              NaN       Finn Allen     Finn Allen
# ..          ...        ...              ...              ...            ...
# 142       Wells        Jon               JW        Jon Wells       JW Wells
# 143  Wildermuth       Jack               JD  Jack Wildermuth  JD Wildermuth
# 144        Wood       Jack               JP        Jack Wood        JP Wood
# 145      Wright        Mac                M       Mac Wright       M Wright
# 146       Zampa       Adam                A       Adam Zampa        A Zampa
#
#       Price                 Team  Role  Available  In_Team
# 0    138000        Sydney Sixers  BOWL          0        0
# 1    122500      Perth Scorchers  BOWL          1        0
# 2     99700       Sydney Thunder  BOWL          0        0
# 3    115700    Adelaide Strikers  ALLR          0        0
# 4    107900      Perth Scorchers   BAT          1        0
# ..      ...                  ...   ...        ...      ...
# 142   78100  Melbourne Renegades   BAT          1        0
# 143   58500        Brisbane Heat  ALLR          0        0
# 144   63900        Brisbane Heat  ALLR          0        0
# 145  126300    Hobart Hurricanes   BAT          0        0
# 146   73800  Melbourne Renegades  BOWL          1        0
#
# [147 rows x 10 columns]
#                    Team           Opposition                     Venue  \
# 3     Adelaide Strikers    Hobart Hurricanes             Adelaide Oval
# 4     Adelaide Strikers      Perth Scorchers             Adelaide Oval
# 5     Adelaide Strikers  Melbourne Renegades                    Marvel
# 6     Adelaide Strikers    Hobart Hurricanes                    Hobart
# 13      Melbourne Stars        Sydney Sixers                       SCG
# 14      Melbourne Stars       Sydney Thunder                     Other
# 15      Melbourne Stars        Brisbane Heat                     GABBA
# 16      Melbourne Stars  Melbourne Renegades  Melbourne Cricket Ground
# 22        Sydney Sixers      Melbourne Stars                       SCG
# 23        Sydney Sixers        Brisbane Heat                     GABBA
# 24        Sydney Sixers    Hobart Hurricanes                    Hobart
# 25        Sydney Sixers        Brisbane Heat                     Other
# 32        Brisbane Heat        Sydney Sixers             Perth Stadium
# 33        Brisbane Heat      Perth Scorchers                     GABBA
# 34        Brisbane Heat      Melbourne Stars                     GABBA
# 35        Brisbane Heat        Sydney Sixers                     Other
# 43      Perth Scorchers        Brisbane Heat             Perth Stadium
# 44      Perth Scorchers    Adelaide Strikers             Adelaide Oval
# 45      Perth Scorchers       Sydney Thunder             Perth Stadium
# 52       Sydney Thunder      Melbourne Stars                     Other
# 53       Sydney Thunder  Melbourne Renegades         Sydney Showground
# 54       Sydney Thunder      Perth Scorchers             Perth Stadium
# 62    Hobart Hurricanes    Adelaide Strikers             Adelaide Oval
# 63    Hobart Hurricanes        Sydney Sixers                    Hobart
# 64    Hobart Hurricanes    Adelaide Strikers                    Hobart
# 73  Melbourne Renegades       Sydney Thunder         Sydney Showground
# 74  Melbourne Renegades    Adelaide Strikers                    Marvel
# 75  Melbourne Renegades      Melbourne Stars  Melbourne Cricket Ground
#
#     Home_f  Round
# 3        1      3
# 4        1      4
# 5        0      4
# 6        0      5
# 13       0      3
# 14       0      3
# 15       0      4
# 16       1      5
# 22       1      3
# 23       0      3
# 24       0      4
# 25       0      5
# 32       0      3
# 33       1      3
# 34       1      4
# 35       0      5
# 43       1      3
# 44       0      4
# 45       1      5
# 52       0      3
# 53       1      4
# 54       0      5
# 62       0      3
# 63       1      4
# 64       1      5
# 73       0      4
# 74       1      4
# 75       0      5
#              Name                 Team                  opp  \
# 0     Sean Abbott        Sydney Sixers  Melbourne Renegades
# 1     Sean Abbott        Sydney Sixers       Sydney Thunder
# 2     Sean Abbott        Sydney Sixers      Melbourne Stars
# 3     Sean Abbott        Sydney Sixers        Brisbane Heat
# 4     Sean Abbott        Sydney Sixers    Hobart Hurricanes
# ...           ...                  ...                  ...
# 1465   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1466   Adam Zampa  Melbourne Renegades      Perth Scorchers
# 1467   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1468   Adam Zampa  Melbourne Renegades    Hobart Hurricanes
# 1469   Adam Zampa  Melbourne Renegades        Brisbane Heat
#
#                          venue  Home_f  Round    Full_Name  season_fp_lag1  \
# 0                          SCG       1      1  Sean Abbott           448.0
# 1            Sydney Showground       0      2  Sean Abbott           448.0
# 2                          SCG       1      3  Sean Abbott           448.0
# 3                        GABBA       0      3  Sean Abbott           448.0
# 4                       Hobart       0      4  Sean Abbott           448.0
# ...                        ...     ...    ...          ...             ...
# 1465  Melbourne Cricket Ground       0      5   Adam Zampa           235.0
# 1466             Perth Stadium       0      6   Adam Zampa           235.0
# 1467                    Marvel       1      7   Adam Zampa           235.0
# 1468                    Hobart       0      8   Adam Zampa           235.0
# 1469                    Marvel       1      9   Adam Zampa           235.0
#
#       avg_season_fp_lag1  max_season_fp_lag1  ...  avg_season_fp_lag3  \
# 0              49.777778               139.0  ...           63.692308
# 1              49.777778               139.0  ...           63.692308
# 2              49.777778               139.0  ...           63.692308
# 3              49.777778               139.0  ...           63.692308
# 4              49.777778               139.0  ...           63.692308
# ...                  ...                 ...  ...                 ...
# 1465           29.375000                62.0  ...           38.500000
# 1466           29.375000                62.0  ...           38.500000
# 1467           29.375000                62.0  ...           38.500000
# 1468           29.375000                62.0  ...           38.500000
# 1469           29.375000                62.0  ...           38.500000
#
#       max_season_fp_lag3  min_season_fp_lag3  med_season_fp_lag3  \
# 0                  157.0                 7.0                48.0
# 1                  157.0                 7.0                48.0
# 2                  157.0                 7.0                48.0
# 3                  157.0                 7.0                48.0
# 4                  157.0                 7.0                48.0
# ...                  ...                 ...                 ...
# 1465                70.0                 5.0                36.5
# 1466                70.0                 5.0                36.5
# 1467                70.0                 5.0                36.5
# 1468                70.0                 5.0                36.5
# 1469                70.0                 5.0                36.5
#
#       sd_season_fp_lag3  match_cnt_lag3  season  rank  rank_group    exp_pts
# 0             54.608279            13.0      14     4      Middle  47.030620
# 1             54.608279            13.0      14     5      Middle  46.475145
# 2             54.608279            13.0      14     8         Low  47.811215
# 3             54.608279            13.0      14     3      Middle  46.635580
# 4             54.608279            13.0      14     7         Low  47.904145
# ...                 ...             ...     ...   ...         ...        ...
# 1465          26.154456            10.0      14     8         Low  37.674315
# 1466          26.154456            10.0      14     2        High  29.598070
# 1467          26.154456            10.0      14     8         Low  37.299865
# 1468          26.154456            10.0      14     7         Low  38.016385
# 1469          26.154456            10.0      14     3      Middle  30.854300
#
# [1470 rows x 32 columns]
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  122500      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 510   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 511   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 512   Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
# 513   Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
# 514   Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
#
#      Available  In_Team         Opposition                     Venue  Home_f  \
# 0            0        0    Melbourne Stars                       SCG       1
# 1            0        0      Brisbane Heat                     GABBA       0
# 2            0        0  Hobart Hurricanes                    Hobart       0
# 3            0        0      Brisbane Heat                     Other       0
# 4            1        0      Brisbane Heat             Perth Stadium       1
# ..         ...      ...                ...                       ...     ...
# 510          0        0      Sydney Sixers                    Hobart       1
# 511          0        0  Adelaide Strikers                    Hobart       1
# 512          1        0     Sydney Thunder         Sydney Showground       0
# 513          1        0  Adelaide Strikers                    Marvel       1
# 514          1        0    Melbourne Stars  Melbourne Cricket Ground       0
#
#      Round
# 0        3
# 1        3
# 2        4
# 3        5
# 4        3
# ..     ...
# 510      4
# 511      5
# 512      4
# 513      4
# 514      5
#
# [515 rows x 13 columns]
# Index(['Name', 'Price', 'Team', 'Wk_f', 'Bat_f', 'Bowl_f', 'Role', 'Available',
#        'In_Team', 'Opposition', 'Venue', 'Home_f', 'Round'],
#       dtype='object')
# Index(['Name', 'Team', 'opp', 'venue', 'Home_f', 'Round', 'Full_Name',
#        'season_fp_lag1', 'avg_season_fp_lag1', 'max_season_fp_lag1',
#        'min_season_fp_lag1', 'med_season_fp_lag1', 'sd_season_fp_lag1',
#        'match_cnt_lag1', 'season_fp_lag2', 'avg_season_fp_lag2',
#        'max_season_fp_lag2', 'min_season_fp_lag2', 'med_season_fp_lag2',
#        'sd_season_fp_lag2', 'match_cnt_lag2', 'season_fp_lag3',
#        'avg_season_fp_lag3', 'max_season_fp_lag3', 'min_season_fp_lag3',
#        'med_season_fp_lag3', 'sd_season_fp_lag3', 'match_cnt_lag3', 'season',
#        'rank', 'rank_group', 'exp_pts'],
#       dtype='object')
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  138000        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  122500      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 510   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 511   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 512   Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
# 513   Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
# 514   Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
#
#      Available  In_Team         Opposition  ... max_season_fp_lag3  \
# 0            0        0    Melbourne Stars  ...              157.0
# 1            0        0      Brisbane Heat  ...              157.0
# 2            0        0  Hobart Hurricanes  ...              157.0
# 3            0        0      Brisbane Heat  ...              157.0
# 4            1        0      Brisbane Heat  ...              107.0
# ..         ...      ...                ...  ...                ...
# 510          0        0      Sydney Sixers  ...                6.0
# 511          0        0  Adelaide Strikers  ...                6.0
# 512          1        0     Sydney Thunder  ...               70.0
# 513          1        0  Adelaide Strikers  ...               70.0
# 514          1        0    Melbourne Stars  ...               70.0
#
#      min_season_fp_lag3  med_season_fp_lag3 sd_season_fp_lag3 match_cnt_lag3  \
# 0                   7.0                48.0         54.608279           13.0
# 1                   7.0                48.0         54.608279           13.0
# 2                   7.0                48.0         54.608279           13.0
# 3                   7.0                48.0         54.608279           13.0
# 4                  10.0                57.0         26.326702           15.0
# ..                  ...                 ...               ...            ...
# 510                 6.0                 6.0               NaN            1.0
# 511                 6.0                 6.0               NaN            1.0
# 512                 5.0                36.5         26.154456           10.0
# 513                 5.0                36.5         26.154456           10.0
# 514                 5.0                36.5         26.154456           10.0
#
#     season  rank  rank_group    exp_pts  weight
# 0       14     8         Low  52.341215       1
# 1       14     3      Middle  51.165580       1
# 2       14     7         Low  52.434145       1
# 3       14     3      Middle  51.165580       1
# 4       14     3      Middle  43.531275       1
# ..     ...   ...         ...        ...     ...
# 510     14     1        High  29.975040       1
# 511     14     6         Low  34.954630       1
# 512     14     5      Middle  37.061735       1
# 513     14     6         Low  41.167835       1
# 514     14     8         Low  42.204315       1
#
# [515 rows x 42 columns]
#                 Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0       Aaron Hardie  177800      Perth Scorchers     0      1       1  ALLR
# 1         Adam Milne  102600      Melbourne Stars     0      0       1  BOWL
# 2         Adam Zampa   73800  Melbourne Renegades     0      0       1  BOWL
# 3       Akeal Hosein  195900        Sydney Sixers     0      0       1  BOWL
# 4         Alex Carey  167500    Adelaide Strikers     1      1       0    WK
# ..               ...     ...                  ...   ...    ...     ...   ...
# 142  Will Prestwidge   60900        Brisbane Heat     0      0       1  BOWL
# 143    Will Salzmann   39500       Sydney Thunder     0      1       1  ALLR
# 144  Will Sutherland  191600  Melbourne Renegades     0      1       1  ALLR
# 145  Xavier Bartlett  207000        Brisbane Heat     0      0       1  BOWL
# 146     Xavier Crone   39500  Melbourne Renegades     0      0       1  BOWL
#
#      weight  Available  In_Team     exp_pts
# 0         1          1        0  118.321710
# 1         1          0        0  197.786715
# 2         1          1        0  120.433885
# 3         1          1        0  202.132600
# 4         1          0        0  164.708065
# ..      ...        ...      ...         ...
# 142       1          1        0  146.538360
# 143       1          0        0   83.164307
# 144       1          1        0  150.300430
# 145       1          1        0  170.151670
# 146       1          0        0   84.136317
#
# [147 rows x 11 columns]

# %% [markdown]
# # 2. Optimisation Process (Round 3) - Normal 3 Trades
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,762,800
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1767100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]
sel_player_df = pd.merge(sel_player_df, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 1])
print(sel_player_df[sel_player_df['In_Team'] == 0])


sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_3.csv')
# Out:
# [<mip.entities.Var object at 0x00000258C378F0A0>, <mip.entities.Var object at 0x00000258C378E530>, <mip.entities.Var object at 0x00000258C378E4D0>, <mip.entities.Var object at 0x00000258C378E350>, <mip.entities.Var object at 0x00000258C378F550>, <mip.entities.Var object at 0x00000258C378D510>, <mip.entities.Var object at 0x00000258C378E110>, <mip.entities.Var object at 0x00000258C378D930>, <mip.entities.Var object at 0x00000258C378F5B0>, <mip.entities.Var object at 0x00000258C378E770>, <mip.entities.Var object at 0x00000258C378E890>, <mip.entities.Var object at 0x00000258C378EB00>, <mip.entities.Var object at 0x00000258C378DEA0>, <mip.entities.Var object at 0x00000258C378E5F0>, <mip.entities.Var object at 0x00000258C378E7D0>, <mip.entities.Var object at 0x00000258C378F430>, <mip.entities.Var object at 0x00000258C378E950>, <mip.entities.Var object at 0x00000258C378E320>, <mip.entities.Var object at 0x00000258C378EEC0>, <mip.entities.Var object at 0x00000258C378EBC0>, <mip.entities.Var object at 0x00000258C378EE60>, <mip.entities.Var object at 0x00000258C378F610>, <mip.entities.Var object at 0x00000258C378E680>, <mip.entities.Var object at 0x00000258C378E740>, <mip.entities.Var object at 0x00000258C378E470>, <mip.entities.Var object at 0x00000258C378EC50>, <mip.entities.Var object at 0x00000258C378EB90>, <mip.entities.Var object at 0x00000258C378EDD0>, <mip.entities.Var object at 0x00000258C378E9E0>, <mip.entities.Var object at 0x00000258C378E650>, <mip.entities.Var object at 0x00000258C378D030>, <mip.entities.Var object at 0x00000258C378E1D0>, <mip.entities.Var object at 0x00000258C378EA10>, <mip.entities.Var object at 0x00000258C378EBF0>, <mip.entities.Var object at 0x00000258C378F220>, <mip.entities.Var object at 0x00000258C378E830>, <mip.entities.Var object at 0x00000258C378EB60>, <mip.entities.Var object at 0x00000258C378EC20>, <mip.entities.Var object at 0x00000258C378F070>, <mip.entities.Var object at 0x00000258C378F190>, <mip.entities.Var object at 0x00000258C378EC80>, <mip.entities.Var object at 0x00000258C378E710>, <mip.entities.Var object at 0x00000258C378ECE0>, <mip.entities.Var object at 0x00000258C378CFD0>, <mip.entities.Var object at 0x00000258C378E800>, <mip.entities.Var object at 0x00000258C378E170>, <mip.entities.Var object at 0x00000258C378F7C0>, <mip.entities.Var object at 0x00000258C378E620>, <mip.entities.Var object at 0x00000258C378F3A0>, <mip.entities.Var object at 0x00000258C378D330>, <mip.entities.Var object at 0x00000258C378E860>, <mip.entities.Var object at 0x00000258C378DED0>, <mip.entities.Var object at 0x00000258C378E8F0>, <mip.entities.Var object at 0x00000258C378E920>, <mip.entities.Var object at 0x00000258C378F2E0>, <mip.entities.Var object at 0x00000258C378F1C0>, <mip.entities.Var object at 0x00000258C378E260>, <mip.entities.Var object at 0x00000258C378E6B0>, <mip.entities.Var object at 0x00000258C378E590>, <mip.entities.Var object at 0x00000258C378E440>, <mip.entities.Var object at 0x00000258C378E6E0>, <mip.entities.Var object at 0x00000258C378F280>, <mip.entities.Var object at 0x00000258C378E500>, <mip.entities.Var object at 0x00000258C378F130>, <mip.entities.Var object at 0x00000258C378E3E0>, <mip.entities.Var object at 0x00000258C378F4F0>, <mip.entities.Var object at 0x00000258C378E2F0>, <mip.entities.Var object at 0x00000258C378EF50>, <mip.entities.Var object at 0x00000258C378F250>, <mip.entities.Var object at 0x00000258C378C160>, <mip.entities.Var object at 0x00000258C378F6D0>, <mip.entities.Var object at 0x00000258C378F640>, <mip.entities.Var object at 0x00000258C378F6A0>, <mip.entities.Var object at 0x00000258C378F4C0>, <mip.entities.Var object at 0x00000258C378F730>, <mip.entities.Var object at 0x00000258C378E200>, <mip.entities.Var object at 0x00000258C378FA90>, <mip.entities.Var object at 0x00000258C378E980>, <mip.entities.Var object at 0x00000258C378E5C0>, <mip.entities.Var object at 0x00000258C378FA00>, <mip.entities.Var object at 0x00000258C378FCD0>, <mip.entities.Var object at 0x ...
# selected items: [11, 42, 43, 46, 57, 78, 84, 92, 112, 114, 120, 134]
# Total Expect Points: 2321.1724049999993
# Total Next Round Points: 959.5412199999997
# Total Team Cost: 1755600
# Number of Wk: 1
# Number of Bat: 8
# Number of Bowl: 11
# Available Players: 12
# Current Players Remaining: 9
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 3     Jack Edwards  153800      Sydney Sixers     0      1       1  ALLR
# 4    Jamie Overton  225400  Adelaide Strikers     0      1       1  ALLR
# 7    Matthew Short  254600  Adelaide Strikers     0      1       1  ALLR
# 1      Hayden Kerr  103500      Sydney Sixers     0      1       1  ALLR
# 11      Tom Curran  146900    Melbourne Stars     0      1       1  ALLR
# 0    Ben Dwarshuis  162700      Sydney Sixers     0      0       1  BOWL
# 6   Marcus Stoinis  121000    Melbourne Stars     0      1       1  ALLR
# 5       Lloyd Pope  145600  Adelaide Strikers     0      0       1  BOWL
# 2   Henry Thornton  115700  Adelaide Strikers     0      0       1  BOWL
# 10      Sam Harper   81700    Melbourne Stars     1      1       0    WK
# 8      Paul Walter  159400      Brisbane Heat     0      1       1  ALLR
# 9     Peter Siddle   85300    Melbourne Stars     0      0       1  BOWL
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 3        1          1        0  230.748975        116.173235
# 4        1          1        1  225.275540         58.504630
# 7        1          1        1  218.221755         58.568040
# 1        1          1        0  212.322030        106.831275
# 11       1          1        1  208.478950        101.745930
# 0        1          1        1  202.810585        102.349590
# 6        1          1        0  187.685770         91.712935
# 5        1          1        1  182.041185         49.493220
# 2        1          1        1  181.939115         48.184230
# 10       1          1        1  160.665965         76.991345
# 8        1          1        1  157.411260         74.238175
# 9        1          1        1  153.571275         74.748615
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Ben Dwarshuis  162700      Sydney Sixers     0      0       1  BOWL
# 2   Henry Thornton  115700  Adelaide Strikers     0      0       1  BOWL
# 4    Jamie Overton  225400  Adelaide Strikers     0      1       1  ALLR
# 5       Lloyd Pope  145600  Adelaide Strikers     0      0       1  BOWL
# 7    Matthew Short  254600  Adelaide Strikers     0      1       1  ALLR
# 8      Paul Walter  159400      Brisbane Heat     0      1       1  ALLR
# 9     Peter Siddle   85300    Melbourne Stars     0      0       1  BOWL
# 10      Sam Harper   81700    Melbourne Stars     1      1       0    WK
# 11      Tom Curran  146900    Melbourne Stars     0      1       1  ALLR
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 0        1          1        1  202.810585        102.349590
# 2        1          1        1  181.939115         48.184230
# 4        1          1        1  225.275540         58.504630
# 5        1          1        1  182.041185         49.493220
# 7        1          1        1  218.221755         58.568040
# 8        1          1        1  157.411260         74.238175
# 9        1          1        1  153.571275         74.748615
# 10       1          1        1  160.665965         76.991345
# 11       1          1        1  208.478950        101.745930
#              Name   Price             Team  Wk_f  Bat_f  Bowl_f  Role  weight  \
# 1     Hayden Kerr  103500    Sydney Sixers     0      1       1  ALLR       1
# 3    Jack Edwards  153800    Sydney Sixers     0      1       1  ALLR       1
# 6  Marcus Stoinis  121000  Melbourne Stars     0      1       1  ALLR       1
#
#    Available  In_Team     exp_pts  next_rnd_exp_pts
# 1          1        0  212.322030        106.831275
# 3          1        0  230.748975        116.173235
# 6          1        0  187.685770         91.712935

# %% [markdown]
# # 3. Optimisation Process (Round 3) - Normal 3 Trades + Boost
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,762,800
# 6. Atleast 8 players in current team (4 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 8, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1767100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]
sel_player_df = pd.merge(sel_player_df, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 1])
print(sel_player_df[sel_player_df['In_Team'] == 0])


sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_3_boost.csv')
# Out:
# [<mip.entities.Var object at 0x00000258C372A980>, <mip.entities.Var object at 0x00000258C3729E40>, <mip.entities.Var object at 0x00000258C3729E70>, <mip.entities.Var object at 0x00000258C372B010>, <mip.entities.Var object at 0x00000258C372AC50>, <mip.entities.Var object at 0x00000258C372A050>, <mip.entities.Var object at 0x00000258C372A590>, <mip.entities.Var object at 0x00000258C372A620>, <mip.entities.Var object at 0x00000258C372A650>, <mip.entities.Var object at 0x00000258C372AB00>, <mip.entities.Var object at 0x00000258C372A080>, <mip.entities.Var object at 0x00000258C269D720>, <mip.entities.Var object at 0x00000258C1E97880>, <mip.entities.Var object at 0x00000258932806A0>, <mip.entities.Var object at 0x00000258932805B0>, <mip.entities.Var object at 0x0000025893280220>, <mip.entities.Var object at 0x0000025893282440>, <mip.entities.Var object at 0x00000258C372AAA0>, <mip.entities.Var object at 0x00000258C372A3B0>, <mip.entities.Var object at 0x00000258C372A410>, <mip.entities.Var object at 0x00000258C372A260>, <mip.entities.Var object at 0x00000258C372AB60>, <mip.entities.Var object at 0x00000258C372AAD0>, <mip.entities.Var object at 0x00000258C372A0E0>, <mip.entities.Var object at 0x00000258C372AC80>, <mip.entities.Var object at 0x00000258C3729F00>, <mip.entities.Var object at 0x00000258C372AEC0>, <mip.entities.Var object at 0x00000258C372A8C0>, <mip.entities.Var object at 0x00000258C372A110>, <mip.entities.Var object at 0x00000258C372AF50>, <mip.entities.Var object at 0x00000258C372AEF0>, <mip.entities.Var object at 0x00000258C372AF20>, <mip.entities.Var object at 0x00000258C372AFB0>, <mip.entities.Var object at 0x00000258C372ADA0>, <mip.entities.Var object at 0x00000258C372B9A0>, <mip.entities.Var object at 0x00000258C372B070>, <mip.entities.Var object at 0x00000258C372A4A0>, <mip.entities.Var object at 0x00000258C372AC20>, <mip.entities.Var object at 0x00000258C372B940>, <mip.entities.Var object at 0x00000258C372B430>, <mip.entities.Var object at 0x00000258C372B4C0>, <mip.entities.Var object at 0x00000258C372AE30>, <mip.entities.Var object at 0x00000258C372ACB0>, <mip.entities.Var object at 0x00000258C372B1F0>, <mip.entities.Var object at 0x00000258C372B160>, <mip.entities.Var object at 0x00000258C372ABF0>, <mip.entities.Var object at 0x00000258C372AF80>, <mip.entities.Var object at 0x00000258C372B2E0>, <mip.entities.Var object at 0x00000258C372B370>, <mip.entities.Var object at 0x00000258C372B280>, <mip.entities.Var object at 0x00000258C372B3D0>, <mip.entities.Var object at 0x00000258C372B3A0>, <mip.entities.Var object at 0x00000258C372B550>, <mip.entities.Var object at 0x00000258C3728B80>, <mip.entities.Var object at 0x00000258C372B0D0>, <mip.entities.Var object at 0x00000258C372B340>, <mip.entities.Var object at 0x00000258C3729900>, <mip.entities.Var object at 0x00000258C372B850>, <mip.entities.Var object at 0x00000258C372BA00>, <mip.entities.Var object at 0x00000258C372B9D0>, <mip.entities.Var object at 0x00000258C372B190>, <mip.entities.Var object at 0x00000258C372B250>, <mip.entities.Var object at 0x00000258C372B100>, <mip.entities.Var object at 0x00000258C372B2B0>, <mip.entities.Var object at 0x00000258C372B400>, <mip.entities.Var object at 0x00000258C372B490>, <mip.entities.Var object at 0x00000258C372AA70>, <mip.entities.Var object at 0x00000258C372A4D0>, <mip.entities.Var object at 0x00000258C3729FC0>, <mip.entities.Var object at 0x00000258C372A140>, <mip.entities.Var object at 0x00000258C372AB90>, <mip.entities.Var object at 0x00000258C372B0A0>, <mip.entities.Var object at 0x00000258C372AFE0>, <mip.entities.Var object at 0x00000258C372B130>, <mip.entities.Var object at 0x00000258C3729F30>, <mip.entities.Var object at 0x00000258C372B460>, <mip.entities.Var object at 0x00000258C372B520>, <mip.entities.Var object at 0x00000258C372B580>, <mip.entities.Var object at 0x00000258C372B310>, <mip.entities.Var object at 0x00000258C372B5E0>, <mip.entities.Var object at 0x00000258C372B220>, <mip.entities.Var object at 0x ...
# selected items: [3, 11, 42, 43, 46, 57, 78, 92, 97, 114, 120, 134]
# Total Expect Points: 2365.707884999999
# Total Next Round Points: 959.6574649999997
# Total Team Cost: 1761800
# Number of Wk: 1
# Number of Bat: 7
# Number of Bowl: 11
# Available Players: 12
# Current Players Remaining: 8
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 4     Jack Edwards  153800      Sydney Sixers     0      1       1  ALLR
# 5    Jamie Overton  225400  Adelaide Strikers     0      1       1  ALLR
# 7    Matthew Short  254600  Adelaide Strikers     0      1       1  ALLR
# 2      Hayden Kerr  103500      Sydney Sixers     0      1       1  ALLR
# 11      Tom Curran  146900    Melbourne Stars     0      1       1  ALLR
# 1    Ben Dwarshuis  162700      Sydney Sixers     0      0       1  BOWL
# 0     Akeal Hosein  195900      Sydney Sixers     0      0       1  BOWL
# 8       Mitch Owen   90700  Hobart Hurricanes     0      1       1  ALLR
# 6       Lloyd Pope  145600  Adelaide Strikers     0      0       1  BOWL
# 3   Henry Thornton  115700  Adelaide Strikers     0      0       1  BOWL
# 10      Sam Harper   81700    Melbourne Stars     1      1       0    WK
# 9     Peter Siddle   85300    Melbourne Stars     0      0       1  BOWL
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 4        1          1        0  230.748975        116.173235
# 5        1          1        1  225.275540         58.504630
# 7        1          1        1  218.221755         58.568040
# 2        1          1        0  212.322030        106.831275
# 11       1          1        1  208.478950        101.745930
# 1        1          1        1  202.810585        102.349590
# 0        1          1        0  202.132600        102.100810
# 8        1          1        0  187.499910         63.966545
# 6        1          1        1  182.041185         49.493220
# 3        1          1        1  181.939115         48.184230
# 10       1          1        1  160.665965         76.991345
# 9        1          1        1  153.571275         74.748615
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 1    Ben Dwarshuis  162700      Sydney Sixers     0      0       1  BOWL
# 3   Henry Thornton  115700  Adelaide Strikers     0      0       1  BOWL
# 5    Jamie Overton  225400  Adelaide Strikers     0      1       1  ALLR
# 6       Lloyd Pope  145600  Adelaide Strikers     0      0       1  BOWL
# 7    Matthew Short  254600  Adelaide Strikers     0      1       1  ALLR
# 9     Peter Siddle   85300    Melbourne Stars     0      0       1  BOWL
# 10      Sam Harper   81700    Melbourne Stars     1      1       0    WK
# 11      Tom Curran  146900    Melbourne Stars     0      1       1  ALLR
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 1        1          1        1  202.810585        102.349590
# 3        1          1        1  181.939115         48.184230
# 5        1          1        1  225.275540         58.504630
# 6        1          1        1  182.041185         49.493220
# 7        1          1        1  218.221755         58.568040
# 9        1          1        1  153.571275         74.748615
# 10       1          1        1  160.665965         76.991345
# 11       1          1        1  208.478950        101.745930
#            Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  weight  \
# 0  Akeal Hosein  195900      Sydney Sixers     0      0       1  BOWL       1
# 2   Hayden Kerr  103500      Sydney Sixers     0      1       1  ALLR       1
# 4  Jack Edwards  153800      Sydney Sixers     0      1       1  ALLR       1
# 8    Mitch Owen   90700  Hobart Hurricanes     0      1       1  ALLR       1
#
#    Available  In_Team     exp_pts  next_rnd_exp_pts
# 0          1        0  202.132600        102.100810
# 2          1        0  212.322030        106.831275
# 4          1        0  230.748975        116.173235
# 8          1        0  187.499910         63.966545

# %% [markdown]
# # 3. Optimisation Process (Round 3) - Normal 3 Trades + Sam Konstas (Boost)
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,798,900
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1798900, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]
sel_player_df = pd.merge(sel_player_df, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 1])
print(sel_player_df[sel_player_df['In_Team'] == 0])


sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_3_boost_SK.csv')
# Out:
# [<mip.entities.Var object at 0x00000258C378EE90>, <mip.entities.Var object at 0x00000258C378EFB0>, <mip.entities.Var object at 0x00000258C378EFE0>, <mip.entities.Var object at 0x00000258C378C310>, <mip.entities.Var object at 0x00000258C378C3D0>, <mip.entities.Var object at 0x00000258C378C730>, <mip.entities.Var object at 0x00000258C378C820>, <mip.entities.Var object at 0x00000258C378D0C0>, <mip.entities.Var object at 0x00000258C378C1F0>, <mip.entities.Var object at 0x00000258C378CA00>, <mip.entities.Var object at 0x00000258C378CFA0>, <mip.entities.Var object at 0x00000258C378CEE0>, <mip.entities.Var object at 0x00000258C378C940>, <mip.entities.Var object at 0x00000258C378D900>, <mip.entities.Var object at 0x00000258C378CF40>, <mip.entities.Var object at 0x00000258C378C910>, <mip.entities.Var object at 0x00000258C378C190>, <mip.entities.Var object at 0x00000258C378C2E0>, <mip.entities.Var object at 0x00000258C378CAC0>, <mip.entities.Var object at 0x00000258C378C5E0>, <mip.entities.Var object at 0x00000258C378CA30>, <mip.entities.Var object at 0x00000258C378CA90>, <mip.entities.Var object at 0x00000258C378C370>, <mip.entities.Var object at 0x00000258C378C6A0>, <mip.entities.Var object at 0x00000258C378CBB0>, <mip.entities.Var object at 0x00000258C378CB50>, <mip.entities.Var object at 0x00000258C378C8B0>, <mip.entities.Var object at 0x00000258C378CAF0>, <mip.entities.Var object at 0x00000258C378C880>, <mip.entities.Var object at 0x00000258C378CA60>, <mip.entities.Var object at 0x00000258C378CC10>, <mip.entities.Var object at 0x00000258C378CC40>, <mip.entities.Var object at 0x00000258C378CEB0>, <mip.entities.Var object at 0x00000258C378CF10>, <mip.entities.Var object at 0x00000258C378D8A0>, <mip.entities.Var object at 0x00000258C378D2D0>, <mip.entities.Var object at 0x00000258C378D210>, <mip.entities.Var object at 0x00000258C378C280>, <mip.entities.Var object at 0x00000258C378D090>, <mip.entities.Var object at 0x00000258C378CBE0>, <mip.entities.Var object at 0x00000258C378CD00>, <mip.entities.Var object at 0x00000258C378C340>, <mip.entities.Var object at 0x00000258C378CD90>, <mip.entities.Var object at 0x00000258C378C7C0>, <mip.entities.Var object at 0x00000258C378C8E0>, <mip.entities.Var object at 0x00000258C378C670>, <mip.entities.Var object at 0x00000258C378D450>, <mip.entities.Var object at 0x00000258C378CCA0>, <mip.entities.Var object at 0x00000258C378C2B0>, <mip.entities.Var object at 0x00000258C378C850>, <mip.entities.Var object at 0x00000258C378C0A0>, <mip.entities.Var object at 0x00000258C378C6D0>, <mip.entities.Var object at 0x00000258C378CD30>, <mip.entities.Var object at 0x00000258C378FD90>, <mip.entities.Var object at 0x00000258C378C1C0>, <mip.entities.Var object at 0x00000258C378E020>, <mip.entities.Var object at 0x00000258C378C790>, <mip.entities.Var object at 0x00000258C378C700>, <mip.entities.Var object at 0x00000258C378C760>, <mip.entities.Var object at 0x00000258C378C4F0>, <mip.entities.Var object at 0x00000258C378C5B0>, <mip.entities.Var object at 0x00000258C378C250>, <mip.entities.Var object at 0x00000258C378CF70>, <mip.entities.Var object at 0x00000258C378D6C0>, <mip.entities.Var object at 0x00000258C378D180>, <mip.entities.Var object at 0x00000258C378C490>, <mip.entities.Var object at 0x00000258C378D0F0>, <mip.entities.Var object at 0x00000258C378D2A0>, <mip.entities.Var object at 0x00000258C378D000>, <mip.entities.Var object at 0x00000258C378DE40>, <mip.entities.Var object at 0x00000258C378C640>, <mip.entities.Var object at 0x00000258C378C580>, <mip.entities.Var object at 0x00000258C378D390>, <mip.entities.Var object at 0x00000258C378C4C0>, <mip.entities.Var object at 0x00000258C378D420>, <mip.entities.Var object at 0x00000258C378D6F0>, <mip.entities.Var object at 0x00000258C378C400>, <mip.entities.Var object at 0x00000258C378D600>, <mip.entities.Var object at 0x00000258C378D5D0>, <mip.entities.Var object at 0x0000025893281630>, <mip.entities.Var object at 0x00000258932824D0>, <mip.entities.Var object at 0x ...
# selected items: [11, 42, 43, 46, 57, 78, 84, 92, 112, 114, 120, 134]
# Total Expect Points: 2321.1724049999993
# Total Next Round Points: 959.5412199999997
# Total Team Cost: 1755600
# Number of Wk: 1
# Number of Bat: 8
# Number of Bowl: 11
# Available Players: 12
# Current Players Remaining: 9
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 3     Jack Edwards  153800      Sydney Sixers     0      1       1  ALLR
# 4    Jamie Overton  225400  Adelaide Strikers     0      1       1  ALLR
# 7    Matthew Short  254600  Adelaide Strikers     0      1       1  ALLR
# 1      Hayden Kerr  103500      Sydney Sixers     0      1       1  ALLR
# 11      Tom Curran  146900    Melbourne Stars     0      1       1  ALLR
# 0    Ben Dwarshuis  162700      Sydney Sixers     0      0       1  BOWL
# 6   Marcus Stoinis  121000    Melbourne Stars     0      1       1  ALLR
# 5       Lloyd Pope  145600  Adelaide Strikers     0      0       1  BOWL
# 2   Henry Thornton  115700  Adelaide Strikers     0      0       1  BOWL
# 10      Sam Harper   81700    Melbourne Stars     1      1       0    WK
# 8      Paul Walter  159400      Brisbane Heat     0      1       1  ALLR
# 9     Peter Siddle   85300    Melbourne Stars     0      0       1  BOWL
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 3        1          1        0  230.748975        116.173235
# 4        1          1        1  225.275540         58.504630
# 7        1          1        1  218.221755         58.568040
# 1        1          1        0  212.322030        106.831275
# 11       1          1        1  208.478950        101.745930
# 0        1          1        1  202.810585        102.349590
# 6        1          1        0  187.685770         91.712935
# 5        1          1        1  182.041185         49.493220
# 2        1          1        1  181.939115         48.184230
# 10       1          1        1  160.665965         76.991345
# 8        1          1        1  157.411260         74.238175
# 9        1          1        1  153.571275         74.748615
#               Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Ben Dwarshuis  162700      Sydney Sixers     0      0       1  BOWL
# 2   Henry Thornton  115700  Adelaide Strikers     0      0       1  BOWL
# 4    Jamie Overton  225400  Adelaide Strikers     0      1       1  ALLR
# 5       Lloyd Pope  145600  Adelaide Strikers     0      0       1  BOWL
# 7    Matthew Short  254600  Adelaide Strikers     0      1       1  ALLR
# 8      Paul Walter  159400      Brisbane Heat     0      1       1  ALLR
# 9     Peter Siddle   85300    Melbourne Stars     0      0       1  BOWL
# 10      Sam Harper   81700    Melbourne Stars     1      1       0    WK
# 11      Tom Curran  146900    Melbourne Stars     0      1       1  ALLR
#
#     weight  Available  In_Team     exp_pts  next_rnd_exp_pts
# 0        1          1        1  202.810585        102.349590
# 2        1          1        1  181.939115         48.184230
# 4        1          1        1  225.275540         58.504630
# 5        1          1        1  182.041185         49.493220
# 7        1          1        1  218.221755         58.568040
# 8        1          1        1  157.411260         74.238175
# 9        1          1        1  153.571275         74.748615
# 10       1          1        1  160.665965         76.991345
# 11       1          1        1  208.478950        101.745930
#              Name   Price             Team  Wk_f  Bat_f  Bowl_f  Role  weight  \
# 1     Hayden Kerr  103500    Sydney Sixers     0      1       1  ALLR       1
# 3    Jack Edwards  153800    Sydney Sixers     0      1       1  ALLR       1
# 6  Marcus Stoinis  121000  Melbourne Stars     0      1       1  ALLR       1
#
#    Available  In_Team     exp_pts  next_rnd_exp_pts
# 1          1        0  212.322030        106.831275
# 3          1        0  230.748975        116.173235
# 6          1        0  187.685770         91.712935
