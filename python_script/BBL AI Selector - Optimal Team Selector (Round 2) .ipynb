# %% [markdown]
# # BBLF AI Selector: Part 2: During Tournament Optimal Squad - Optimser (Round 2)

# %% [markdown]
# # 0. Prerequistes

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 

os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI'

# %% [markdown]
# # 1. Data Extraction

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 2
opt_round = 3

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(directory,'data/python_datasets/player_price_round_2.csv'), low_memory=False)
print(price_df)

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(directory,'data/python_datasets/team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(directory,'data/python_datasets/bbl14_fullteam_model_score_during_rnd2.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
print(game_df)

    # Join on expected points for each game
print(game_df.columns)
print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f"], right_on = ["Name", "Team", "opp", "venue", "Home_f"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
print(player_df)
# Out:
#       Last_Name First_Name First_Name_Short        Full_Name         player  \
# 0        Abbott       Sean               SA      Sean Abbott      SA Abbott
# 1          Agar     Ashton               AC      Ashton Agar        AC Agar
# 2          Agar        Wes               WA         Wes Agar        WA Agar
# 3         Allen       Finn              NaN       Finn Allen     Finn Allen
# 4         Allen     Fabian              NaN     Fabian Allen   Fabian Allen
# ..          ...        ...              ...              ...            ...
# 142       Wells        Jon               JW        Jon Wells       JW Wells
# 143  Wildermuth       Jack               JD  Jack Wildermuth  JD Wildermuth
# 144        Wood       Jack               JP        Jack Wood        JP Wood
# 145      Wright        Mac                M       Mac Wright       M Wright
# 146       Zampa       Adam                A       Adam Zampa        A Zampa
#
#       Price                 Team  Role  Available  In_Team
# 0    135700        Sydney Sixers  BOWL          1        0
# 1    123500      Perth Scorchers  BOWL          1        0
# 2     99700       Sydney Thunder  BOWL          0        0
# 3    140700      Perth Scorchers   BAT          1        0
# 4    115700    Adelaide Strikers  ALLR          0        0
# ..      ...                  ...   ...        ...      ...
# 142   78100  Melbourne Renegades   BAT          1        0
# 143   58500        Brisbane Heat  ALLR          0        0
# 144   63900        Brisbane Heat  ALLR          0        0
# 145  126300    Hobart Hurricanes   BAT          1        0
# 146   75500  Melbourne Renegades  BOWL          1        0
#
# [147 rows x 10 columns]
#                    Team           Opposition              Venue  Home_f  Round
# 1     Adelaide Strikers      Melbourne Stars      Adelaide Oval       1      2
# 2     Adelaide Strikers        Brisbane Heat              GABBA       0      2
# 3     Adelaide Strikers    Hobart Hurricanes      Adelaide Oval       1      3
# 4     Adelaide Strikers      Perth Scorchers      Adelaide Oval       1      4
# 5     Adelaide Strikers  Melbourne Renegades             Marvel       0      4
# 12      Melbourne Stars    Adelaide Strikers      Adelaide Oval       0      2
# 13      Melbourne Stars        Sydney Sixers                SCG       0      3
# 14      Melbourne Stars       Sydney Thunder              Other       0      3
# 15      Melbourne Stars        Brisbane Heat              GABBA       0      4
# 21        Sydney Sixers       Sydney Thunder  Sydney Showground       0      2
# 22        Sydney Sixers      Melbourne Stars                SCG       1      3
# 23        Sydney Sixers        Brisbane Heat              GABBA       0      3
# 24        Sydney Sixers    Hobart Hurricanes             Hobart       0      4
# 31        Brisbane Heat    Adelaide Strikers              GABBA       1      2
# 32        Brisbane Heat        Sydney Sixers      Perth Stadium       0      3
# 33        Brisbane Heat      Perth Scorchers              GABBA       1      3
# 34        Brisbane Heat      Melbourne Stars              GABBA       1      4
# 41      Perth Scorchers    Hobart Hurricanes             Hobart       0      2
# 42      Perth Scorchers  Melbourne Renegades             Marvel       0      2
# 43      Perth Scorchers        Brisbane Heat      Perth Stadium       1      3
# 44      Perth Scorchers    Adelaide Strikers      Adelaide Oval       0      4
# 51       Sydney Thunder        Sydney Sixers  Sydney Showground       1      2
# 52       Sydney Thunder      Melbourne Stars              Other       0      3
# 53       Sydney Thunder  Melbourne Renegades  Sydney Showground       1      4
# 61    Hobart Hurricanes      Perth Scorchers             Hobart       1      2
# 62    Hobart Hurricanes    Adelaide Strikers      Adelaide Oval       0      3
# 63    Hobart Hurricanes        Sydney Sixers             Hobart       1      4
# 72  Melbourne Renegades      Perth Scorchers             Marvel       1      2
# 73  Melbourne Renegades       Sydney Thunder  Sydney Showground       0      4
# 74  Melbourne Renegades    Adelaide Strikers             Marvel       1      4
#              Name                 Team                  opp  \
# 0     Sean Abbott        Sydney Sixers  Melbourne Renegades
# 1     Sean Abbott        Sydney Sixers       Sydney Thunder
# 2     Sean Abbott        Sydney Sixers      Melbourne Stars
# 3     Sean Abbott        Sydney Sixers        Brisbane Heat
# 4     Sean Abbott        Sydney Sixers    Hobart Hurricanes
# ...           ...                  ...                  ...
# 1465   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1466   Adam Zampa  Melbourne Renegades      Perth Scorchers
# 1467   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1468   Adam Zampa  Melbourne Renegades    Hobart Hurricanes
# 1469   Adam Zampa  Melbourne Renegades        Brisbane Heat
#
#                          venue  Home_f  Round    Full_Name  season_fp_lag1  \
# 0                          SCG       1      1  Sean Abbott           448.0
# 1            Sydney Showground       0      2  Sean Abbott           448.0
# 2                          SCG       1      3  Sean Abbott           448.0
# 3                        GABBA       0      3  Sean Abbott           448.0
# 4                       Hobart       0      4  Sean Abbott           448.0
# ...                        ...     ...    ...          ...             ...
# 1465  Melbourne Cricket Ground       0      5   Adam Zampa           235.0
# 1466             Perth Stadium       0      6   Adam Zampa           235.0
# 1467                    Marvel       1      7   Adam Zampa           235.0
# 1468                    Hobart       0      8   Adam Zampa           235.0
# 1469                    Marvel       1      9   Adam Zampa           235.0
#
#       avg_season_fp_lag1  max_season_fp_lag1  ...  avg_season_fp_lag3  \
# 0              49.777778               139.0  ...           63.692308
# 1              49.777778               139.0  ...           63.692308
# 2              49.777778               139.0  ...           63.692308
# 3              49.777778               139.0  ...           63.692308
# 4              49.777778               139.0  ...           63.692308
# ...                  ...                 ...  ...                 ...
# 1465           29.375000                62.0  ...           38.500000
# 1466           29.375000                62.0  ...           38.500000
# 1467           29.375000                62.0  ...           38.500000
# 1468           29.375000                62.0  ...           38.500000
# 1469           29.375000                62.0  ...           38.500000
#
#       max_season_fp_lag3  min_season_fp_lag3  med_season_fp_lag3  \
# 0                  157.0                 7.0                48.0
# 1                  157.0                 7.0                48.0
# 2                  157.0                 7.0                48.0
# 3                  157.0                 7.0                48.0
# 4                  157.0                 7.0                48.0
# ...                  ...                 ...                 ...
# 1465                70.0                 5.0                36.5
# 1466                70.0                 5.0                36.5
# 1467                70.0                 5.0                36.5
# 1468                70.0                 5.0                36.5
# 1469                70.0                 5.0                36.5
#
#       sd_season_fp_lag3  match_cnt_lag3  season  rank  rank_group    exp_pts
# 0             54.608279            13.0      14     2        High  54.756412
# 1             54.608279            13.0      14     2        High  52.784622
# 2             54.608279            13.0      14     2        High  51.560210
# 3             54.608279            13.0      14     2        High  54.826781
# 4             54.608279            13.0      14     2        High  52.801622
# ...                 ...             ...     ...   ...         ...        ...
# 1465          26.154456            10.0      14     6         Low  45.818832
# 1466          26.154456            10.0      14     6         Low  44.535638
# 1467          26.154456            10.0      14     6         Low  45.392840
# 1468          26.154456            10.0      14     6         Low  46.421516
# 1469          26.154456            10.0      14     6         Low  44.814832
#
# [1470 rows x 32 columns]
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  123500      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 546   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 547   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 548   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 549   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 550   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
#
#      Available  In_Team         Opposition              Venue  Home_f  Round
# 0            1        0     Sydney Thunder  Sydney Showground       0      2
# 1            1        0    Melbourne Stars                SCG       1      3
# 2            1        0      Brisbane Heat              GABBA       0      3
# 3            1        0  Hobart Hurricanes             Hobart       0      4
# 4            1        0  Hobart Hurricanes             Hobart       0      2
# ..         ...      ...                ...                ...     ...    ...
# 546          1        0  Adelaide Strikers      Adelaide Oval       0      3
# 547          1        0      Sydney Sixers             Hobart       1      4
# 548          1        0    Perth Scorchers             Marvel       1      2
# 549          1        0     Sydney Thunder  Sydney Showground       0      4
# 550          1        0  Adelaide Strikers             Marvel       1      4
#
# [551 rows x 13 columns]
# Index(['Name', 'Price', 'Team', 'Wk_f', 'Bat_f', 'Bowl_f', 'Role', 'Available',
#        'In_Team', 'Opposition', 'Venue', 'Home_f', 'Round'],
#       dtype='object')
# Index(['Name', 'Team', 'opp', 'venue', 'Home_f', 'Round', 'Full_Name',
#        'season_fp_lag1', 'avg_season_fp_lag1', 'max_season_fp_lag1',
#        'min_season_fp_lag1', 'med_season_fp_lag1', 'sd_season_fp_lag1',
#        'match_cnt_lag1', 'season_fp_lag2', 'avg_season_fp_lag2',
#        'max_season_fp_lag2', 'min_season_fp_lag2', 'med_season_fp_lag2',
#        'sd_season_fp_lag2', 'match_cnt_lag2', 'season_fp_lag3',
#        'avg_season_fp_lag3', 'max_season_fp_lag3', 'min_season_fp_lag3',
#        'med_season_fp_lag3', 'sd_season_fp_lag3', 'match_cnt_lag3', 'season',
#        'rank', 'rank_group', 'exp_pts'],
#       dtype='object')
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  123500      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 546   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 547   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 548   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 549   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 550   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
#
#      Available  In_Team         Opposition  ... max_season_fp_lag3  \
# 0            1        0     Sydney Thunder  ...              157.0
# 1            1        0    Melbourne Stars  ...              157.0
# 2            1        0      Brisbane Heat  ...              157.0
# 3            1        0  Hobart Hurricanes  ...              157.0
# 4            1        0  Hobart Hurricanes  ...              107.0
# ..         ...      ...                ...  ...                ...
# 546          1        0  Adelaide Strikers  ...                6.0
# 547          1        0      Sydney Sixers  ...                6.0
# 548          1        0    Perth Scorchers  ...               70.0
# 549          1        0     Sydney Thunder  ...               70.0
# 550          1        0  Adelaide Strikers  ...               70.0
#
#      min_season_fp_lag3  med_season_fp_lag3 sd_season_fp_lag3 match_cnt_lag3  \
# 0                   7.0                48.0         54.608279           13.0
# 1                   7.0                48.0         54.608279           13.0
# 2                   7.0                48.0         54.608279           13.0
# 3                   7.0                48.0         54.608279           13.0
# 4                  10.0                57.0         26.326702           15.0
# ..                  ...                 ...               ...            ...
# 546                 6.0                 6.0               NaN            1.0
# 547                 6.0                 6.0               NaN            1.0
# 548                 5.0                36.5         26.154456           10.0
# 549                 5.0                36.5         26.154456           10.0
# 550                 5.0                36.5         26.154456           10.0
#
#      season rank  rank_group    exp_pts  weight
# 0        14    2        High  57.314622       1
# 1        14    2        High  56.090210       1
# 2        14    2        High  59.356781       1
# 3        14    2        High  57.331622       1
# 4        14    1        High  32.961785       1
# ..      ...  ...         ...        ...     ...
# 546      14    7         Low  31.094032       1
# 547      14    7         Low  37.284419       1
# 548      14    6         Low  48.953436       1
# 549      14    6         Low  48.892844       1
# 550      14    6         Low  49.627222       1
#
# [551 rows x 43 columns]
#                 Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0       Aaron Hardie  177800      Perth Scorchers     0      1       1  ALLR
# 1         Adam Milne  106700      Melbourne Stars     0      0       1  BOWL
# 2         Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 3       Akeal Hosein  196700        Sydney Sixers     0      0       1  BOWL
# 4         Alex Carey  167500    Adelaide Strikers     1      1       0    WK
# ..               ...     ...                  ...   ...    ...     ...   ...
# 142  Will Prestwidge   56600        Brisbane Heat     0      0       1  BOWL
# 143    Will Salzmann   39500       Sydney Thunder     0      1       1  ALLR
# 144  Will Sutherland  163800  Melbourne Renegades     0      1       1  ALLR
# 145  Xavier Bartlett  207400        Brisbane Heat     0      0       1  BOWL
# 146     Xavier Crone   39500  Melbourne Renegades     0      0       1  BOWL
#
#      weight  Available  In_Team     exp_pts
# 0         1          0        0  172.306348
# 1         1          1        0  194.147513
# 2         1          1        0  147.473502
# 3         1          1        0  136.440401
# 4         1          0        0  178.551081
# ..      ...        ...      ...         ...
# 142       1          0        0  169.946116
# 143       1          0        0   58.864832
# 144       1          1        0  183.442794
# 145       1          1        0  216.978010
# 146       1          0        0   71.844790
#
# [147 rows x 11 columns]

# %% [markdown]
# # 2. Optimisation Process (Round 2)
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,762,800
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1762800, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]

print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))

sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_2.csv')
# Out:
# [<mip.entities.Var object at 0x000002329B0A5E40>, <mip.entities.Var object at 0x000002329B0A4D60>, <mip.entities.Var object at 0x000002329B0A5660>, <mip.entities.Var object at 0x000002329B0A52A0>, <mip.entities.Var object at 0x000002329B0A6740>, <mip.entities.Var object at 0x000002329B0A4310>, <mip.entities.Var object at 0x000002329B0A5300>, <mip.entities.Var object at 0x000002329B0A63E0>, <mip.entities.Var object at 0x000002329B0A4160>, <mip.entities.Var object at 0x000002329B0A4CA0>, <mip.entities.Var object at 0x000002329B0A5090>, <mip.entities.Var object at 0x000002329B0A6B60>, <mip.entities.Var object at 0x000002329B0A7220>, <mip.entities.Var object at 0x000002329B0A4820>, <mip.entities.Var object at 0x000002329B0A4F40>, <mip.entities.Var object at 0x000002329B0A4D00>, <mip.entities.Var object at 0x000002329B0A5030>, <mip.entities.Var object at 0x000002329B0A5420>, <mip.entities.Var object at 0x000002329B0A56C0>, <mip.entities.Var object at 0x000002329B0A5720>, <mip.entities.Var object at 0x000002329B0A5000>, <mip.entities.Var object at 0x000002329B0A54E0>, <mip.entities.Var object at 0x000002329B0A4520>, <mip.entities.Var object at 0x000002329B0A5A80>, <mip.entities.Var object at 0x000002329B0A7040>, <mip.entities.Var object at 0x000002329B0A5120>, <mip.entities.Var object at 0x000002329B0A7B20>, <mip.entities.Var object at 0x000002329B0A43D0>, <mip.entities.Var object at 0x000002329B0A5330>, <mip.entities.Var object at 0x000002329B0A4040>, <mip.entities.Var object at 0x00000232FF2C3880>, <mip.entities.Var object at 0x00000232FF2C3970>, <mip.entities.Var object at 0x000002329B0A5DE0>, <mip.entities.Var object at 0x000002329B0A5CF0>, <mip.entities.Var object at 0x000002329B0A6320>, <mip.entities.Var object at 0x000002329B0A5690>, <mip.entities.Var object at 0x000002329B0A5DB0>, <mip.entities.Var object at 0x000002329B0A4A30>, <mip.entities.Var object at 0x000002329B0A4880>, <mip.entities.Var object at 0x000002329B0A5E10>, <mip.entities.Var object at 0x000002329B0A5360>, <mip.entities.Var object at 0x000002329B0A4460>, <mip.entities.Var object at 0x000002329B0A6470>, <mip.entities.Var object at 0x000002329B0A49D0>, <mip.entities.Var object at 0x000002329B0A5D20>, <mip.entities.Var object at 0x000002329B0A7160>, <mip.entities.Var object at 0x000002329B0A6E90>, <mip.entities.Var object at 0x000002329B0A4580>, <mip.entities.Var object at 0x000002329B0A7520>, <mip.entities.Var object at 0x000002329B0A6050>, <mip.entities.Var object at 0x000002329B0A6E00>, <mip.entities.Var object at 0x000002329B0A5AB0>, <mip.entities.Var object at 0x000002329B0A47C0>, <mip.entities.Var object at 0x000002329B0A46D0>, <mip.entities.Var object at 0x000002329B0A53F0>, <mip.entities.Var object at 0x000002329B0A5900>, <mip.entities.Var object at 0x000002329B0A7010>, <mip.entities.Var object at 0x000002329B0A48B0>, <mip.entities.Var object at 0x000002329B0A5C30>, <mip.entities.Var object at 0x000002329B0A4430>, <mip.entities.Var object at 0x000002329B0A53C0>, <mip.entities.Var object at 0x000002329B0A5540>, <mip.entities.Var object at 0x000002329B0A58D0>, <mip.entities.Var object at 0x000002329B0A5E70>, <mip.entities.Var object at 0x000002329B0A47F0>, <mip.entities.Var object at 0x000002329B0A5FC0>, <mip.entities.Var object at 0x000002329B0A70A0>, <mip.entities.Var object at 0x000002329B0A5990>, <mip.entities.Var object at 0x000002329B0A6170>, <mip.entities.Var object at 0x000002329B0A7070>, <mip.entities.Var object at 0x000002329B0A5A50>, <mip.entities.Var object at 0x000002329B0A54B0>, <mip.entities.Var object at 0x000002329B0A4550>, <mip.entities.Var object at 0x000002329B0A40A0>, <mip.entities.Var object at 0x000002329B0A6500>, <mip.entities.Var object at 0x000002329B0A4F10>, <mip.entities.Var object at 0x000002329B0A4D90>, <mip.entities.Var object at 0x000002329B0A6D70>, <mip.entities.Var object at 0x000002329B0A5B40>, <mip.entities.Var object at 0x000002329B0A4B20>, <mip.entities.Var object at 0x000002329B0A4FD0>, <mip.entities.Var object at 0x ...
# selected items: [9, 11, 43, 44, 57, 58, 78, 92, 112, 114, 120, 134]
# Total Expect Points: 2863.3175656000003
# Total Team Cost: 1761300
# Number of Wk: 1
# Number of Bat: 7
# Number of Bowl: 10
# Available Players: 12
# Current Players Remaining: 9
#                   Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 92       Matthew Short  288700  Adelaide Strikers     0      1       1  ALLR
# 57       Jamie Overton  214600  Adelaide Strikers     0      1       1  ALLR
# 78          Lloyd Pope  131700  Adelaide Strikers     0      0       1  BOWL
# 43      Henry Thornton  102600  Adelaide Strikers     0      0       1  BOWL
# 134         Tom Curran  152200    Melbourne Stars     0      1       1  ALLR
# 58   Jason Behrendorff  166500    Perth Scorchers     0      0       1  BOWL
# 112        Paul Walter  174700      Brisbane Heat     0      1       1  ALLR
# 11       Ben Dwarshuis  142900      Sydney Sixers     0      0       1  BOWL
# 9         Beau Webster  153400    Melbourne Stars     0      1       1  ALLR
# 114       Peter Siddle   72400    Melbourne Stars     0      0       1  BOWL
# 44   Hilton Cartwright   95200    Melbourne Stars     0      1       0   BAT
# 120         Sam Harper   66400    Melbourne Stars     1      1       0    WK
#
#      weight  Available  In_Team     exp_pts
# 92        1          1        1  345.410104
# 57        1          1        1  328.862620
# 78        1          1        0  289.879606
# 43        1          1        0  258.123589
# 134       1          1        1  255.860146
# 58        1          1        1  241.844473
# 112       1          1        0  241.530130
# 11        1          1        1  217.069526
# 9         1          1        1  200.240386
# 114       1          1        1  191.423153
# 44        1          1        1  151.275678
# 120       1          1        1  141.798155

# %% [markdown]
# # Hayden Kerr Replacement

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 2
opt_round = 3

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(directory,'data/python_datasets/player_price_round_2_g3.csv'), low_memory=False)
print(price_df)

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(directory,'data/python_datasets/team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(directory,'data/python_datasets/bbl14_fullteam_model_score_during_rnd2.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
print(game_df)

    # Join on expected points for each game
print(game_df.columns)
print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f"], right_on = ["Name", "Team", "opp", "venue", "Home_f"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
print(player_df)
# Out:
#       Last_Name First_Name First_Name_Short        Full_Name         player  \
# 0        Abbott       Sean               SA      Sean Abbott      SA Abbott
# 1          Agar     Ashton               AC      Ashton Agar        AC Agar
# 2          Agar        Wes               WA         Wes Agar        WA Agar
# 3         Allen       Finn              NaN       Finn Allen     Finn Allen
# 4         Allen     Fabian              NaN     Fabian Allen   Fabian Allen
# ..          ...        ...              ...              ...            ...
# 142       Wells        Jon               JW        Jon Wells       JW Wells
# 143  Wildermuth       Jack               JD  Jack Wildermuth  JD Wildermuth
# 144        Wood       Jack               JP        Jack Wood        JP Wood
# 145      Wright        Mac                M       Mac Wright       M Wright
# 146       Zampa       Adam                A       Adam Zampa        A Zampa
#
#       Price                 Team  Role  Available  In_Team
# 0    135700        Sydney Sixers  BOWL          1        0
# 1    123500      Perth Scorchers  BOWL          0        0
# 2     99700       Sydney Thunder  BOWL          0        0
# 3    140700      Perth Scorchers   BAT          0        0
# 4    115700    Adelaide Strikers  ALLR          0        0
# ..      ...                  ...   ...        ...      ...
# 142   78100  Melbourne Renegades   BAT          1        0
# 143   58500        Brisbane Heat  ALLR          0        0
# 144   63900        Brisbane Heat  ALLR          0        0
# 145  126300    Hobart Hurricanes   BAT          0        0
# 146   75500  Melbourne Renegades  BOWL          1        0
#
# [147 rows x 10 columns]
#                    Team           Opposition              Venue  Home_f  Round
# 1     Adelaide Strikers      Melbourne Stars      Adelaide Oval       1      2
# 2     Adelaide Strikers        Brisbane Heat              GABBA       0      2
# 3     Adelaide Strikers    Hobart Hurricanes      Adelaide Oval       1      3
# 4     Adelaide Strikers      Perth Scorchers      Adelaide Oval       1      4
# 5     Adelaide Strikers  Melbourne Renegades             Marvel       0      4
# 12      Melbourne Stars    Adelaide Strikers      Adelaide Oval       0      2
# 13      Melbourne Stars        Sydney Sixers                SCG       0      3
# 14      Melbourne Stars       Sydney Thunder              Other       0      3
# 15      Melbourne Stars        Brisbane Heat              GABBA       0      4
# 21        Sydney Sixers       Sydney Thunder  Sydney Showground       0      2
# 22        Sydney Sixers      Melbourne Stars                SCG       1      3
# 23        Sydney Sixers        Brisbane Heat              GABBA       0      3
# 24        Sydney Sixers    Hobart Hurricanes             Hobart       0      4
# 31        Brisbane Heat    Adelaide Strikers              GABBA       1      2
# 32        Brisbane Heat        Sydney Sixers      Perth Stadium       0      3
# 33        Brisbane Heat      Perth Scorchers              GABBA       1      3
# 34        Brisbane Heat      Melbourne Stars              GABBA       1      4
# 41      Perth Scorchers    Hobart Hurricanes             Hobart       0      2
# 42      Perth Scorchers  Melbourne Renegades             Marvel       0      2
# 43      Perth Scorchers        Brisbane Heat      Perth Stadium       1      3
# 44      Perth Scorchers    Adelaide Strikers      Adelaide Oval       0      4
# 51       Sydney Thunder        Sydney Sixers  Sydney Showground       1      2
# 52       Sydney Thunder      Melbourne Stars              Other       0      3
# 53       Sydney Thunder  Melbourne Renegades  Sydney Showground       1      4
# 61    Hobart Hurricanes      Perth Scorchers             Hobart       1      2
# 62    Hobart Hurricanes    Adelaide Strikers      Adelaide Oval       0      3
# 63    Hobart Hurricanes        Sydney Sixers             Hobart       1      4
# 72  Melbourne Renegades      Perth Scorchers             Marvel       1      2
# 73  Melbourne Renegades       Sydney Thunder  Sydney Showground       0      4
# 74  Melbourne Renegades    Adelaide Strikers             Marvel       1      4
#              Name                 Team                  opp  \
# 0     Sean Abbott        Sydney Sixers  Melbourne Renegades
# 1     Sean Abbott        Sydney Sixers       Sydney Thunder
# 2     Sean Abbott        Sydney Sixers      Melbourne Stars
# 3     Sean Abbott        Sydney Sixers        Brisbane Heat
# 4     Sean Abbott        Sydney Sixers    Hobart Hurricanes
# ...           ...                  ...                  ...
# 1465   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1466   Adam Zampa  Melbourne Renegades      Perth Scorchers
# 1467   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1468   Adam Zampa  Melbourne Renegades    Hobart Hurricanes
# 1469   Adam Zampa  Melbourne Renegades        Brisbane Heat
#
#                          venue  Home_f  Round    Full_Name  season_fp_lag1  \
# 0                          SCG       1      1  Sean Abbott           448.0
# 1            Sydney Showground       0      2  Sean Abbott           448.0
# 2                          SCG       1      3  Sean Abbott           448.0
# 3                        GABBA       0      3  Sean Abbott           448.0
# 4                       Hobart       0      4  Sean Abbott           448.0
# ...                        ...     ...    ...          ...             ...
# 1465  Melbourne Cricket Ground       0      5   Adam Zampa           235.0
# 1466             Perth Stadium       0      6   Adam Zampa           235.0
# 1467                    Marvel       1      7   Adam Zampa           235.0
# 1468                    Hobart       0      8   Adam Zampa           235.0
# 1469                    Marvel       1      9   Adam Zampa           235.0
#
#       avg_season_fp_lag1  max_season_fp_lag1  ...  avg_season_fp_lag3  \
# 0              49.777778               139.0  ...           63.692308
# 1              49.777778               139.0  ...           63.692308
# 2              49.777778               139.0  ...           63.692308
# 3              49.777778               139.0  ...           63.692308
# 4              49.777778               139.0  ...           63.692308
# ...                  ...                 ...  ...                 ...
# 1465           29.375000                62.0  ...           38.500000
# 1466           29.375000                62.0  ...           38.500000
# 1467           29.375000                62.0  ...           38.500000
# 1468           29.375000                62.0  ...           38.500000
# 1469           29.375000                62.0  ...           38.500000
#
#       max_season_fp_lag3  min_season_fp_lag3  med_season_fp_lag3  \
# 0                  157.0                 7.0                48.0
# 1                  157.0                 7.0                48.0
# 2                  157.0                 7.0                48.0
# 3                  157.0                 7.0                48.0
# 4                  157.0                 7.0                48.0
# ...                  ...                 ...                 ...
# 1465                70.0                 5.0                36.5
# 1466                70.0                 5.0                36.5
# 1467                70.0                 5.0                36.5
# 1468                70.0                 5.0                36.5
# 1469                70.0                 5.0                36.5
#
#       sd_season_fp_lag3  match_cnt_lag3  season  rank  rank_group    exp_pts
# 0             54.608279            13.0      14     2        High  54.756412
# 1             54.608279            13.0      14     2        High  52.784622
# 2             54.608279            13.0      14     2        High  51.560210
# 3             54.608279            13.0      14     2        High  54.826781
# 4             54.608279            13.0      14     2        High  52.801622
# ...                 ...             ...     ...   ...         ...        ...
# 1465          26.154456            10.0      14     6         Low  45.818832
# 1466          26.154456            10.0      14     6         Low  44.535638
# 1467          26.154456            10.0      14     6         Low  45.392840
# 1468          26.154456            10.0      14     6         Low  46.421516
# 1469          26.154456            10.0      14     6         Low  44.814832
#
# [1470 rows x 32 columns]
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  123500      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 546   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 547   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 548   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 549   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 550   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
#
#      Available  In_Team         Opposition              Venue  Home_f  Round
# 0            1        0     Sydney Thunder  Sydney Showground       0      2
# 1            1        0    Melbourne Stars                SCG       1      3
# 2            1        0      Brisbane Heat              GABBA       0      3
# 3            1        0  Hobart Hurricanes             Hobart       0      4
# 4            0        0  Hobart Hurricanes             Hobart       0      2
# ..         ...      ...                ...                ...     ...    ...
# 546          0        0  Adelaide Strikers      Adelaide Oval       0      3
# 547          0        0      Sydney Sixers             Hobart       1      4
# 548          1        0    Perth Scorchers             Marvel       1      2
# 549          1        0     Sydney Thunder  Sydney Showground       0      4
# 550          1        0  Adelaide Strikers             Marvel       1      4
#
# [551 rows x 13 columns]
# Index(['Name', 'Price', 'Team', 'Wk_f', 'Bat_f', 'Bowl_f', 'Role', 'Available',
#        'In_Team', 'Opposition', 'Venue', 'Home_f', 'Round'],
#       dtype='object')
# Index(['Name', 'Team', 'opp', 'venue', 'Home_f', 'Round', 'Full_Name',
#        'season_fp_lag1', 'avg_season_fp_lag1', 'max_season_fp_lag1',
#        'min_season_fp_lag1', 'med_season_fp_lag1', 'sd_season_fp_lag1',
#        'match_cnt_lag1', 'season_fp_lag2', 'avg_season_fp_lag2',
#        'max_season_fp_lag2', 'min_season_fp_lag2', 'med_season_fp_lag2',
#        'sd_season_fp_lag2', 'match_cnt_lag2', 'season_fp_lag3',
#        'avg_season_fp_lag3', 'max_season_fp_lag3', 'min_season_fp_lag3',
#        'med_season_fp_lag3', 'sd_season_fp_lag3', 'match_cnt_lag3', 'season',
#        'rank', 'rank_group', 'exp_pts'],
#       dtype='object')
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  135700        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  123500      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 546   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 547   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 548   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 549   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 550   Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
#
#      Available  In_Team         Opposition  ... max_season_fp_lag3  \
# 0            1        0     Sydney Thunder  ...              157.0
# 1            1        0    Melbourne Stars  ...              157.0
# 2            1        0      Brisbane Heat  ...              157.0
# 3            1        0  Hobart Hurricanes  ...              157.0
# 4            0        0  Hobart Hurricanes  ...              107.0
# ..         ...      ...                ...  ...                ...
# 546          0        0  Adelaide Strikers  ...                6.0
# 547          0        0      Sydney Sixers  ...                6.0
# 548          1        0    Perth Scorchers  ...               70.0
# 549          1        0     Sydney Thunder  ...               70.0
# 550          1        0  Adelaide Strikers  ...               70.0
#
#      min_season_fp_lag3  med_season_fp_lag3 sd_season_fp_lag3 match_cnt_lag3  \
# 0                   7.0                48.0         54.608279           13.0
# 1                   7.0                48.0         54.608279           13.0
# 2                   7.0                48.0         54.608279           13.0
# 3                   7.0                48.0         54.608279           13.0
# 4                  10.0                57.0         26.326702           15.0
# ..                  ...                 ...               ...            ...
# 546                 6.0                 6.0               NaN            1.0
# 547                 6.0                 6.0               NaN            1.0
# 548                 5.0                36.5         26.154456           10.0
# 549                 5.0                36.5         26.154456           10.0
# 550                 5.0                36.5         26.154456           10.0
#
#      season rank  rank_group    exp_pts  weight
# 0        14    2        High  57.314622       1
# 1        14    2        High  56.090210       1
# 2        14    2        High  59.356781       1
# 3        14    2        High  57.331622       1
# 4        14    1        High  32.961785       1
# ..      ...  ...         ...        ...     ...
# 546      14    7         Low  31.094032       1
# 547      14    7         Low  37.284419       1
# 548      14    6         Low  48.953436       1
# 549      14    6         Low  48.892844       1
# 550      14    6         Low  49.627222       1
#
# [551 rows x 43 columns]
#                 Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0       Aaron Hardie  177800      Perth Scorchers     0      1       1  ALLR
# 1         Adam Milne  106700      Melbourne Stars     0      0       1  BOWL
# 2         Adam Zampa   75500  Melbourne Renegades     0      0       1  BOWL
# 3       Akeal Hosein  196700        Sydney Sixers     0      0       1  BOWL
# 4         Alex Carey  167500    Adelaide Strikers     1      1       0    WK
# ..               ...     ...                  ...   ...    ...     ...   ...
# 142  Will Prestwidge   56600        Brisbane Heat     0      0       1  BOWL
# 143    Will Salzmann   39500       Sydney Thunder     0      1       1  ALLR
# 144  Will Sutherland  163800  Melbourne Renegades     0      1       1  ALLR
# 145  Xavier Bartlett  207400        Brisbane Heat     0      0       1  BOWL
# 146     Xavier Crone   39500  Melbourne Renegades     0      0       1  BOWL
#
#      weight  Available  In_Team     exp_pts
# 0         1          0        0  172.306348
# 1         1          0        0  194.147513
# 2         1          1        0  147.473502
# 3         1          1        0  136.440401
# 4         1          0        0  178.551081
# ..      ...        ...      ...         ...
# 142       1          0        0  169.946116
# 143       1          0        0   58.864832
# 144       1          1        0  183.442794
# 145       1          1        0  216.978010
# 146       1          0        0   71.844790
#
# [147 rows x 11 columns]

# %% [markdown]
# # 2. Optimisation Process (Round 2.2 - Hayden Kerr Replacement)
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 1
# 2. Atleast 0 wicketkeeper
# 3. Atleast 1 batters
# 4. Atleast 0 bowlers
# 5. Total budget of team is less than $176,200
# 6. Atleast 0 players in current team (New player)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 1, range(len(price))
team_play_cnt, total_team_player = 0, range(len(price))
wk_cnt, total_wk = 0, range(len(price))
bat_cnt, total_bat = 1, range(len(price))
bowl_cnt, total_bowl = 0, range(len(price))
budget, total_budget = 176200, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) == team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]

print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))

sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_2_HK_repl.csv')
# Out:
# [<mip.entities.Var object at 0x000002329B0A41C0>, <mip.entities.Var object at 0x000002329B0A4280>, <mip.entities.Var object at 0x000002329B0A6B90>, <mip.entities.Var object at 0x000002329B0A6DD0>, <mip.entities.Var object at 0x000002329B0A52D0>, <mip.entities.Var object at 0x000002329B0A44F0>, <mip.entities.Var object at 0x000002329B0A5270>, <mip.entities.Var object at 0x000002329B0A5210>, <mip.entities.Var object at 0x000002329B0A51E0>, <mip.entities.Var object at 0x000002329B0A45E0>, <mip.entities.Var object at 0x000002329B0A50C0>, <mip.entities.Var object at 0x000002329B0A4D30>, <mip.entities.Var object at 0x000002329B0A4400>, <mip.entities.Var object at 0x000002329B0A4E80>, <mip.entities.Var object at 0x000002329B0A4FA0>, <mip.entities.Var object at 0x000002329B0A4EB0>, <mip.entities.Var object at 0x000002329B0A4DC0>, <mip.entities.Var object at 0x000002329B0A4E50>, <mip.entities.Var object at 0x000002329B0A4DF0>, <mip.entities.Var object at 0x000002329B0A4A90>, <mip.entities.Var object at 0x000002329B0A4C10>, <mip.entities.Var object at 0x000002329B0A4B80>, <mip.entities.Var object at 0x000002329B0A4970>, <mip.entities.Var object at 0x000002329B0A49A0>, <mip.entities.Var object at 0x000002329B0A45B0>, <mip.entities.Var object at 0x000002329B0A4850>, <mip.entities.Var object at 0x000002329B0A4640>, <mip.entities.Var object at 0x000002329B0A4670>, <mip.entities.Var object at 0x000002329B0A44C0>, <mip.entities.Var object at 0x000002329B0A42B0>, <mip.entities.Var object at 0x000002329B0A4190>, <mip.entities.Var object at 0x000002329B0A42E0>, <mip.entities.Var object at 0x000002329B0A4490>, <mip.entities.Var object at 0x000002329B0A43A0>, <mip.entities.Var object at 0x000002329B0A4340>, <mip.entities.Var object at 0x000002329B0A4BE0>, <mip.entities.Var object at 0x000002329B0A4C40>, <mip.entities.Var object at 0x000002329B0A6C80>, <mip.entities.Var object at 0x000002329B0A46A0>, <mip.entities.Var object at 0x000002329B0A4220>, <mip.entities.Var object at 0x000002329B0A6FE0>, <mip.entities.Var object at 0x000002329B0A6F80>, <mip.entities.Var object at 0x000002329B0A6E30>, <mip.entities.Var object at 0x000002329B0A6BC0>, <mip.entities.Var object at 0x000002329B0A6FB0>, <mip.entities.Var object at 0x000002329B0A7100>, <mip.entities.Var object at 0x000002329B0A6A70>, <mip.entities.Var object at 0x000002329B0A6B30>, <mip.entities.Var object at 0x000002329B0A58A0>, <mip.entities.Var object at 0x000002329B0A57E0>, <mip.entities.Var object at 0x000002329B0A56F0>, <mip.entities.Var object at 0x000002329B0A5510>, <mip.entities.Var object at 0x000002329B0A6860>, <mip.entities.Var object at 0x000002329B0A5960>, <mip.entities.Var object at 0x000002329B0A6920>, <mip.entities.Var object at 0x000002329B0A68F0>, <mip.entities.Var object at 0x000002329B0A66E0>, <mip.entities.Var object at 0x000002329B0A6950>, <mip.entities.Var object at 0x000002329B0A6A10>, <mip.entities.Var object at 0x000002329B0A5780>, <mip.entities.Var object at 0x000002329B0A6410>, <mip.entities.Var object at 0x000002329B0A5390>, <mip.entities.Var object at 0x000002329B0A67D0>, <mip.entities.Var object at 0x000002329B0A6890>, <mip.entities.Var object at 0x000002329B0A5180>, <mip.entities.Var object at 0x000002329B0A6830>, <mip.entities.Var object at 0x000002329B0A57B0>, <mip.entities.Var object at 0x000002329B0A6650>, <mip.entities.Var object at 0x000002329B0A69E0>, <mip.entities.Var object at 0x000002329B0A5810>, <mip.entities.Var object at 0x000002329B0A5750>, <mip.entities.Var object at 0x000002329B0A6CE0>, <mip.entities.Var object at 0x000002329B0A7310>, <mip.entities.Var object at 0x000002329B0A6C50>, <mip.entities.Var object at 0x000002329B0A7370>, <mip.entities.Var object at 0x000002329B0A5870>, <mip.entities.Var object at 0x000002329B0A5840>, <mip.entities.Var object at 0x00000232FEA47760>, <mip.entities.Var object at 0x000002329B0A6F50>, <mip.entities.Var object at 0x00000232FE13F460>, <mip.entities.Var object at 0x00000232FEFA7130>, <mip.entities.Var object at 0x ...
# selected items: [112]
# Total Expect Points: 241.53013000000004
# Total Team Cost: 174700
# Number of Wk: 0
# Number of Bat: 1
# Number of Bowl: 1
# Available Players: 1
# Current Players Remaining: 0
#             Name   Price           Team  Wk_f  Bat_f  Bowl_f  Role  weight  \
# 112  Paul Walter  174700  Brisbane Heat     0      1       1  ALLR       1
#
#      Available  In_Team    exp_pts
# 112          1        0  241.53013
