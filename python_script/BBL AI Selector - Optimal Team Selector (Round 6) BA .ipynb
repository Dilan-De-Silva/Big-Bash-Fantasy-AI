# %% [markdown]
# # BBLF AI Selector: Part 2: During Tournament Optimal Squad - Optimser (Round 6)

# %% [markdown]
# # 0. Prerequistes

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 

os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI'
add_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/round_6'
over_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/add_data_created/overall'
py_data_directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets'

# %% [markdown]
# # 1. Data Extraction

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 9
opt_round = 1

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_6_boost_scen_6B7N8N.csv'), low_memory=False)
#price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_', str(current_round), '.csv'), low_memory=False)

# print(price_df) 

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
# print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(py_data_directory,'bbl14_fullteam_model_score_during_rnd_6.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
# print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
# print(game_df)

    # Join on expected points for each game
# print(game_df.columns)
# print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], how = "left")
#player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
# print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# print(player_df)

player_df_next_rnd = player_df_raw[player_df_raw.Round == current_round].groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
next_rnd_exp_pts=('exp_pts',"sum"))
player_df_next_rnd = player_df_next_rnd[["Name", "Team", "next_rnd_exp_pts"]]

# %% [markdown]
# # 2. Optimisation Process (Round 6) - Normal 3 Trades
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,758,100
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1758100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]
sel_player_df = pd.merge(sel_player_df, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))
print("Current Players Remaining:", sum(sel_player_df["In_Team"]))

print(sel_player_df.sort_values(by = "Price", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df[sel_player_df['In_Team'] == 0].sort_values(by = "Price", ascending = False))


#sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_6.csv')
# Out:
# [<mip.entities.Var object at 0x000001A39011AE90>, <mip.entities.Var object at 0x000001A390119990>, <mip.entities.Var object at 0x000001A3901187F0>, <mip.entities.Var object at 0x000001A390118DF0>, <mip.entities.Var object at 0x000001A39011A8F0>, <mip.entities.Var object at 0x000001A39011A770>, <mip.entities.Var object at 0x000001A39011B460>, <mip.entities.Var object at 0x000001A390119570>, <mip.entities.Var object at 0x000001A390119300>, <mip.entities.Var object at 0x000001A3901191B0>, <mip.entities.Var object at 0x000001A390119A80>, <mip.entities.Var object at 0x000001A390267D30>, <mip.entities.Var object at 0x000001A38E170490>, <mip.entities.Var object at 0x000001A38E1707C0>, <mip.entities.Var object at 0x000001A38E1708E0>, <mip.entities.Var object at 0x000001A38E170670>, <mip.entities.Var object at 0x000001A38E171ED0>, <mip.entities.Var object at 0x000001A38E170400>, <mip.entities.Var object at 0x000001A38E1711B0>, <mip.entities.Var object at 0x000001A38E1716F0>, <mip.entities.Var object at 0x000001A38E173460>, <mip.entities.Var object at 0x000001A38E170C10>, <mip.entities.Var object at 0x000001A38E1718A0>, <mip.entities.Var object at 0x000001A38E19C760>, <mip.entities.Var object at 0x000001A38E19C4F0>, <mip.entities.Var object at 0x000001A38E19CFD0>, <mip.entities.Var object at 0x000001A38E19E050>, <mip.entities.Var object at 0x000001A38E19D120>, <mip.entities.Var object at 0x000001A38E19CE80>, <mip.entities.Var object at 0x000001A38E19E140>, <mip.entities.Var object at 0x000001A38E19F220>, <mip.entities.Var object at 0x000001A38E19C130>, <mip.entities.Var object at 0x000001A38E19D330>, <mip.entities.Var object at 0x000001A38E19C790>, <mip.entities.Var object at 0x000001A38E19F100>, <mip.entities.Var object at 0x000001A38E19DFC0>, <mip.entities.Var object at 0x000001A38E19CE50>, <mip.entities.Var object at 0x000001A38E19DAB0>, <mip.entities.Var object at 0x000001A38E19E350>, <mip.entities.Var object at 0x000001A38E19F430>, <mip.entities.Var object at 0x000001A38E19C160>, <mip.entities.Var object at 0x000001A38E19DE70>, <mip.entities.Var object at 0x000001A38E19C7C0>, <mip.entities.Var object at 0x000001A38E19CD90>, <mip.entities.Var object at 0x000001A38E19F6A0>, <mip.entities.Var object at 0x000001A38E19D480>, <mip.entities.Var object at 0x000001A38E19F610>, <mip.entities.Var object at 0x000001A38E19F640>, <mip.entities.Var object at 0x000001A38E19F280>, <mip.entities.Var object at 0x000001A38E19F3D0>, <mip.entities.Var object at 0x000001A38E19D660>, <mip.entities.Var object at 0x000001A38E19F340>, <mip.entities.Var object at 0x000001A38E19C280>, <mip.entities.Var object at 0x000001A38E19D3C0>, <mip.entities.Var object at 0x000001A38E19DA20>, <mip.entities.Var object at 0x000001A38E19F790>, <mip.entities.Var object at 0x000001A38E19C220>, <mip.entities.Var object at 0x000001A38E19C5E0>, <mip.entities.Var object at 0x000001A38E19DF30>, <mip.entities.Var object at 0x000001A38E19C8E0>, <mip.entities.Var object at 0x000001A38E19C520>, <mip.entities.Var object at 0x000001A38E19E8F0>, <mip.entities.Var object at 0x000001A38E19CF70>, <mip.entities.Var object at 0x000001A38E19DA50>, <mip.entities.Var object at 0x000001A38E19C190>, <mip.entities.Var object at 0x000001A38E19DC60>, <mip.entities.Var object at 0x000001A38E19CB20>, <mip.entities.Var object at 0x000001A38E19D180>, <mip.entities.Var object at 0x000001A38E19F4F0>, <mip.entities.Var object at 0x000001A38E19D4B0>, <mip.entities.Var object at 0x000001A38E19C250>, <mip.entities.Var object at 0x000001A38E19E2F0>, <mip.entities.Var object at 0x000001A38E19DCC0>, <mip.entities.Var object at 0x000001A38E19F1F0>, <mip.entities.Var object at 0x000001A38E19C550>, <mip.entities.Var object at 0x000001A38E19CC70>, <mip.entities.Var object at 0x000001A38E19C580>, <mip.entities.Var object at 0x000001A38E19D8A0>, <mip.entities.Var object at 0x000001A38E19EE60>, <mip.entities.Var object at 0x000001A38E19CEB0>, <mip.entities.Var object at 0x000001A38E19CA00>, <mip.entities.Var object at 0x ...
# selected items: [24, 25, 31, 37, 80, 95, 127, 131, 132, 138, 143, 146]
# Total Expect Points: 578.4395
# Total Next Round Points: 578.4395
# Total Team Cost: 1639100
# Number of Wk: 2
# Number of Bat: 6
# Number of Bowl: 7
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 9        Tom Rogers  164800  Melbourne Renegades     0      0       1  BOWL
# 10         Wes Agar  159200       Sydney Thunder     0      0       1  BOWL
# 6   Spencer Johnson  157800        Brisbane Heat     0      0       1  BOWL
# 2      David Warner  151900       Sydney Thunder     0      1       0   BAT
# 11  Will Sutherland  148400  Melbourne Renegades     0      1       1  ALLR
# 1        Chris Lynn  144800    Adelaide Strikers     0      1       0   BAT
# 0      Chris Jordan  141200    Hobart Hurricanes     0      0       1  BOWL
# 4   Lockie Ferguson  134300       Sydney Thunder     0      0       1  BOWL
# 8       Tim Seifert  126900  Melbourne Renegades     1      1       0    WK
# 5      Matthew Wade  115700    Hobart Hurricanes     1      1       0    WK
# 3   Gurinder Sandhu  104000  Melbourne Renegades     0      0       1  BOWL
# 7         Tim David   90100    Hobart Hurricanes     0      1       0   BAT
#
#     weight  Available  In_Team  exp_pts  next_rnd_exp_pts
# 9        1          1        0  53.1860           53.1860
# 10       1          1        1  62.9195           62.9195
# 6        1          1        1  52.3945           52.3945
# 2        1          1        1  41.1410           41.1410
# 11       1          1        1  41.6805           41.6805
# 1        1          1        0  41.0000           41.0000
# 0        1          1        1  48.5205           48.5205
# 4        1          1        1  50.4245           50.4245
# 8        1          1        0  46.5840           46.5840
# 5        1          1        1  43.2260           43.2260
# 3        1          1        1  55.4845           55.4845
# 7        1          1        1  41.8785           41.8785
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 10         Wes Agar  159200       Sydney Thunder     0      0       1  BOWL
# 6   Spencer Johnson  157800        Brisbane Heat     0      0       1  BOWL
# 2      David Warner  151900       Sydney Thunder     0      1       0   BAT
# 11  Will Sutherland  148400  Melbourne Renegades     0      1       1  ALLR
# 0      Chris Jordan  141200    Hobart Hurricanes     0      0       1  BOWL
# 4   Lockie Ferguson  134300       Sydney Thunder     0      0       1  BOWL
# 5      Matthew Wade  115700    Hobart Hurricanes     1      1       0    WK
# 3   Gurinder Sandhu  104000  Melbourne Renegades     0      0       1  BOWL
# 7         Tim David   90100    Hobart Hurricanes     0      1       0   BAT
#
#     weight  Available  In_Team  exp_pts  next_rnd_exp_pts
# 10       1          1        1  62.9195           62.9195
# 6        1          1        1  52.3945           52.3945
# 2        1          1        1  41.1410           41.1410
# 11       1          1        1  41.6805           41.6805
# 0        1          1        1  48.5205           48.5205
# 4        1          1        1  50.4245           50.4245
# 5        1          1        1  43.2260           43.2260
# 3        1          1        1  55.4845           55.4845
# 7        1          1        1  41.8785           41.8785
#           Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 9   Tom Rogers  164800  Melbourne Renegades     0      0       1  BOWL
# 1   Chris Lynn  144800    Adelaide Strikers     0      1       0   BAT
# 8  Tim Seifert  126900  Melbourne Renegades     1      1       0    WK
#
#    weight  Available  In_Team  exp_pts  next_rnd_exp_pts
# 9       1          1        0   53.186            53.186
# 1       1          1        0   41.000            41.000
# 8       1          1        0   46.584            46.584

# %% [markdown]
# # 3. Optimisation Process (Round 6) - Normal 3 Trades + Boost
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,758,100
# 6. Atleast 8 players in current team (4 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 8, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1758100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost = player_df.iloc[selected]
sel_player_df_boost = pd.merge(sel_player_df_boost, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost["Price"]))
print("Number of Wk:", sum(sel_player_df_boost["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost["In_Team"]))

print(sel_player_df_boost.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost[sel_player_df_boost['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost[sel_player_df_boost['In_Team'] == 0].sort_values(by = "Price", ascending = False))


#sel_player_df_boost.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_6_boost.csv')
# Out:
# [<mip.entities.Var object at 0x000001A38E20F970>, <mip.entities.Var object at 0x000001A38E20C970>, <mip.entities.Var object at 0x000001A38E20F460>, <mip.entities.Var object at 0x000001A38E20C790>, <mip.entities.Var object at 0x000001A38E20F8E0>, <mip.entities.Var object at 0x000001A38E1AEEF0>, <mip.entities.Var object at 0x000001A38E1AF370>, <mip.entities.Var object at 0x000001A38E1AF4C0>, <mip.entities.Var object at 0x000001A38E1AF8B0>, <mip.entities.Var object at 0x000001A38E1ACC70>, <mip.entities.Var object at 0x000001A38E1AF8E0>, <mip.entities.Var object at 0x000001A38E1AF220>, <mip.entities.Var object at 0x000001A38E1AC580>, <mip.entities.Var object at 0x000001A38E1AC3A0>, <mip.entities.Var object at 0x000001A38E1AF3A0>, <mip.entities.Var object at 0x000001A38E1AF910>, <mip.entities.Var object at 0x000001A38E1AEDA0>, <mip.entities.Var object at 0x000001A38E1AF280>, <mip.entities.Var object at 0x000001A38E1AF400>, <mip.entities.Var object at 0x000001A38E1AC460>, <mip.entities.Var object at 0x000001A38E1AF2E0>, <mip.entities.Var object at 0x000001A38E1AC340>, <mip.entities.Var object at 0x000001A38E1AC790>, <mip.entities.Var object at 0x000001A39011BD00>, <mip.entities.Var object at 0x000001A39011ADD0>, <mip.entities.Var object at 0x000001A39011B910>, <mip.entities.Var object at 0x000001A39011AC50>, <mip.entities.Var object at 0x000001A390118940>, <mip.entities.Var object at 0x000001A39011B670>, <mip.entities.Var object at 0x000001A3901180A0>, <mip.entities.Var object at 0x000001A39011A650>, <mip.entities.Var object at 0x000001A390119390>, <mip.entities.Var object at 0x000001A39011A560>, <mip.entities.Var object at 0x000001A390118340>, <mip.entities.Var object at 0x000001A39011B010>, <mip.entities.Var object at 0x000001A39011A0E0>, <mip.entities.Var object at 0x000001A390119090>, <mip.entities.Var object at 0x000001A39011AEC0>, <mip.entities.Var object at 0x000001A39011ABC0>, <mip.entities.Var object at 0x000001A39011B7F0>, <mip.entities.Var object at 0x000001A39011B3A0>, <mip.entities.Var object at 0x000001A390118D30>, <mip.entities.Var object at 0x000001A39027E950>, <mip.entities.Var object at 0x000001A39027DC60>, <mip.entities.Var object at 0x000001A39027F8E0>, <mip.entities.Var object at 0x000001A39027FDC0>, <mip.entities.Var object at 0x000001A39027FEB0>, <mip.entities.Var object at 0x000001A39027CC40>, <mip.entities.Var object at 0x000001A39027F160>, <mip.entities.Var object at 0x000001A39027C400>, <mip.entities.Var object at 0x000001A39027E1A0>, <mip.entities.Var object at 0x000001A39027F760>, <mip.entities.Var object at 0x000001A39027C5E0>, <mip.entities.Var object at 0x000001A39027E9E0>, <mip.entities.Var object at 0x000001A39027EB60>, <mip.entities.Var object at 0x000001A39027FA60>, <mip.entities.Var object at 0x000001A39027C280>, <mip.entities.Var object at 0x000001A38E11B0D0>, <mip.entities.Var object at 0x000001A38E11AB90>, <mip.entities.Var object at 0x000001A38E11AD10>, <mip.entities.Var object at 0x000001A38E11A860>, <mip.entities.Var object at 0x000001A38E11AD40>, <mip.entities.Var object at 0x000001A38E11B760>, <mip.entities.Var object at 0x000001A38E11B340>, <mip.entities.Var object at 0x000001A38E11B8B0>, <mip.entities.Var object at 0x000001A38E11B490>, <mip.entities.Var object at 0x000001A38E11AFE0>, <mip.entities.Var object at 0x000001A38E11AA40>, <mip.entities.Var object at 0x000001A38E11B100>, <mip.entities.Var object at 0x000001A38E11ADA0>, <mip.entities.Var object at 0x000001A38E11BC70>, <mip.entities.Var object at 0x000001A38E11BF40>, <mip.entities.Var object at 0x000001A38E11B7C0>, <mip.entities.Var object at 0x000001A38E11B730>, <mip.entities.Var object at 0x000001A38E11A8F0>, <mip.entities.Var object at 0x000001A38E11A890>, <mip.entities.Var object at 0x000001A38E11A7A0>, <mip.entities.Var object at 0x000001A38E11A140>, <mip.entities.Var object at 0x000001A38E11AB00>, <mip.entities.Var object at 0x000001A38E11A7D0>, <mip.entities.Var object at 0x000001A38E11A920>, <mip.entities.Var object at 0x ...
# selected items: [24, 25, 31, 37, 80, 95, 127, 131, 132, 138, 143, 146]
# Total Expect Points: 578.4395
# Total Next Round Points: 578.4395
# Total Team Cost: 1639100
# Number of Wk: 2
# Number of Bat: 6
# Number of Bowl: 7
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 9        Tom Rogers  164800  Melbourne Renegades     0      0       1  BOWL
# 10         Wes Agar  159200       Sydney Thunder     0      0       1  BOWL
# 6   Spencer Johnson  157800        Brisbane Heat     0      0       1  BOWL
# 2      David Warner  151900       Sydney Thunder     0      1       0   BAT
# 11  Will Sutherland  148400  Melbourne Renegades     0      1       1  ALLR
# 1        Chris Lynn  144800    Adelaide Strikers     0      1       0   BAT
# 0      Chris Jordan  141200    Hobart Hurricanes     0      0       1  BOWL
# 4   Lockie Ferguson  134300       Sydney Thunder     0      0       1  BOWL
# 8       Tim Seifert  126900  Melbourne Renegades     1      1       0    WK
# 5      Matthew Wade  115700    Hobart Hurricanes     1      1       0    WK
# 3   Gurinder Sandhu  104000  Melbourne Renegades     0      0       1  BOWL
# 7         Tim David   90100    Hobart Hurricanes     0      1       0   BAT
#
#     weight  Available  In_Team  exp_pts  next_rnd_exp_pts
# 9        1          1        0  53.1860           53.1860
# 10       1          1        1  62.9195           62.9195
# 6        1          1        1  52.3945           52.3945
# 2        1          1        1  41.1410           41.1410
# 11       1          1        1  41.6805           41.6805
# 1        1          1        0  41.0000           41.0000
# 0        1          1        1  48.5205           48.5205
# 4        1          1        1  50.4245           50.4245
# 8        1          1        0  46.5840           46.5840
# 5        1          1        1  43.2260           43.2260
# 3        1          1        1  55.4845           55.4845
# 7        1          1        1  41.8785           41.8785
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 10         Wes Agar  159200       Sydney Thunder     0      0       1  BOWL
# 6   Spencer Johnson  157800        Brisbane Heat     0      0       1  BOWL
# 2      David Warner  151900       Sydney Thunder     0      1       0   BAT
# 11  Will Sutherland  148400  Melbourne Renegades     0      1       1  ALLR
# 0      Chris Jordan  141200    Hobart Hurricanes     0      0       1  BOWL
# 4   Lockie Ferguson  134300       Sydney Thunder     0      0       1  BOWL
# 5      Matthew Wade  115700    Hobart Hurricanes     1      1       0    WK
# 3   Gurinder Sandhu  104000  Melbourne Renegades     0      0       1  BOWL
# 7         Tim David   90100    Hobart Hurricanes     0      1       0   BAT
#
#     weight  Available  In_Team  exp_pts  next_rnd_exp_pts
# 10       1          1        1  62.9195           62.9195
# 6        1          1        1  52.3945           52.3945
# 2        1          1        1  41.1410           41.1410
# 11       1          1        1  41.6805           41.6805
# 0        1          1        1  48.5205           48.5205
# 4        1          1        1  50.4245           50.4245
# 5        1          1        1  43.2260           43.2260
# 3        1          1        1  55.4845           55.4845
# 7        1          1        1  41.8785           41.8785
#           Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 9   Tom Rogers  164800  Melbourne Renegades     0      0       1  BOWL
# 1   Chris Lynn  144800    Adelaide Strikers     0      1       0   BAT
# 8  Tim Seifert  126900  Melbourne Renegades     1      1       0    WK
#
#    weight  Available  In_Team  exp_pts  next_rnd_exp_pts
# 9       1          1        0   53.186            53.186
# 1       1          1        0   41.000            41.000
# 8       1          1        0   46.584            46.584

# %% [markdown]
# # 5. Extra Scenario - Round 6 ()

# %%
# 1. Data Extraction 
    # Current Round & Optimal Number of Rounds
current_round = 6
opt_round = 2

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_6.csv'), low_memory=False)
#price_df = pd.read_csv(os.path.join(add_data_directory,'player_price_rnd_', str(current_round), '.csv'), low_memory=False)

# print(price_df) 

    # Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available", "In_Team"]].rename(columns = {"Full_Name": "Name"}) 
    
    # Pull in team fixture csv file

team_fix_df = pd.read_csv(os.path.join(over_data_directory,'team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round >= current_round].dropna()
team_fix_df = team_fix_df[team_fix_df.Round <= current_round + opt_round - 1].dropna()
# print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(py_data_directory,'bbl14_fullteam_model_score_during_rnd_6.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
# print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
# print(game_df)

    # Join on expected points for each game
# print(game_df.columns)
# print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], right_on = ["Name", "Team", "Opposition", "Venue", "Home_f","Round"], how = "left")
player_df_raw["exp_pts"] = np.where((player_df_raw["Role"] == "WK"), player_df_raw["exp_pts"] + 10.51, player_df_raw["exp_pts"] + 4.53)
player_df_raw["weight"] = 1
# print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# print(player_df)

player_df_next_rnd = player_df_raw[player_df_raw.Round == current_round].groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available", "In_Team"], as_index=False).agg(
next_rnd_exp_pts=('exp_pts',"sum"))
player_df_next_rnd = player_df_next_rnd[["Name", "Team", "next_rnd_exp_pts"]]

# %% [markdown]
# # 6. Optimisation Process (Round 6) - Extra Scenario - 2 Trades
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 12
# 2. Atleast 1 wicketkeeper
# 3. Atleast 6 batters
# 4. Atleast 5 bowlers
# 5. Total budget of team is less than $1,746,100
# 6. Atleast 9 players in current team (3 trades)

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
in_team = player_df["In_Team"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 12, range(len(price))
team_play_cnt, total_team_player = 9, range(len(price))
wk_cnt, total_wk = 1, range(len(price))
bat_cnt, total_bat = 6, range(len(price))
bowl_cnt, total_bowl = 5, range(len(price))
budget, total_budget = 1746100, range(len(price))

m = Model("knapsack")


x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt
m += xsum(in_team[i] * x[i] for i in total_team_player) >= team_play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df_boost_SK = player_df.iloc[selected]
sel_player_df_boost_SK = pd.merge(sel_player_df_boost_SK, player_df_next_rnd, left_on = ["Name","Team"], right_on = ["Name","Team"], how = "left")
print("Total Expect Points:", sum(sel_player_df_boost_SK["exp_pts"]))
print("Total Next Round Points:", sum(sel_player_df_boost_SK["next_rnd_exp_pts"]))
print("Total Team Cost:", sum(sel_player_df_boost_SK["Price"]))
print("Number of Wk:", sum(sel_player_df_boost_SK["Wk_f"]))
print("Number of Bat:", sum(sel_player_df_boost_SK["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df_boost_SK["Bowl_f"]))
print("Available Players:", sum(sel_player_df_boost_SK["Available"]))
print("Current Players Remaining:", sum(sel_player_df_boost_SK["In_Team"]))

print(sel_player_df_boost_SK.sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 1].sort_values(by = "Price", ascending = False))
print(sel_player_df_boost_SK[sel_player_df_boost_SK['In_Team'] == 0].sort_values(by = "Price", ascending = False))


# sel_player_df_boost_SK.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_round_6_extra.csv')
# Out:
# [<mip.entities.Var object at 0x000001A38D0BD7E0>, <mip.entities.Var object at 0x000001A38D0BCBB0>, <mip.entities.Var object at 0x000001A38D0BDFF0>, <mip.entities.Var object at 0x000001A38D0BD960>, <mip.entities.Var object at 0x000001A38D0BD0F0>, <mip.entities.Var object at 0x000001A38D0BCB50>, <mip.entities.Var object at 0x000001A38D0BCA30>, <mip.entities.Var object at 0x000001A38D0BC490>, <mip.entities.Var object at 0x000001A38D0BD540>, <mip.entities.Var object at 0x000001A38D0BD720>, <mip.entities.Var object at 0x000001A38E15BE20>, <mip.entities.Var object at 0x000001A38E159D50>, <mip.entities.Var object at 0x000001A38E1595D0>, <mip.entities.Var object at 0x000001A38E15A800>, <mip.entities.Var object at 0x000001A38E11B130>, <mip.entities.Var object at 0x000001A38E11BF70>, <mip.entities.Var object at 0x000001A38E11B280>, <mip.entities.Var object at 0x000001A38E11B3D0>, <mip.entities.Var object at 0x000001A38E11BDC0>, <mip.entities.Var object at 0x000001A38E11B220>, <mip.entities.Var object at 0x000001A38E11BD30>, <mip.entities.Var object at 0x000001A38E11B7F0>, <mip.entities.Var object at 0x000001A38E11B2B0>, <mip.entities.Var object at 0x000001A38E11AC80>, <mip.entities.Var object at 0x000001A38E11AF20>, <mip.entities.Var object at 0x000001A38E11AAD0>, <mip.entities.Var object at 0x000001A38E11B160>, <mip.entities.Var object at 0x000001A38E11B4F0>, <mip.entities.Var object at 0x000001A38E11AA70>, <mip.entities.Var object at 0x000001A38E11B940>, <mip.entities.Var object at 0x000001A38E11BFD0>, <mip.entities.Var object at 0x000001A38E11BA00>, <mip.entities.Var object at 0x000001A38E11BD90>, <mip.entities.Var object at 0x000001A38E11BF10>, <mip.entities.Var object at 0x000001A38E19EC50>, <mip.entities.Var object at 0x000001A38E19CE20>, <mip.entities.Var object at 0x000001A38E19E7A0>, <mip.entities.Var object at 0x000001A38E19E380>, <mip.entities.Var object at 0x000001A38E19DFF0>, <mip.entities.Var object at 0x000001A38E19F2E0>, <mip.entities.Var object at 0x000001A38E19C100>, <mip.entities.Var object at 0x000001A38E19D690>, <mip.entities.Var object at 0x000001A38E19DB10>, <mip.entities.Var object at 0x000001A38E19C670>, <mip.entities.Var object at 0x000001A38E19ECE0>, <mip.entities.Var object at 0x000001A38E19C850>, <mip.entities.Var object at 0x000001A38E19EE90>, <mip.entities.Var object at 0x000001A38E19E3B0>, <mip.entities.Var object at 0x000001A38E19F250>, <mip.entities.Var object at 0x000001A38E19C940>, <mip.entities.Var object at 0x000001A38E19D810>, <mip.entities.Var object at 0x000001A38E19E4D0>, <mip.entities.Var object at 0x000001A38E19D120>, <mip.entities.Var object at 0x000001A38E19D360>, <mip.entities.Var object at 0x000001A38C243E50>, <mip.entities.Var object at 0x000001A38C242530>, <mip.entities.Var object at 0x000001A38CA57D60>, <mip.entities.Var object at 0x000001A38CC613F0>, <mip.entities.Var object at 0x000001A38C12CD00>, <mip.entities.Var object at 0x000001A39011A440>, <mip.entities.Var object at 0x000001A39011B730>, <mip.entities.Var object at 0x000001A390118640>, <mip.entities.Var object at 0x000001A3901181C0>, <mip.entities.Var object at 0x000001A3901196C0>, <mip.entities.Var object at 0x000001A39011B190>, <mip.entities.Var object at 0x000001A39011AD40>, <mip.entities.Var object at 0x000001A39011B970>, <mip.entities.Var object at 0x000001A390119C30>, <mip.entities.Var object at 0x000001A3901184F0>, <mip.entities.Var object at 0x000001A390119450>, <mip.entities.Var object at 0x000001A390119960>, <mip.entities.Var object at 0x000001A3901189A0>, <mip.entities.Var object at 0x000001A39011AB60>, <mip.entities.Var object at 0x000001A39011A200>, <mip.entities.Var object at 0x000001A39011BAC0>, <mip.entities.Var object at 0x000001A39011B6D0>, <mip.entities.Var object at 0x000001A39011BE80>, <mip.entities.Var object at 0x000001A39011A380>, <mip.entities.Var object at 0x000001A39011BFA0>, <mip.entities.Var object at 0x000001A390119600>, <mip.entities.Var object at 0x000001A39011BBB0>, <mip.entities.Var object at 0x ...
# selected items: [31, 46, 69, 80, 85, 89, 115, 119, 121, 127, 143, 146]
# Total Expect Points: 1382.81125
# Total Next Round Points: 817.78775
# Total Team Cost: 1535200
# Number of Wk: 3
# Number of Bat: 8
# Number of Bowl: 7
# Available Players: 12
# Current Players Remaining: 9
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 7      Sam Billings  161800       Sydney Thunder     1      1       0    WK
# 10         Wes Agar  159200       Sydney Thunder     0      0       1  BOWL
# 9   Spencer Johnson  157800        Brisbane Heat     0      0       1  BOWL
# 0      David Warner  151900       Sydney Thunder     0      1       0   BAT
# 11  Will Sutherland  148400  Melbourne Renegades     0      1       1  ALLR
# 1      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 3   Lockie Ferguson  134300       Sydney Thunder     0      0       1  BOWL
# 4    Marcus Stoinis  129500      Melbourne Stars     0      1       1  ALLR
# 2        Josh Brown  114400  Melbourne Renegades     0      1       0   BAT
# 6      Peter Siddle  100200      Melbourne Stars     0      0       1  BOWL
# 8        Sam Harper   71700      Melbourne Stars     1      1       0    WK
# 5    Matthew Gilkes   64300       Sydney Thunder     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 7        1          1        1  134.44250          90.89550
# 10       1          1        1  211.15350         141.62400
# 9        1          1        0  117.85450          57.51600
# 0        1          1        0  126.44900          84.76850
# 11       1          1        1   81.99375          40.23625
# 1        1          1        1   79.73850          40.34450
# 3        1          1        1  177.33450         118.93900
# 4        1          1        1   71.71000          39.47300
# 2        1          1        1   82.49200          39.24150
# 6        1          1        1   86.59350          41.51050
# 8        1          1        1   87.82300          40.32550
# 5        1          1        0  125.22650          82.91350
#                Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 7      Sam Billings  161800       Sydney Thunder     1      1       0    WK
# 10         Wes Agar  159200       Sydney Thunder     0      0       1  BOWL
# 11  Will Sutherland  148400  Melbourne Renegades     0      1       1  ALLR
# 1      Jack Edwards  141700        Sydney Sixers     0      1       1  ALLR
# 3   Lockie Ferguson  134300       Sydney Thunder     0      0       1  BOWL
# 4    Marcus Stoinis  129500      Melbourne Stars     0      1       1  ALLR
# 2        Josh Brown  114400  Melbourne Renegades     0      1       0   BAT
# 6      Peter Siddle  100200      Melbourne Stars     0      0       1  BOWL
# 8        Sam Harper   71700      Melbourne Stars     1      1       0    WK
#
#     weight  Available  In_Team    exp_pts  next_rnd_exp_pts
# 7        1          1        1  134.44250          90.89550
# 10       1          1        1  211.15350         141.62400
# 11       1          1        1   81.99375          40.23625
# 1        1          1        1   79.73850          40.34450
# 3        1          1        1  177.33450         118.93900
# 4        1          1        1   71.71000          39.47300
# 2        1          1        1   82.49200          39.24150
# 6        1          1        1   86.59350          41.51050
# 8        1          1        1   87.82300          40.32550
#               Name   Price            Team  Wk_f  Bat_f  Bowl_f  Role  weight  \
# 9  Spencer Johnson  157800   Brisbane Heat     0      0       1  BOWL       1
# 0     David Warner  151900  Sydney Thunder     0      1       0   BAT       1
# 5   Matthew Gilkes   64300  Sydney Thunder     1      1       0    WK       1
#
#    Available  In_Team   exp_pts  next_rnd_exp_pts
# 9          1        0  117.8545           57.5160
# 0          1        0  126.4490           84.7685
# 5          1        0  125.2265           82.9135
