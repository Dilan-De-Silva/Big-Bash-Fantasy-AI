# %% [markdown]
# # BBLF AI Selector: Part 1: Pre Tournament Optimal Squad - Optimser

# %% [markdown]
# # 0. Prerequistes

# %%
# 0. Prerequistes

import pandas as pd
import numpy as np
import os
import random
from mip import Model, xsum, maximize, BINARY 

os.getcwd()
directory = 'C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI'

# %% [markdown]
# # 1. Data Extraction

# %%
# 1. Data Extraction 
    # Optimal Number of Rounds
opt_round = 3

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(directory,'data/python_datasets/player_price_round1_fix.csv'), low_memory=False)
print(price_df)

# Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available"]].rename(columns = {"Full_Name": "Name"}) 
    # Pull in team fixture csv file

#team_fix_df = pd.read_csv(os.path.join(directory,'data/python_datasets/team_fixture.csv'), low_memory=False)
#team_fix_df = team_fix_df.melt(id_vars = "Team")
#team_fix_df = team_fix_df.rename(columns = {"variable": "Round", "value": "Opposition"})
#team_fix_df[["Round", "Game"]] = team_fix_df["Round"].str.split("_", expand = True)
#team_fix_df["Round"] = team_fix_df["Round"].str[1:].astype(int)
#team_fix_df = team_fix_df[["Team", "Round", "Opposition"]]
#team_fix_df = team_fix_df[team_fix_df.Round <= opt_round].dropna()
#print(team_fix_df)

team_fix_df = pd.read_csv(os.path.join(directory,'data/python_datasets/team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round <= opt_round].dropna()
print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(directory,'data/python_datasets/bbl14_fullteam_model_score.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
print(game_df)

    # Join on expected points for each game
print(game_df.columns)
print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f"], right_on = ["Name", "Team", "opp", "venue", "Home_f"], how = "left")
#player_df_raw["exp_pts"] = np.random.randint(0, 125, player_df_raw.shape[0])
player_df_raw["weight"] = 1
print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# Out:
#       Last_Name First_Name First_Name_Short        Full_Name         player  \
# 0        Abbott       Sean               SA      Sean Abbott      SA Abbott
# 1          Agar     Ashton               AC      Ashton Agar        AC Agar
# 2          Agar        Wes               WA         Wes Agar        WA Agar
# 3         Allen       Finn              NaN       Finn Allen     Finn Allen
# 4         Allen     Fabian              NaN     Fabian Allen   Fabian Allen
# ..          ...        ...              ...              ...            ...
# 142       Wells        Jon               JW        Jon Wells       JW Wells
# 143  Wildermuth       Jack               JD  Jack Wildermuth  JD Wildermuth
# 144        Wood       Jack               JP        Jack Wood        JP Wood
# 145      Wright        Mac                M       Mac Wright       M Wright
# 146       Zampa       Adam                A       Adam Zampa        A Zampa
#
#       Price                 Team  Role  Available
# 0    131800        Sydney Sixers  BOWL          1
# 1    124100      Perth Scorchers  BOWL          0
# 2     99700       Sydney Thunder  BOWL          1
# 3    152000      Perth Scorchers   BAT          0
# 4    117500    Adelaide Strikers  ALLR          1
# ..      ...                  ...   ...        ...
# 142   78100  Melbourne Renegades   BAT          1
# 143   58500        Brisbane Heat  ALLR          0
# 144   58500        Brisbane Heat  ALLR          0
# 145  126300    Hobart Hurricanes   BAT          1
# 146   80100  Melbourne Renegades  BOWL          1
#
# [147 rows x 9 columns]
#                    Team           Opposition                     Venue  \
# 0     Adelaide Strikers       Sydney Thunder                     Other
# 1     Adelaide Strikers      Melbourne Stars             Adelaide Oval
# 2     Adelaide Strikers        Brisbane Heat                     GABBA
# 3     Adelaide Strikers    Hobart Hurricanes             Adelaide Oval
# 10      Melbourne Stars      Perth Scorchers             Perth Stadium
# 11      Melbourne Stars        Brisbane Heat  Melbourne Cricket Ground
# 12      Melbourne Stars    Adelaide Strikers             Adelaide Oval
# 13      Melbourne Stars        Sydney Sixers                       SCG
# 14      Melbourne Stars       Sydney Thunder                     Other
# 20        Sydney Sixers  Melbourne Renegades                       SCG
# 21        Sydney Sixers       Sydney Thunder         Sydney Showground
# 22        Sydney Sixers      Melbourne Stars                       SCG
# 23        Sydney Sixers        Brisbane Heat                     GABBA
# 30        Brisbane Heat      Melbourne Stars  Melbourne Cricket Ground
# 31        Brisbane Heat    Adelaide Strikers                     GABBA
# 32        Brisbane Heat        Sydney Sixers             Perth Stadium
# 33        Brisbane Heat      Perth Scorchers                     GABBA
# 40      Perth Scorchers      Melbourne Stars             Perth Stadium
# 41      Perth Scorchers    Hobart Hurricanes                    Hobart
# 42      Perth Scorchers  Melbourne Renegades                    Marvel
# 43      Perth Scorchers        Brisbane Heat             Perth Stadium
# 50       Sydney Thunder    Adelaide Strikers                     Other
# 51       Sydney Thunder        Sydney Sixers         Sydney Showground
# 52       Sydney Thunder      Melbourne Stars                     Other
# 60    Hobart Hurricanes  Melbourne Renegades                     Other
# 61    Hobart Hurricanes      Perth Scorchers                    Hobart
# 62    Hobart Hurricanes    Adelaide Strikers             Adelaide Oval
# 70  Melbourne Renegades        Sydney Sixers                       SCG
# 71  Melbourne Renegades    Hobart Hurricanes                     Other
# 72  Melbourne Renegades      Perth Scorchers                    Marvel
#
#     Home_f  Round
# 0        0      1
# 1        1      2
# 2        0      2
# 3        1      3
# 10       0      1
# 11       1      1
# 12       0      2
# 13       0      3
# 14       0      3
# 20       1      1
# 21       0      2
# 22       1      3
# 23       0      3
# 30       0      1
# 31       1      2
# 32       0      3
# 33       1      3
# 40       1      1
# 41       0      2
# 42       0      2
# 43       1      3
# 50       0      1
# 51       1      2
# 52       0      3
# 60       0      1
# 61       1      2
# 62       0      3
# 70       0      1
# 71       0      1
# 72       1      2
#              Name                 Team                  opp  \
# 0     Sean Abbott        Sydney Sixers  Melbourne Renegades
# 1     Sean Abbott        Sydney Sixers       Sydney Thunder
# 2     Sean Abbott        Sydney Sixers      Melbourne Stars
# 3     Sean Abbott        Sydney Sixers        Brisbane Heat
# 4     Sean Abbott        Sydney Sixers    Hobart Hurricanes
# ...           ...                  ...                  ...
# 1465   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1466   Adam Zampa  Melbourne Renegades      Perth Scorchers
# 1467   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1468   Adam Zampa  Melbourne Renegades    Hobart Hurricanes
# 1469   Adam Zampa  Melbourne Renegades        Brisbane Heat
#
#                          venue  Home_f  Round    Full_Name  season_fp_lag1  \
# 0                          SCG       1      1  Sean Abbott           448.0
# 1            Sydney Showground       0      2  Sean Abbott           448.0
# 2                          SCG       1      3  Sean Abbott           448.0
# 3                        GABBA       0      3  Sean Abbott           448.0
# 4                       Hobart       0      4  Sean Abbott           448.0
# ...                        ...     ...    ...          ...             ...
# 1465  Melbourne Cricket Ground       0      5   Adam Zampa           235.0
# 1466             Perth Stadium       0      6   Adam Zampa           235.0
# 1467                    Marvel       1      7   Adam Zampa           235.0
# 1468                    Hobart       0      8   Adam Zampa           235.0
# 1469                    Marvel       1      9   Adam Zampa           235.0
#
#       avg_season_fp_lag1  max_season_fp_lag1  ...  avg_season_fp_lag3  \
# 0              49.777778               139.0  ...           63.692308
# 1              49.777778               139.0  ...           63.692308
# 2              49.777778               139.0  ...           63.692308
# 3              49.777778               139.0  ...           63.692308
# 4              49.777778               139.0  ...           63.692308
# ...                  ...                 ...  ...                 ...
# 1465           29.375000                62.0  ...           38.500000
# 1466           29.375000                62.0  ...           38.500000
# 1467           29.375000                62.0  ...           38.500000
# 1468           29.375000                62.0  ...           38.500000
# 1469           29.375000                62.0  ...           38.500000
#
#       max_season_fp_lag3  min_season_fp_lag3  med_season_fp_lag3  \
# 0                  157.0                 7.0                48.0
# 1                  157.0                 7.0                48.0
# 2                  157.0                 7.0                48.0
# 3                  157.0                 7.0                48.0
# 4                  157.0                 7.0                48.0
# ...                  ...                 ...                 ...
# 1465                70.0                 5.0                36.5
# 1466                70.0                 5.0                36.5
# 1467                70.0                 5.0                36.5
# 1468                70.0                 5.0                36.5
# 1469                70.0                 5.0                36.5
#
#       sd_season_fp_lag3  match_cnt_lag3  season  rank  rank_group    exp_pts
# 0             54.608279            13.0      14     2        High  44.377133
# 1             54.608279            13.0      14     2        High  42.854199
# 2             54.608279            13.0      14     2        High  43.304810
# 3             54.608279            13.0      14     2        High  46.412899
# 4             54.608279            13.0      14     2        High  46.364273
# ...                 ...             ...     ...   ...         ...        ...
# 1465          26.154456            10.0      14     8         Low  41.223206
# 1466          26.154456            10.0      14     8         Low  33.898375
# 1467          26.154456            10.0      14     8         Low  41.024582
# 1468          26.154456            10.0      14     8         Low  40.590905
# 1469          26.154456            10.0      14     8         Low  40.618309
#
# [1470 rows x 32 columns]
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 548   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 549   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 550   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 551   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 552   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
#
#      Available           Opposition              Venue  Home_f  Round
# 0            1  Melbourne Renegades                SCG       1      1
# 1            1       Sydney Thunder  Sydney Showground       0      2
# 2            1      Melbourne Stars                SCG       1      3
# 3            1        Brisbane Heat              GABBA       0      3
# 4            0      Melbourne Stars      Perth Stadium       1      1
# ..         ...                  ...                ...     ...    ...
# 548          1      Perth Scorchers             Hobart       1      2
# 549          1    Adelaide Strikers      Adelaide Oval       0      3
# 550          1        Sydney Sixers                SCG       0      1
# 551          1    Hobart Hurricanes              Other       0      1
# 552          1      Perth Scorchers             Marvel       1      2
#
# [553 rows x 12 columns]
# Index(['Name', 'Price', 'Team', 'Wk_f', 'Bat_f', 'Bowl_f', 'Role', 'Available',
#        'Opposition', 'Venue', 'Home_f', 'Round'],
#       dtype='object')
# Index(['Name', 'Team', 'opp', 'venue', 'Home_f', 'Round', 'Full_Name',
#        'season_fp_lag1', 'avg_season_fp_lag1', 'max_season_fp_lag1',
#        'min_season_fp_lag1', 'med_season_fp_lag1', 'sd_season_fp_lag1',
#        'match_cnt_lag1', 'season_fp_lag2', 'avg_season_fp_lag2',
#        'max_season_fp_lag2', 'min_season_fp_lag2', 'med_season_fp_lag2',
#        'sd_season_fp_lag2', 'match_cnt_lag2', 'season_fp_lag3',
#        'avg_season_fp_lag3', 'max_season_fp_lag3', 'min_season_fp_lag3',
#        'med_season_fp_lag3', 'sd_season_fp_lag3', 'match_cnt_lag3', 'season',
#        'rank', 'rank_group', 'exp_pts'],
#       dtype='object')
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 2    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 3    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 4    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 548   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 549   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 550   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 551   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 552   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
#
#      Available           Opposition              Venue  ...  \
# 0            1  Melbourne Renegades                SCG  ...
# 1            1       Sydney Thunder  Sydney Showground  ...
# 2            1      Melbourne Stars                SCG  ...
# 3            1        Brisbane Heat              GABBA  ...
# 4            0      Melbourne Stars      Perth Stadium  ...
# ..         ...                  ...                ...  ...
# 548          1      Perth Scorchers             Hobart  ...
# 549          1    Adelaide Strikers      Adelaide Oval  ...
# 550          1        Sydney Sixers                SCG  ...
# 551          1    Hobart Hurricanes              Other  ...
# 552          1      Perth Scorchers             Marvel  ...
#
#      max_season_fp_lag3  min_season_fp_lag3 med_season_fp_lag3  \
# 0                 157.0                 7.0               48.0
# 1                 157.0                 7.0               48.0
# 2                 157.0                 7.0               48.0
# 3                 157.0                 7.0               48.0
# 4                 107.0                10.0               57.0
# ..                  ...                 ...                ...
# 548                 6.0                 6.0                6.0
# 549                 6.0                 6.0                6.0
# 550                70.0                 5.0               36.5
# 551                70.0                 5.0               36.5
# 552                70.0                 5.0               36.5
#
#     sd_season_fp_lag3  match_cnt_lag3 season  rank  rank_group    exp_pts  \
# 0           54.608279            13.0     14     2        High  44.377133
# 1           54.608279            13.0     14     2        High  42.854199
# 2           54.608279            13.0     14     2        High  43.304810
# 3           54.608279            13.0     14     2        High  46.412899
# 4           26.326702            15.0     14     1        High  28.902633
# ..                ...             ...    ...   ...         ...        ...
# 548               NaN             1.0     14     4      Middle  34.757817
# 549               NaN             1.0     14     4      Middle  32.140229
# 550         26.154456            10.0     14     8         Low  37.164088
# 551         26.154456            10.0     14     8         Low  40.590905
# 552         26.154456            10.0     14     8         Low  38.467628
#
#      weight
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 548       1
# 549       1
# 550       1
# 551       1
# 552       1
#
# [553 rows x 42 columns]

# %% [markdown]
# # 2. Optimisation Process
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 4
# 2. Atleast NA wicketkeeper
# 3. Atleast 2 batters
# 4. Atleast 1 bowlers
# 5. Total budget of team is less than $887000

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

#model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"] = model_df.loc[:,"opp_Adelaide Strikers":"venue_WACA"].astype(object)

weight = player_df["weight"]
available = player_df["Available"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 4, range(len(price))
wk_cnt, total_wk = 0, range(len(price))
bat_cnt, total_bat = 2, range(len(price))
bowl_cnt, total_bowl = 1, range(len(price))
budget, total_budget = 887000, range(len(price))

m = Model("knapsack")

x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]

print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))

sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/optimal_4_remaining_post_mistake.csv')
# Out:
# [<mip.entities.Var object at 0x0000018C8D03C250>, <mip.entities.Var object at 0x0000018C8D03C2B0>, <mip.entities.Var object at 0x0000018C8D03C6D0>, <mip.entities.Var object at 0x0000018C8D03C7C0>, <mip.entities.Var object at 0x0000018C8D03C820>, <mip.entities.Var object at 0x0000018C8D03C880>, <mip.entities.Var object at 0x0000018C8D03C6A0>, <mip.entities.Var object at 0x0000018C8D03C730>, <mip.entities.Var object at 0x0000018C8D03C7F0>, <mip.entities.Var object at 0x0000018C8D03C790>, <mip.entities.Var object at 0x0000018C8D03C910>, <mip.entities.Var object at 0x0000018C8D03C4F0>, <mip.entities.Var object at 0x0000018C8D03C5B0>, <mip.entities.Var object at 0x0000018C8D03C9A0>, <mip.entities.Var object at 0x0000018C8D03C8E0>, <mip.entities.Var object at 0x0000018C8D03C940>, <mip.entities.Var object at 0x0000018C8D03CA30>, <mip.entities.Var object at 0x0000018C8D03C9D0>, <mip.entities.Var object at 0x0000018C8D03CA00>, <mip.entities.Var object at 0x0000018C8D03C850>, <mip.entities.Var object at 0x0000018C8D03CAF0>, <mip.entities.Var object at 0x0000018C8D03C8B0>, <mip.entities.Var object at 0x0000018C8D03C970>, <mip.entities.Var object at 0x0000018C8D03CB80>, <mip.entities.Var object at 0x0000018C8D03CBB0>, <mip.entities.Var object at 0x0000018C8D03CAC0>, <mip.entities.Var object at 0x0000018C8D03CC10>, <mip.entities.Var object at 0x0000018C8D03CB50>, <mip.entities.Var object at 0x0000018C8D03CA90>, <mip.entities.Var object at 0x0000018C8D03CA60>, <mip.entities.Var object at 0x0000018C8D03CC70>, <mip.entities.Var object at 0x0000018C8D03CB20>, <mip.entities.Var object at 0x0000018C8D03CD00>, <mip.entities.Var object at 0x0000018C8D03CD60>, <mip.entities.Var object at 0x0000018C8D03CCA0>, <mip.entities.Var object at 0x0000018C8D03CCD0>, <mip.entities.Var object at 0x0000018C8D03CD90>, <mip.entities.Var object at 0x0000018C8D03CBE0>, <mip.entities.Var object at 0x0000018C8D03CDF0>, <mip.entities.Var object at 0x0000018C8D03CDC0>, <mip.entities.Var object at 0x0000018C8D03CE50>, <mip.entities.Var object at 0x0000018C8D03CE20>, <mip.entities.Var object at 0x0000018C8D03CD30>, <mip.entities.Var object at 0x0000018C8D03CEB0>, <mip.entities.Var object at 0x0000018C8D03CF70>, <mip.entities.Var object at 0x0000018C8D03CEE0>, <mip.entities.Var object at 0x0000018C8D03CC40>, <mip.entities.Var object at 0x0000018C8D03D000>, <mip.entities.Var object at 0x0000018C8D03CFA0>, <mip.entities.Var object at 0x0000018C8D03CFD0>, <mip.entities.Var object at 0x0000018C8D03D060>, <mip.entities.Var object at 0x0000018C8D03D0C0>, <mip.entities.Var object at 0x0000018C8D03CE80>, <mip.entities.Var object at 0x0000018C8D03CF10>, <mip.entities.Var object at 0x0000018C8D03D120>, <mip.entities.Var object at 0x0000018C8D03D180>, <mip.entities.Var object at 0x0000018C8D03D030>, <mip.entities.Var object at 0x0000018C8D03D0F0>, <mip.entities.Var object at 0x0000018C8D03D1E0>, <mip.entities.Var object at 0x0000018C8D03D240>, <mip.entities.Var object at 0x0000018C8D03CF40>, <mip.entities.Var object at 0x0000018C8D03D1B0>, <mip.entities.Var object at 0x0000018C8D03D2A0>, <mip.entities.Var object at 0x0000018C8D03D300>, <mip.entities.Var object at 0x0000018C8D03D360>, <mip.entities.Var object at 0x0000018C8D03D3C0>, <mip.entities.Var object at 0x0000018C8D03D210>, <mip.entities.Var object at 0x0000018C8D03D270>, <mip.entities.Var object at 0x0000018C8D03D090>, <mip.entities.Var object at 0x0000018C8D03D420>, <mip.entities.Var object at 0x0000018C8D03D4B0>, <mip.entities.Var object at 0x0000018C8D03D510>, <mip.entities.Var object at 0x0000018C8D03D330>, <mip.entities.Var object at 0x0000018C8D03D2D0>, <mip.entities.Var object at 0x0000018C8D03D390>, <mip.entities.Var object at 0x0000018C8D03D4E0>, <mip.entities.Var object at 0x0000018C8D03D3F0>, <mip.entities.Var object at 0x0000018C8D03D540>, <mip.entities.Var object at 0x0000018C8D03D600>, <mip.entities.Var object at 0x0000018C8D03D660>, <mip.entities.Var object at 0x0000018C8D03D150>, <mip.entities.Var object at 0x ...
# selected items: [11, 25, 57, 92]
# Total Expect Points: 921.6774764943476
# Total Team Cost: 846700
# Number of Wk: 0
# Number of Bat: 3
# Number of Bowl: 3
# Available Players: 4
#              Name   Price               Team  Wk_f  Bat_f  Bowl_f  Role  \
# 92  Matthew Short  304200  Adelaide Strikers     0      1       1  ALLR
# 57  Jamie Overton  207700  Adelaide Strikers     0      1       1  ALLR
# 11  Ben Dwarshuis  136900      Sydney Sixers     0      0       1  BOWL
# 25     Chris Lynn  197900  Adelaide Strikers     0      1       0   BAT
#
#     weight  Available     exp_pts
# 92       1          1  288.059352
# 57       1          1  221.083426
# 11       1          1  210.153062
# 25       1          1  202.381637

# %% [markdown]
# # 1b. Data Extraction (Best Bench Trick Player)

# %%
# 1. Data Extraction 
    # Optimal Number of Rounds
opt_round = 2

    # Pull in player price data csv file 

price_df = pd.read_csv(os.path.join(directory,'data/python_datasets/player_price_round1_fix_roll_window.csv'), low_memory=False)
print(price_df)

# Player Role Flags

price_df["Wk_f"] = np.where((price_df["Role"] == "WK"), 1, 0)
price_df["Bat_f"] = np.where((price_df["Role"] == "WK") |(price_df["Role"] == "BAT") | (price_df["Role"] == "ALLR") , 1, 0)
price_df["Bowl_f"] = np.where((price_df["Role"] == "BOWL") | (price_df["Role"] == "ALLR") , 1, 0)
price_df = price_df[["Full_Name", "Price", "Team","Wk_f", "Bat_f", "Bowl_f", "Role", "Available"]].rename(columns = {"Full_Name": "Name"}) 
    # Pull in team fixture csv file

#team_fix_df = pd.read_csv(os.path.join(directory,'data/python_datasets/team_fixture.csv'), low_memory=False)
#team_fix_df = team_fix_df.melt(id_vars = "Team")
#team_fix_df = team_fix_df.rename(columns = {"variable": "Round", "value": "Opposition"})
#team_fix_df[["Round", "Game"]] = team_fix_df["Round"].str.split("_", expand = True)
#team_fix_df["Round"] = team_fix_df["Round"].str[1:].astype(int)
#team_fix_df = team_fix_df[["Team", "Round", "Opposition"]]
#team_fix_df = team_fix_df[team_fix_df.Round <= opt_round].dropna()
#print(team_fix_df)

team_fix_df = pd.read_csv(os.path.join(directory,'data/python_datasets/team_loc_fixture.csv'), low_memory=False)
team_fix_df = team_fix_df[team_fix_df.Round <= opt_round].dropna()
print(team_fix_df)

    # Pull player expected points csv file
exp_pts_df = pd.read_csv(os.path.join(directory,'data/python_datasets/bbl14_fullteam_model_score.csv'), low_memory=False).drop(["Unnamed: 0", "player"], axis = 1)
print(exp_pts_df)

    # Join team fixture to player price to create a row for each game
game_df = pd.merge(price_df , team_fix_df, left_on = ["Team"], right_on = ["Team"], how = "left")
print(game_df)

    # Join on expected points for each game
print(game_df.columns)
print(exp_pts_df.columns)
player_df_raw = pd.merge(game_df, exp_pts_df, left_on = ["Name", "Team", "Opposition", "Venue", "Home_f"], right_on = ["Name", "Team", "opp", "venue", "Home_f"], how = "left")
#player_df_raw["exp_pts"] = np.random.randint(0, 125, player_df_raw.shape[0])
player_df_raw["weight"] = 1
print(player_df_raw)

    # Aggregate by player name (calculate total expected points for each player for x number of rounds)
player_df = player_df_raw.groupby(['Name', 'Price', "Team", "Wk_f", "Bat_f", "Bowl_f", "Role", "weight","Available"], as_index=False).agg(
exp_pts=('exp_pts',"sum"))
# Out:
#       Last_Name First_Name First_Name_Short        Full_Name         player  \
# 0        Abbott       Sean               SA      Sean Abbott      SA Abbott
# 1          Agar     Ashton               AC      Ashton Agar        AC Agar
# 2          Agar        Wes               WA         Wes Agar        WA Agar
# 3         Allen       Finn              NaN       Finn Allen     Finn Allen
# 4         Allen     Fabian              NaN     Fabian Allen   Fabian Allen
# ..          ...        ...              ...              ...            ...
# 142       Wells        Jon               JW        Jon Wells       JW Wells
# 143  Wildermuth       Jack               JD  Jack Wildermuth  JD Wildermuth
# 144        Wood       Jack               JP        Jack Wood        JP Wood
# 145      Wright        Mac                M       Mac Wright       M Wright
# 146       Zampa       Adam                A       Adam Zampa        A Zampa
#
#       Price                 Team  Role  Available
# 0    131800        Sydney Sixers  BOWL          0
# 1    124100      Perth Scorchers  BOWL          0
# 2     99700       Sydney Thunder  BOWL          1
# 3    152000      Perth Scorchers   BAT          0
# 4    117500    Adelaide Strikers  ALLR          0
# ..      ...                  ...   ...        ...
# 142   78100  Melbourne Renegades   BAT          1
# 143   58500        Brisbane Heat  ALLR          0
# 144   58500        Brisbane Heat  ALLR          0
# 145  126300    Hobart Hurricanes   BAT          1
# 146   80100  Melbourne Renegades  BOWL          1
#
# [147 rows x 9 columns]
#                    Team           Opposition                     Venue  \
# 0     Adelaide Strikers       Sydney Thunder                     Other
# 1     Adelaide Strikers      Melbourne Stars             Adelaide Oval
# 2     Adelaide Strikers        Brisbane Heat                     GABBA
# 10      Melbourne Stars      Perth Scorchers             Perth Stadium
# 11      Melbourne Stars        Brisbane Heat  Melbourne Cricket Ground
# 12      Melbourne Stars    Adelaide Strikers             Adelaide Oval
# 20        Sydney Sixers  Melbourne Renegades                       SCG
# 21        Sydney Sixers       Sydney Thunder         Sydney Showground
# 30        Brisbane Heat      Melbourne Stars  Melbourne Cricket Ground
# 31        Brisbane Heat    Adelaide Strikers                     GABBA
# 40      Perth Scorchers      Melbourne Stars             Perth Stadium
# 41      Perth Scorchers    Hobart Hurricanes                    Hobart
# 42      Perth Scorchers  Melbourne Renegades                    Marvel
# 50       Sydney Thunder    Adelaide Strikers                     Other
# 51       Sydney Thunder        Sydney Sixers         Sydney Showground
# 60    Hobart Hurricanes  Melbourne Renegades                     Other
# 61    Hobart Hurricanes      Perth Scorchers                    Hobart
# 70  Melbourne Renegades        Sydney Sixers                       SCG
# 71  Melbourne Renegades    Hobart Hurricanes                     Other
# 72  Melbourne Renegades      Perth Scorchers                    Marvel
#
#     Home_f  Round
# 0        0      1
# 1        1      2
# 2        0      2
# 10       0      1
# 11       1      1
# 12       0      2
# 20       1      1
# 21       0      2
# 30       0      1
# 31       1      2
# 40       1      1
# 41       0      2
# 42       0      2
# 50       0      1
# 51       1      2
# 60       0      1
# 61       1      2
# 70       0      1
# 71       0      1
# 72       1      2
#              Name                 Team                  opp  \
# 0     Sean Abbott        Sydney Sixers  Melbourne Renegades
# 1     Sean Abbott        Sydney Sixers       Sydney Thunder
# 2     Sean Abbott        Sydney Sixers      Melbourne Stars
# 3     Sean Abbott        Sydney Sixers        Brisbane Heat
# 4     Sean Abbott        Sydney Sixers    Hobart Hurricanes
# ...           ...                  ...                  ...
# 1465   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1466   Adam Zampa  Melbourne Renegades      Perth Scorchers
# 1467   Adam Zampa  Melbourne Renegades      Melbourne Stars
# 1468   Adam Zampa  Melbourne Renegades    Hobart Hurricanes
# 1469   Adam Zampa  Melbourne Renegades        Brisbane Heat
#
#                          venue  Home_f  Round    Full_Name  season_fp_lag1  \
# 0                          SCG       1      1  Sean Abbott           448.0
# 1            Sydney Showground       0      2  Sean Abbott           448.0
# 2                          SCG       1      3  Sean Abbott           448.0
# 3                        GABBA       0      3  Sean Abbott           448.0
# 4                       Hobart       0      4  Sean Abbott           448.0
# ...                        ...     ...    ...          ...             ...
# 1465  Melbourne Cricket Ground       0      5   Adam Zampa           235.0
# 1466             Perth Stadium       0      6   Adam Zampa           235.0
# 1467                    Marvel       1      7   Adam Zampa           235.0
# 1468                    Hobart       0      8   Adam Zampa           235.0
# 1469                    Marvel       1      9   Adam Zampa           235.0
#
#       avg_season_fp_lag1  max_season_fp_lag1  ...  avg_season_fp_lag3  \
# 0              49.777778               139.0  ...           63.692308
# 1              49.777778               139.0  ...           63.692308
# 2              49.777778               139.0  ...           63.692308
# 3              49.777778               139.0  ...           63.692308
# 4              49.777778               139.0  ...           63.692308
# ...                  ...                 ...  ...                 ...
# 1465           29.375000                62.0  ...           38.500000
# 1466           29.375000                62.0  ...           38.500000
# 1467           29.375000                62.0  ...           38.500000
# 1468           29.375000                62.0  ...           38.500000
# 1469           29.375000                62.0  ...           38.500000
#
#       max_season_fp_lag3  min_season_fp_lag3  med_season_fp_lag3  \
# 0                  157.0                 7.0                48.0
# 1                  157.0                 7.0                48.0
# 2                  157.0                 7.0                48.0
# 3                  157.0                 7.0                48.0
# 4                  157.0                 7.0                48.0
# ...                  ...                 ...                 ...
# 1465                70.0                 5.0                36.5
# 1466                70.0                 5.0                36.5
# 1467                70.0                 5.0                36.5
# 1468                70.0                 5.0                36.5
# 1469                70.0                 5.0                36.5
#
#       sd_season_fp_lag3  match_cnt_lag3  season  rank  rank_group    exp_pts
# 0             54.608279            13.0      14     2        High  44.377133
# 1             54.608279            13.0      14     2        High  42.854199
# 2             54.608279            13.0      14     2        High  43.304810
# 3             54.608279            13.0      14     2        High  46.412899
# 4             54.608279            13.0      14     2        High  46.364273
# ...                 ...             ...     ...   ...         ...        ...
# 1465          26.154456            10.0      14     8         Low  41.223206
# 1466          26.154456            10.0      14     8         Low  33.898375
# 1467          26.154456            10.0      14     8         Low  41.024582
# 1468          26.154456            10.0      14     8         Low  40.590905
# 1469          26.154456            10.0      14     8         Low  40.618309
#
# [1470 rows x 32 columns]
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 2    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# 3    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# 4    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 363   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 364   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 365   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 366   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 367   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
#
#      Available           Opposition              Venue  Home_f  Round
# 0            0  Melbourne Renegades                SCG       1      1
# 1            0       Sydney Thunder  Sydney Showground       0      2
# 2            0      Melbourne Stars      Perth Stadium       1      1
# 3            0    Hobart Hurricanes             Hobart       0      2
# 4            0  Melbourne Renegades             Marvel       0      2
# ..         ...                  ...                ...     ...    ...
# 363          1  Melbourne Renegades              Other       0      1
# 364          1      Perth Scorchers             Hobart       1      2
# 365          1        Sydney Sixers                SCG       0      1
# 366          1    Hobart Hurricanes              Other       0      1
# 367          1      Perth Scorchers             Marvel       1      2
#
# [368 rows x 12 columns]
# Index(['Name', 'Price', 'Team', 'Wk_f', 'Bat_f', 'Bowl_f', 'Role', 'Available',
#        'Opposition', 'Venue', 'Home_f', 'Round'],
#       dtype='object')
# Index(['Name', 'Team', 'opp', 'venue', 'Home_f', 'Round', 'Full_Name',
#        'season_fp_lag1', 'avg_season_fp_lag1', 'max_season_fp_lag1',
#        'min_season_fp_lag1', 'med_season_fp_lag1', 'sd_season_fp_lag1',
#        'match_cnt_lag1', 'season_fp_lag2', 'avg_season_fp_lag2',
#        'max_season_fp_lag2', 'min_season_fp_lag2', 'med_season_fp_lag2',
#        'sd_season_fp_lag2', 'match_cnt_lag2', 'season_fp_lag3',
#        'avg_season_fp_lag3', 'max_season_fp_lag3', 'min_season_fp_lag3',
#        'med_season_fp_lag3', 'sd_season_fp_lag3', 'match_cnt_lag3', 'season',
#        'rank', 'rank_group', 'exp_pts'],
#       dtype='object')
#             Name   Price                 Team  Wk_f  Bat_f  Bowl_f  Role  \
# 0    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 1    Sean Abbott  131800        Sydney Sixers     0      0       1  BOWL
# 2    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# 3    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# 4    Ashton Agar  124100      Perth Scorchers     0      0       1  BOWL
# ..           ...     ...                  ...   ...    ...     ...   ...
# 363   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 364   Mac Wright  126300    Hobart Hurricanes     0      1       0   BAT
# 365   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 366   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
# 367   Adam Zampa   80100  Melbourne Renegades     0      0       1  BOWL
#
#      Available           Opposition              Venue  ...  \
# 0            0  Melbourne Renegades                SCG  ...
# 1            0       Sydney Thunder  Sydney Showground  ...
# 2            0      Melbourne Stars      Perth Stadium  ...
# 3            0    Hobart Hurricanes             Hobart  ...
# 4            0  Melbourne Renegades             Marvel  ...
# ..         ...                  ...                ...  ...
# 363          1  Melbourne Renegades              Other  ...
# 364          1      Perth Scorchers             Hobart  ...
# 365          1        Sydney Sixers                SCG  ...
# 366          1    Hobart Hurricanes              Other  ...
# 367          1      Perth Scorchers             Marvel  ...
#
#      max_season_fp_lag3  min_season_fp_lag3 med_season_fp_lag3  \
# 0                 157.0                 7.0               48.0
# 1                 157.0                 7.0               48.0
# 2                 107.0                10.0               57.0
# 3                 107.0                10.0               57.0
# 4                 107.0                10.0               57.0
# ..                  ...                 ...                ...
# 363                 6.0                 6.0                6.0
# 364                 6.0                 6.0                6.0
# 365                70.0                 5.0               36.5
# 366                70.0                 5.0               36.5
# 367                70.0                 5.0               36.5
#
#     sd_season_fp_lag3  match_cnt_lag3 season  rank  rank_group    exp_pts  \
# 0           54.608279            13.0     14     2        High  44.377133
# 1           54.608279            13.0     14     2        High  42.854199
# 2           26.326702            15.0     14     1        High  28.902633
# 3           26.326702            15.0     14     1        High  35.325833
# 4           26.326702            15.0     14     1        High  35.087525
# ..                ...             ...    ...   ...         ...        ...
# 363               NaN             1.0     14     4      Middle  34.727386
# 364               NaN             1.0     14     4      Middle  34.757817
# 365         26.154456            10.0     14     8         Low  37.164088
# 366         26.154456            10.0     14     8         Low  40.590905
# 367         26.154456            10.0     14     8         Low  38.467628
#
#      weight
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 363       1
# 364       1
# 365       1
# 366       1
# 367       1
#
# [368 rows x 42 columns]

# %% [markdown]
# # 2b. Optimisation Process
#
# Optimisation Objective: Maximise the number of expected fantasy points
#
# Constraints:
# 1. Number of players selected must be 1
# 2. Atleast NA wicketkeeper
# 3. Atleast NA batters
# 4. Atleast NA bowlers
# 5. Total budget of team is less than $155900

# %%
# Optimisation Setup

points = player_df["exp_pts"]

price = player_df["Price"]

weight = player_df["weight"]
available = player_df["Available"]
wk_weight = player_df["Wk_f"]
bat_weight = player_df["Bat_f"]
bowl_weight = player_df["Bowl_f"]

play_cnt, total_player = 1, range(len(price))
wk_cnt, total_wk = 0, range(len(price))
bat_cnt, total_bat = 0, range(len(price))
bowl_cnt, total_bowl = 0, range(len(price))
budget, total_budget = 155900, range(len(price))

m = Model("knapsack")

x = [m.add_var(var_type=BINARY) for i in total_player]
print(x)

m.objective = maximize(xsum(points[i]*x[i] for i in total_player))

m += xsum(weight[i] * x[i] for i in total_player) == play_cnt
m += xsum(wk_weight[i] * x[i] for i in total_wk) >= wk_cnt
m += xsum(bat_weight[i] * x[i] for i in total_bat) >= bat_cnt
m += xsum(bowl_weight[i] * x[i] for i in total_bowl) >= bowl_cnt
m += xsum(price[i] * x[i] for i in total_budget) <= budget
m += xsum(available[i] * x[i] for i in total_player) == play_cnt

m.optimize()

selected = [i for i in total_player if x[i].x >= 0.99]
print("selected items: {}".format(selected))

sel_player_df = player_df.iloc[selected]

print("Total Expect Points:", sum(sel_player_df["exp_pts"]))
print("Total Team Cost:", sum(sel_player_df["Price"]))
print("Number of Wk:", sum(sel_player_df["Wk_f"]))
print("Number of Bat:", sum(sel_player_df["Bat_f"]))
print("Number of Bowl:", sum(sel_player_df["Bowl_f"]))
print("Available Players:", sum(sel_player_df["Available"]))

print(sel_player_df.sort_values(by = "exp_pts", ascending = False))

sel_player_df.to_csv('C:/Users/dilan/OneDrive/Documents/Data Science Projects/Big Bash Fantasy AI/data/python_datasets/bench_trick_remaining_post_mistake.csv')
# Out:
# [<mip.entities.Var object at 0x0000020EF47245B0>, <mip.entities.Var object at 0x0000020EF4724730>, <mip.entities.Var object at 0x0000020EF4724820>, <mip.entities.Var object at 0x0000020EF47248B0>, <mip.entities.Var object at 0x0000020EF47247C0>, <mip.entities.Var object at 0x0000020EF47248E0>, <mip.entities.Var object at 0x0000020EF4724760>, <mip.entities.Var object at 0x0000020EF4724940>, <mip.entities.Var object at 0x0000020EF47244C0>, <mip.entities.Var object at 0x0000020EF4724970>, <mip.entities.Var object at 0x0000020EF4724A00>, <mip.entities.Var object at 0x0000020EF47246A0>, <mip.entities.Var object at 0x0000020EF4724610>, <mip.entities.Var object at 0x0000020EF4724880>, <mip.entities.Var object at 0x0000020EF47249D0>, <mip.entities.Var object at 0x0000020EF47249A0>, <mip.entities.Var object at 0x0000020EF4724A60>, <mip.entities.Var object at 0x0000020EF4724AC0>, <mip.entities.Var object at 0x0000020EF4724850>, <mip.entities.Var object at 0x0000020EF4724B20>, <mip.entities.Var object at 0x0000020EF4724910>, <mip.entities.Var object at 0x0000020EF4724A90>, <mip.entities.Var object at 0x0000020EF4724BE0>, <mip.entities.Var object at 0x0000020EF4724C40>, <mip.entities.Var object at 0x0000020EF4724D00>, <mip.entities.Var object at 0x0000020EF4724C10>, <mip.entities.Var object at 0x0000020EF4724CD0>, <mip.entities.Var object at 0x0000020EF4724D30>, <mip.entities.Var object at 0x0000020EF4724BB0>, <mip.entities.Var object at 0x0000020EF4724CA0>, <mip.entities.Var object at 0x0000020EF4724D60>, <mip.entities.Var object at 0x0000020EF4724E20>, <mip.entities.Var object at 0x0000020EF4724DC0>, <mip.entities.Var object at 0x0000020EF4724DF0>, <mip.entities.Var object at 0x0000020EF4724EE0>, <mip.entities.Var object at 0x0000020EF4724D90>, <mip.entities.Var object at 0x0000020EF4724F40>, <mip.entities.Var object at 0x0000020EF4724F10>, <mip.entities.Var object at 0x0000020EF4724E80>, <mip.entities.Var object at 0x0000020EF4724EB0>, <mip.entities.Var object at 0x0000020EF4724B50>, <mip.entities.Var object at 0x0000020EF4724FA0>, <mip.entities.Var object at 0x0000020EF4725090>, <mip.entities.Var object at 0x0000020EF4725030>, <mip.entities.Var object at 0x0000020EF47250C0>, <mip.entities.Var object at 0x0000020EF4725000>, <mip.entities.Var object at 0x0000020EF4725180>, <mip.entities.Var object at 0x0000020EF4725120>, <mip.entities.Var object at 0x0000020EF4725060>, <mip.entities.Var object at 0x0000020EF4725150>, <mip.entities.Var object at 0x0000020EF4724E50>, <mip.entities.Var object at 0x0000020EF4724F70>, <mip.entities.Var object at 0x0000020EF4724AF0>, <mip.entities.Var object at 0x0000020EF4724B80>, <mip.entities.Var object at 0x0000020EF47250F0>, <mip.entities.Var object at 0x0000020EF4725270>, <mip.entities.Var object at 0x0000020EF47251B0>, <mip.entities.Var object at 0x0000020EF4724FD0>, <mip.entities.Var object at 0x0000020EF47252A0>, <mip.entities.Var object at 0x0000020EF47252D0>, <mip.entities.Var object at 0x0000020EF47251E0>, <mip.entities.Var object at 0x0000020EF4725210>, <mip.entities.Var object at 0x0000020EF4725390>, <mip.entities.Var object at 0x0000020EF4725300>, <mip.entities.Var object at 0x0000020EF47253C0>, <mip.entities.Var object at 0x0000020EF4725420>, <mip.entities.Var object at 0x0000020EF4725240>, <mip.entities.Var object at 0x0000020EF4725450>, <mip.entities.Var object at 0x0000020EF47254B0>, <mip.entities.Var object at 0x0000020EF47253F0>, <mip.entities.Var object at 0x0000020EF47254E0>, <mip.entities.Var object at 0x0000020EF4725540>, <mip.entities.Var object at 0x0000020EF4725480>, <mip.entities.Var object at 0x0000020EF4725570>, <mip.entities.Var object at 0x0000020EF4725600>, <mip.entities.Var object at 0x0000020EF4725510>, <mip.entities.Var object at 0x0000020EF47255D0>, <mip.entities.Var object at 0x0000020EF4725660>, <mip.entities.Var object at 0x0000020EF47255A0>, <mip.entities.Var object at 0x0000020EF4725690>, <mip.entities.Var object at 0x0000020EF47256F0>, <mip.entities.Var object at 0x ...
# selected items: [69]
# Total Expect Points: 174.9140940357805
# Total Team Cost: 112200
# Number of Wk: 0
# Number of Bat: 1
# Number of Bowl: 0
# Available Players: 1
#           Name   Price                 Team  Wk_f  Bat_f  Bowl_f Role  weight  \
# 69  Josh Brown  112200  Melbourne Renegades     0      1       0  BAT       1
#
#     Available     exp_pts
# 69          1  174.914094
